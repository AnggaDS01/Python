# %%
import os
import dotenv
from dotenv import load_dotenv, find_dotenv
import configparser

# %% [markdown]
# ### Load the path from .env

# %%
load_dotenv('../../datasets/Path/.env') # jika True maka berari ada maka ada file tersebut
# Out:
# True

# %% [markdown]
# ### Cara memanggil pathnya

# %%
path = os.getenv('path_dataset_cats_dogs') # sesuai kan dengan nama path atau key-nya

# %% [markdown]
# ### Cara menghapusnya

# %%
pop = os.environ.pop("path_dataset_cats_dogs")
