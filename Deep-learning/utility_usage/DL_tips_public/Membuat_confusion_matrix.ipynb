# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from nnfs.datasets import spiral_data
# Out:
# 2022-09-11 11:53:21.928312: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-11 11:53:22.173724: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-09-11 11:53:22.173768: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-09-11 11:53:22.219034: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-09-11 11:53:23.327622: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-09-11 11:53:23.327711: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-09-11 11:53:23.327721: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
X, y = spiral_data(1000, classes=2)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=.2,
    random_state=43
)


print(f'X_train{X_train.shape}')
print(f'X_test{X_test.shape}')
print(f'y_train{y_train.shape}')
print(f'y_test{y_test.shape}')
print(f'X{X.shape}')
print(f'y{y.shape}')
# Out:
# X_train(1600, 2)
# X_test(400, 2)
# y_train(1600,)
# y_test(400,)
# X(2000, 2)
# y(2000,)

# %%
model = keras.Sequential([
    keras.layers.Dense(10, activation='relu'),
    keras.layers.Dense(5, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid'),
])

model.compile(
    loss=keras.losses.BinaryCrossentropy(),
    optimizer=keras.optimizers.Adam(),
    metrics=['accuracy']
)

# membuat callbacks
lr_rate_schedular = keras.callbacks.LearningRateScheduler(lambda epoch: 1e-4 * 10**(epoch/20))

history = model.fit(
    X_train, 
    y_train, 
    epochs=100,
    callbacks=[lr_rate_schedular]
)
# Out:
# Epoch 1/100
# 2022-09-11 11:53:27.764198: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-09-11 11:53:27.764258: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-09-11 11:53:27.764301: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (anggads01): /proc/driver/nvidia/version does not exist
# 2022-09-11 11:53:27.765202: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 50/50 [==============================] - 1s 2ms/step - loss: 0.6898 - accuracy: 0.4913 - lr: 1.0000e-04
# Epoch 2/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6893 - accuracy: 0.4944 - lr: 1.1220e-04
# Epoch 3/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6887 - accuracy: 0.5063 - lr: 1.2589e-04
# Epoch 4/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6881 - accuracy: 0.5350 - lr: 1.4125e-04
# Epoch 5/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6875 - accuracy: 0.5738 - lr: 1.5849e-04
# Epoch 6/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6869 - accuracy: 0.5888 - lr: 1.7783e-04
# Epoch 7/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6863 - accuracy: 0.5756 - lr: 1.9953e-04
# Epoch 8/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6857 - accuracy: 0.5706 - lr: 2.2387e-04
# Epoch 9/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6852 - accuracy: 0.5694 - lr: 2.5119e-04
# Epoch 10/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6846 - accuracy: 0.5769 - lr: 2.8184e-04
# Epoch 11/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6840 - accuracy: 0.5950 - lr: 3.1623e-04
# Epoch 12/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6832 - accuracy: 0.6025 - lr: 3.5481e-04
# Epoch 13/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6824 - accuracy: 0.6150 - lr: 3.9811e-04
# Epoch 14/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6815 - accuracy: 0.6162 - lr: 4.4668e-04
# Epoch 15/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6805 - accuracy: 0.6162 - lr: 5.0119e-04
# Epoch 16/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6796 - accuracy: 0.6150 - lr: 5.6234e-04
# Epoch 17/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6785 - accuracy: 0.6144 - lr: 6.3096e-04
# Epoch 18/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6775 - accuracy: 0.6156 - lr: 7.0795e-04
# Epoch 19/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6762 - accuracy: 0.6175 - lr: 7.9433e-04
# Epoch 20/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6749 - accuracy: 0.6237 - lr: 8.9125e-04
# Epoch 21/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6736 - accuracy: 0.6206 - lr: 0.0010
# Epoch 22/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6726 - accuracy: 0.6281 - lr: 0.0011
# Epoch 23/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6711 - accuracy: 0.6319 - lr: 0.0013
# Epoch 24/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6700 - accuracy: 0.6325 - lr: 0.0014
# Epoch 25/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6685 - accuracy: 0.6294 - lr: 0.0016
# Epoch 26/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6669 - accuracy: 0.6338 - lr: 0.0018
# Epoch 27/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6646 - accuracy: 0.6356 - lr: 0.0020
# Epoch 28/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6622 - accuracy: 0.6350 - lr: 0.0022
# Epoch 29/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6594 - accuracy: 0.6313 - lr: 0.0025
# Epoch 30/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6548 - accuracy: 0.6344 - lr: 0.0028
# Epoch 31/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6507 - accuracy: 0.6313 - lr: 0.0032
# Epoch 32/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6443 - accuracy: 0.6313 - lr: 0.0035
# Epoch 33/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6350 - accuracy: 0.6369 - lr: 0.0040
# Epoch 34/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6237 - accuracy: 0.6438 - lr: 0.0045
# Epoch 35/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6109 - accuracy: 0.6400 - lr: 0.0050
# Epoch 36/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5997 - accuracy: 0.6550 - lr: 0.0056
# Epoch 37/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5859 - accuracy: 0.6675 - lr: 0.0063
# Epoch 38/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5667 - accuracy: 0.6787 - lr: 0.0071
# Epoch 39/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5439 - accuracy: 0.7194 - lr: 0.0079
# Epoch 40/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5036 - accuracy: 0.7725 - lr: 0.0089
# Epoch 41/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4624 - accuracy: 0.7956 - lr: 0.0100
# Epoch 42/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4177 - accuracy: 0.8250 - lr: 0.0112
# Epoch 43/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3736 - accuracy: 0.8525 - lr: 0.0126
# Epoch 44/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3503 - accuracy: 0.8506 - lr: 0.0141
# Epoch 45/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3307 - accuracy: 0.8737 - lr: 0.0158
# Epoch 46/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3263 - accuracy: 0.8737 - lr: 0.0178
# Epoch 47/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2908 - accuracy: 0.8925 - lr: 0.0200
# Epoch 48/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.2830 - accuracy: 0.8850 - lr: 0.0224
# Epoch 49/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.2694 - accuracy: 0.9000 - lr: 0.0251
# Epoch 50/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2681 - accuracy: 0.8988 - lr: 0.0282
# Epoch 51/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.2586 - accuracy: 0.9050 - lr: 0.0316
# Epoch 52/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.2947 - accuracy: 0.8931 - lr: 0.0355
# Epoch 53/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.2797 - accuracy: 0.8900 - lr: 0.0398
# Epoch 54/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.2906 - accuracy: 0.8875 - lr: 0.0447
# Epoch 55/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.2690 - accuracy: 0.8956 - lr: 0.0501
# Epoch 56/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2765 - accuracy: 0.8963 - lr: 0.0562
# Epoch 57/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.2964 - accuracy: 0.8819 - lr: 0.0631
# Epoch 58/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.2589 - accuracy: 0.9025 - lr: 0.0708
# Epoch 59/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.2706 - accuracy: 0.8900 - lr: 0.0794
# Epoch 60/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4063 - accuracy: 0.8525 - lr: 0.0891
# Epoch 61/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2859 - accuracy: 0.8988 - lr: 0.1000
# Epoch 62/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3107 - accuracy: 0.8906 - lr: 0.1122
# Epoch 63/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.2828 - accuracy: 0.8919 - lr: 0.1259
# Epoch 64/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2662 - accuracy: 0.9087 - lr: 0.1413
# Epoch 65/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.2902 - accuracy: 0.8925 - lr: 0.1585
# Epoch 66/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3261 - accuracy: 0.8869 - lr: 0.1778
# Epoch 67/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3863 - accuracy: 0.8675 - lr: 0.1995
# Epoch 68/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3689 - accuracy: 0.8612 - lr: 0.2239
# Epoch 69/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3169 - accuracy: 0.8906 - lr: 0.2512
# Epoch 70/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3664 - accuracy: 0.8500 - lr: 0.2818
# Epoch 71/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4994 - accuracy: 0.7894 - lr: 0.3162
# Epoch 72/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4290 - accuracy: 0.8050 - lr: 0.3548
# Epoch 73/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4370 - accuracy: 0.7969 - lr: 0.3981
# Epoch 74/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4744 - accuracy: 0.7569 - lr: 0.4467
# Epoch 75/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4670 - accuracy: 0.7719 - lr: 0.5012
# Epoch 76/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5478 - accuracy: 0.6525 - lr: 0.5623
# Epoch 77/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6185 - accuracy: 0.5844 - lr: 0.6310
# Epoch 78/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6148 - accuracy: 0.5950 - lr: 0.7079
# Epoch 79/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6373 - accuracy: 0.5844 - lr: 0.7943
# Epoch 80/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6512 - accuracy: 0.5819 - lr: 0.8913
# Epoch 81/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6322 - accuracy: 0.5925 - lr: 1.0000
# Epoch 82/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6230 - accuracy: 0.5838 - lr: 1.1220
# Epoch 83/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6877 - accuracy: 0.5594 - lr: 1.2589
# Epoch 84/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6316 - accuracy: 0.5663 - lr: 1.4125
# Epoch 85/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6539 - accuracy: 0.5719 - lr: 1.5849
# Epoch 86/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7058 - accuracy: 0.5150 - lr: 1.7783
# Epoch 87/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7213 - accuracy: 0.4969 - lr: 1.9953
# Epoch 88/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6853 - accuracy: 0.5337 - lr: 2.2387
# Epoch 89/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7339 - accuracy: 0.5144 - lr: 2.5119
# Epoch 90/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7502 - accuracy: 0.5013 - lr: 2.8184
# Epoch 91/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7813 - accuracy: 0.4800 - lr: 3.1623
# Epoch 92/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7365 - accuracy: 0.4988 - lr: 3.5481
# Epoch 93/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7383 - accuracy: 0.5025 - lr: 3.9811
# Epoch 94/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7358 - accuracy: 0.5138 - lr: 4.4668
# Epoch 95/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7225 - accuracy: 0.5113 - lr: 5.0119
# Epoch 96/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7528 - accuracy: 0.4875 - lr: 5.6234
# Epoch 97/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8279 - accuracy: 0.5025 - lr: 6.3096
# Epoch 98/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8062 - accuracy: 0.5025 - lr: 7.0795
# Epoch 99/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.8303 - accuracy: 0.4800 - lr: 7.9433
# Epoch 100/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.8703 - accuracy: 0.5088 - lr: 8.9125

# %%
# Tuning lr ideally

lrs =  1e-4 * (10**(tf.range(100) / 20))
loss = np.array(history.history['loss'])

history_lr = pd.DataFrame(np.c_[lrs, np.array(history.history['loss'])])
x_lr, y_loss = history_lr.iloc[np.argmin(loss), :] 

plt.semilogx(lrs, loss)
plt.xlabel('Learning rate')
plt.ylabel('Loss')
plt.title('Learning rate vs. Loss')

plt.annotate(
    f"loss: {round(y_loss, 2)}\n lr: {round(x_lr, 3)}", 
    xy=(x_lr, y_loss), 
    xytext=(y_loss, y_loss), 
    arrowprops=dict(arrowstyle="->", 
    color="green", 
    lw=2,
   )
)

plt.show()

# %%
model = keras.Sequential([
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid'),
])

model.compile(
    loss=keras.losses.BinaryCrossentropy(),
    optimizer=keras.optimizers.Adam(learning_rate=0.022),
    metrics=['accuracy']
)


history = model.fit(
    X_train, 
    y_train, 
    epochs=100,
)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 1s 4ms/step - loss: 0.6782 - accuracy: 0.5819
# Epoch 2/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6554 - accuracy: 0.6025
# Epoch 3/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5915 - accuracy: 0.6187
# Epoch 4/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5303 - accuracy: 0.6975
# Epoch 5/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4615 - accuracy: 0.7419
# Epoch 6/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4224 - accuracy: 0.7606
# Epoch 7/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3797 - accuracy: 0.7894
# Epoch 8/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4006 - accuracy: 0.7775
# Epoch 9/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3901 - accuracy: 0.7850
# Epoch 10/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3375 - accuracy: 0.8081
# Epoch 11/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2968 - accuracy: 0.8313
# Epoch 12/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2635 - accuracy: 0.8756
# Epoch 13/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2577 - accuracy: 0.8875
# Epoch 14/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1955 - accuracy: 0.9369
# Epoch 15/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1746 - accuracy: 0.9450
# Epoch 16/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1781 - accuracy: 0.9469
# Epoch 17/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1614 - accuracy: 0.9556
# Epoch 18/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1381 - accuracy: 0.9644
# Epoch 19/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1156 - accuracy: 0.9625
# Epoch 20/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1240 - accuracy: 0.9650
# Epoch 21/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1323 - accuracy: 0.9619
# Epoch 22/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0974 - accuracy: 0.9725
# Epoch 23/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0916 - accuracy: 0.9762
# Epoch 24/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0813 - accuracy: 0.9744
# Epoch 25/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0752 - accuracy: 0.9812
# Epoch 26/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0900 - accuracy: 0.9725
# Epoch 27/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0792 - accuracy: 0.9719
# Epoch 28/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0948 - accuracy: 0.9712
# Epoch 29/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1322 - accuracy: 0.9613
# Epoch 30/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0929 - accuracy: 0.9688
# Epoch 31/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0774 - accuracy: 0.9756
# Epoch 32/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0673 - accuracy: 0.9756
# Epoch 33/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0965 - accuracy: 0.9725
# Epoch 34/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0958 - accuracy: 0.9712
# Epoch 35/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0742 - accuracy: 0.9762
# Epoch 36/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0812 - accuracy: 0.9694
# Epoch 37/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0744 - accuracy: 0.9737
# Epoch 38/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0658 - accuracy: 0.9787
# Epoch 39/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0685 - accuracy: 0.9737
# Epoch 40/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0754 - accuracy: 0.9819
# Epoch 41/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0696 - accuracy: 0.9756
# Epoch 42/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0696 - accuracy: 0.9756
# Epoch 43/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0583 - accuracy: 0.9831
# Epoch 44/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0955 - accuracy: 0.9681
# Epoch 45/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1047 - accuracy: 0.9700
# Epoch 46/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0562 - accuracy: 0.9812
# Epoch 47/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0824 - accuracy: 0.9712
# Epoch 48/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1175 - accuracy: 0.9756
# Epoch 49/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1146 - accuracy: 0.9669
# Epoch 50/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0903 - accuracy: 0.9731
# Epoch 51/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0632 - accuracy: 0.9794
# Epoch 52/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0669 - accuracy: 0.9756
# Epoch 53/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0538 - accuracy: 0.9825
# Epoch 54/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0919 - accuracy: 0.9688
# Epoch 55/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0973 - accuracy: 0.9681
# Epoch 56/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0457 - accuracy: 0.9875
# Epoch 57/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0542 - accuracy: 0.9806
# Epoch 58/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0824 - accuracy: 0.9756
# Epoch 59/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0634 - accuracy: 0.9806
# Epoch 60/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0631 - accuracy: 0.9787
# Epoch 61/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0580 - accuracy: 0.9825
# Epoch 62/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0525 - accuracy: 0.9800
# Epoch 63/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0540 - accuracy: 0.9800
# Epoch 64/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0585 - accuracy: 0.9800
# Epoch 65/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0989 - accuracy: 0.9706
# Epoch 66/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0819 - accuracy: 0.9775
# Epoch 67/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1153 - accuracy: 0.9650
# Epoch 68/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0583 - accuracy: 0.9769
# Epoch 69/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0726 - accuracy: 0.9781
# Epoch 70/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0616 - accuracy: 0.9806
# Epoch 71/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0695 - accuracy: 0.9781
# Epoch 72/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0701 - accuracy: 0.9787
# Epoch 73/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0681 - accuracy: 0.9812
# Epoch 74/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0542 - accuracy: 0.9819
# Epoch 75/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0634 - accuracy: 0.9781
# Epoch 76/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0691 - accuracy: 0.9787
# Epoch 77/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0880 - accuracy: 0.9744
# Epoch 78/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0921 - accuracy: 0.9756
# Epoch 79/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0628 - accuracy: 0.9819
# Epoch 80/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0650 - accuracy: 0.9781
# Epoch 81/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1129 - accuracy: 0.9706
# Epoch 82/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0888 - accuracy: 0.9731
# Epoch 83/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0846 - accuracy: 0.9725
# Epoch 84/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0746 - accuracy: 0.9737
# Epoch 85/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0864 - accuracy: 0.9700
# Epoch 86/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0634 - accuracy: 0.9800
# Epoch 87/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0593 - accuracy: 0.9819
# Epoch 88/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0481 - accuracy: 0.9856
# Epoch 89/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0545 - accuracy: 0.9806
# Epoch 90/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0580 - accuracy: 0.9787
# Epoch 91/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0608 - accuracy: 0.9775
# Epoch 92/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0613 - accuracy: 0.9812
# Epoch 93/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0482 - accuracy: 0.9812
# Epoch 94/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0493 - accuracy: 0.9819
# Epoch 95/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0736 - accuracy: 0.9787
# Epoch 96/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0466 - accuracy: 0.9831
# Epoch 97/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0549 - accuracy: 0.9806
# Epoch 98/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0704 - accuracy: 0.9787
# Epoch 99/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1021 - accuracy: 0.9669
# Epoch 100/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0942 - accuracy: 0.9762

# %%
model.evaluate(X_test, y_test)
# Out:
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0458 - accuracy: 0.9875
# [0.04580816254019737, 0.987500011920929]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

y_pred = np.round(model.predict(X_test).ravel())
matrix = confusion_matrix(y_test, y_pred)
matrix
# Out:
# 13/13 [==============================] - 0s 1ms/step
# array([[181,   5],
#        [  0, 214]])

# %%
def plot_confusion_matrix(
    matrix,
    class_labels=False,
    figsize=(16, 8), 
    y_ticks_rot=0, 
    x_ticks_rot=0, 
    fs_title=20, 
    fs_label=14, 
    pallete=plt.cm.magma
):
    norm = matrix.sum(axis=1, keepdims=True).ravel()
    cm = np.array(
        [
            f"{val}\n({val / (norm[idx if idx < len(norm) else len(norm) - 1])*100:.2f}%)"
            for idx, val 
            in enumerate(matrix.ravel())
        ]
        ).reshape(matrix.shape)

    plt.figure(figsize=figsize)

    if class_labels:
        values_labels = [val for val in class_labels.values()]
    else:
        values_labels = "auto"

    sns.heatmap(
        matrix, 
        annot=cm, 
        cmap=pallete, 
        fmt='s', 
        xticklabels=values_labels, 
        yticklabels=values_labels
    )
    plt.xticks(rotation=x_ticks_rot)
    plt.yticks(rotation=y_ticks_rot)
    plt.ylabel('True Label', fontsize=fs_label)
    plt.xlabel('Predicted Label', fontsize=fs_label)
    plt.title('confusion matrix', fontsize=fs_title)
    plt.show()

# %%
plot_confusion_matrix(matrix, pallete=plt.cm.magma)

# %%
df = pd.DataFrame(np.append(X, y.reshape(-1,1), axis=1), columns=['X1', 'X2', 'y'])

plt.figure(figsize=(12, 8))
sns.scatterplot(data=df, x='X1', y='X2', hue='y', alpha=.75)
plt.grid(alpha=.6)
plt.show()

# %%
# Jika menggunakan label
labels = {
    0: 'biru',
    1: 'jingga'
}

plot_confusion_matrix(matrix, pallete=plt.cm.magma, class_labels=labels)

# %%
y_pred = np.round(model.predict(X_test))
df_compare = pd.DataFrame(np.append(y_test.reshape(-1,1), y_pred, axis=1), columns=['y test', 'y pred'])

grouping = df_compare.melt().value_counts().sort_index()
display(grouping)
grouping.unstack('variable').plot.bar()
# Out:
# 13/13 [==============================] - 0s 2ms/step
# variable  value
# y pred    0.0      188
#           1.0      212
# y test    0.0      186
#           1.0      214
# dtype: int64
# <AxesSubplot:xlabel='value'>
