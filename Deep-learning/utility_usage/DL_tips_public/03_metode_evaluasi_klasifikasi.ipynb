# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from nnfs.datasets import spiral_data
# Out:
# 2022-09-11 11:46:09.376460: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-11 11:46:09.805603: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-09-11 11:46:09.805638: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-09-11 11:46:09.873772: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-09-11 11:46:11.090625: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-09-11 11:46:11.090750: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-09-11 11:46:11.090761: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
X, y = spiral_data(1000, classes=2)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=.2,
    random_state=43
)


print(f'X_train{X_train.shape}')
print(f'X_test{X_test.shape}')
print(f'y_train{y_train.shape}')
print(f'y_test{y_test.shape}')
print(f'X{X.shape}')
print(f'y{y.shape}')
# Out:
# X_train(1600, 2)
# X_test(400, 2)
# y_train(1600,)
# y_test(400,)
# X(2000, 2)
# y(2000,)

# %%
model = keras.Sequential([
    keras.layers.Dense(10, activation='relu'),
    keras.layers.Dense(5, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid'),
])

model.compile(
    loss=keras.losses.BinaryCrossentropy(),
    optimizer=keras.optimizers.Adam(),
    metrics=['accuracy']
)

# membuat callbacks
lr_rate_schedular = keras.callbacks.LearningRateScheduler(lambda epoch: 1e-4 * 10**(epoch/20))

history = model.fit(
    X_train, 
    y_train, 
    epochs=100,
    callbacks=[lr_rate_schedular]
)
# Out:
# Epoch 1/100
# 2022-09-11 11:46:13.271029: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-09-11 11:46:13.271296: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-09-11 11:46:13.271338: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (anggads01): /proc/driver/nvidia/version does not exist
# 2022-09-11 11:46:13.272598: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7086 - accuracy: 0.5150 - lr: 1.0000e-04
# Epoch 2/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7063 - accuracy: 0.5312 - lr: 1.1220e-04
# Epoch 3/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7041 - accuracy: 0.5406 - lr: 1.2589e-04
# Epoch 4/100
# 50/50 [==============================] - 0s 958us/step - loss: 0.7019 - accuracy: 0.5431 - lr: 1.4125e-04
# Epoch 5/100
# 50/50 [==============================] - 0s 957us/step - loss: 0.6999 - accuracy: 0.5394 - lr: 1.5849e-04
# Epoch 6/100
# 50/50 [==============================] - 0s 927us/step - loss: 0.6980 - accuracy: 0.5344 - lr: 1.7783e-04
# Epoch 7/100
# 50/50 [==============================] - 0s 912us/step - loss: 0.6961 - accuracy: 0.5319 - lr: 1.9953e-04
# Epoch 8/100
# 50/50 [==============================] - 0s 934us/step - loss: 0.6943 - accuracy: 0.5306 - lr: 2.2387e-04
# Epoch 9/100
# 50/50 [==============================] - 0s 791us/step - loss: 0.6925 - accuracy: 0.5394 - lr: 2.5119e-04
# Epoch 10/100
# 50/50 [==============================] - 0s 917us/step - loss: 0.6907 - accuracy: 0.5437 - lr: 2.8184e-04
# Epoch 11/100
# 50/50 [==============================] - 0s 955us/step - loss: 0.6889 - accuracy: 0.5512 - lr: 3.1623e-04
# Epoch 12/100
# 50/50 [==============================] - 0s 880us/step - loss: 0.6872 - accuracy: 0.5562 - lr: 3.5481e-04
# Epoch 13/100
# 50/50 [==============================] - 0s 935us/step - loss: 0.6852 - accuracy: 0.5769 - lr: 3.9811e-04
# Epoch 14/100
# 50/50 [==============================] - 0s 980us/step - loss: 0.6835 - accuracy: 0.5875 - lr: 4.4668e-04
# Epoch 15/100
# 50/50 [==============================] - 0s 966us/step - loss: 0.6819 - accuracy: 0.5675 - lr: 5.0119e-04
# Epoch 16/100
# 50/50 [==============================] - 0s 930us/step - loss: 0.6802 - accuracy: 0.5575 - lr: 5.6234e-04
# Epoch 17/100
# 50/50 [==============================] - 0s 849us/step - loss: 0.6789 - accuracy: 0.5831 - lr: 6.3096e-04
# Epoch 18/100
# 50/50 [==============================] - 0s 956us/step - loss: 0.6773 - accuracy: 0.5956 - lr: 7.0795e-04
# Epoch 19/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6761 - accuracy: 0
100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6430 - accuracy: 0.5713 - lr: 0.4467
# Epoch 75/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6269 - accuracy: 0.5900 - lr: 0.5012
# Epoch 76/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6368 - accuracy: 0.5838 - lr: 0.5623
# Epoch 77/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7098 - accuracy: 0.5175 - lr: 0.6310
# Epoch 78/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6998 - accuracy: 0.4975 - lr: 0.7079
# Epoch 79/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7029 - accuracy: 0.4812 - lr: 0.7943
# Epoch 80/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7059 - accuracy: 0.5113 - lr: 0.8913
# Epoch 81/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7082 - accuracy: 0.5288 - lr: 1.0000
# Epoch 82/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7070 - accuracy: 0.5050 - lr: 1.1220
# Epoch 83/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7127 - accuracy: 0.4988 - lr: 1.2589
# Epoch 84/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7200 - accuracy: 0.5175 - lr: 1.4125
# Epoch 85/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7136 - accuracy: 0.4837 - lr: 1.5849
# Epoch 86/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7569 - accuracy: 0.4975 - lr: 1.7783
# Epoch 87/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7185 - accuracy: 0.4913 - lr: 1.9953
# Epoch 88/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7132 - accuracy: 0.5013 - lr: 2.2387
# Epoch 89/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7645 - accuracy: 0.5050 - lr: 2.5119
# Epoch 90/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7781 - accuracy: 0.4812 - lr: 2.8184
# Epoch 91/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7282 - accuracy: 0.5063 - lr: 3.1623
# Epoch 92/100
# 50/50 [==============================] - 0s 913us/step - loss: 0.8041 - accuracy: 0.5100 - lr: 3.5481
# Epoch 93/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7966 - accuracy: 0.5075 - lr: 3.9811
# Epoch 94/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.9410 - accuracy: 0.5163 - lr: 4.4668
# Epoch 95/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.8282 - accuracy: 0.4988 - lr: 5.0119
# Epoch 96/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7471 - accuracy: 0.5163 - lr: 5.6234
# Epoch 97/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7683 - accuracy: 0.5038 - lr: 6.3096
# Epoch 98/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.8584 - accuracy: 0.5200 - lr: 7.0795
# Epoch 99/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.8231 - accuracy: 0.5050 - lr: 7.9433
# Epoch 100/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7711 - accuracy: 0.5063 - lr: 8.9125

# %%
# Tuning lr ideally

lrs =  1e-4 * (10**(tf.range(100) / 20))
loss = np.array(history.history['loss'])

history_lr = pd.DataFrame(np.c_[lrs, np.array(history.history['loss'])])
x_lr, y_loss = history_lr.iloc[np.argmin(loss), :] 

plt.semilogx(lrs, loss)
plt.xlabel('Learning rate')
plt.ylabel('Loss')
plt.title('Learning rate vs. Loss')

plt.annotate(
    f"loss: {round(y_loss, 2)}\n lr: {round(x_lr, 3)}", 
    xy=(x_lr, y_loss), 
    xytext=(y_loss, y_loss), 
    arrowprops=dict(arrowstyle="->", 
    color="green", 
    lw=2,
   )
)

plt.show()

# %%
model = keras.Sequential([
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid'),
])

model.compile(
    loss=keras.losses.BinaryCrossentropy(),
    optimizer=keras.optimizers.Adam(learning_rate=0.02),
    metrics=['accuracy']
)


history = model.fit(
    X_train, 
    y_train, 
    epochs=100,
)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 1s 2ms/step - loss: 0.6743 - accuracy: 0.5838
# Epoch 2/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6556 - accuracy: 0.5581
# Epoch 3/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5934 - accuracy: 0.6431
# Epoch 4/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5112 - accuracy: 0.7194
# Epoch 5/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4432 - accuracy: 0.8106
# Epoch 6/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3523 - accuracy: 0.8338
# Epoch 7/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2878 - accuracy: 0.8731
# Epoch 8/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2490 - accuracy: 0.8906
# Epoch 9/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2463 - accuracy: 0.8863
# Epoch 10/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2131 - accuracy: 0.9050
# Epoch 11/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1839 - accuracy: 0.9187
# Epoch 12/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1558 - accuracy: 0.9388
# Epoch 13/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1573 - accuracy: 0.9350
# Epoch 14/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1563 - accuracy: 0.9375
# Epoch 15/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1270 - accuracy: 0.9506
# Epoch 16/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1078 - accuracy: 0.9494
# Epoch 17/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0952 - accuracy: 0.9644
# Epoch 18/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1001 - accuracy: 0.9650
# Epoch 19/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1487 - accuracy: 0.9394
# Epoch 20/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1046 - accuracy: 0.9613
# Epoch 21/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0729 - accuracy: 0.9737
# Epoch 22/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0937 - accuracy: 0.9569
# Epoch 23/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1304 - accuracy: 0.9550
# Epoch 24/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0776 - accuracy: 0.9744
# Epoch 25/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0924 - accuracy: 0.9675
# Epoch 26/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0708 - accuracy: 0.9781
# Epoch 27/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0718 - accuracy: 0.9769
# Epoch 28/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0735 - accuracy: 0.9725
# Epoch 29/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0696 - accuracy: 0.9781
# Epoch 30/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0836 - accuracy: 0.9731
# Epoch 31/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0634 - accuracy: 0.9762
# Epoch 32/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0673 - accuracy: 0.9762
# Epoch 33/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1156 - accuracy: 0.9563
# Epoch 34/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0636 - accuracy: 0.9737
# Epoch 35/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0758 - accuracy: 0.9731
# Epoch 36/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0531 - accuracy: 0.9812
# Epoch 37/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9719
# Epoch 38/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0772 - accuracy: 0.9762
# Epoch 39/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0715 - accuracy: 0.9731
# Epoch 40/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0496 - accuracy: 0.9812
# Epoch 41/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0751 - accuracy: 0.9712
# Epoch 42/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0506 - accuracy: 0.9844
# Epoch 43/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0450 - accuracy: 0.9819
# Epoch 44/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0517 - accuracy: 0.9794
# Epoch 45/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0407 - accuracy: 0.9856
# Epoch 46/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0554 - accuracy: 0.9825
# Epoch 47/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0539 - accuracy: 0.9825
# Epoch 48/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0787 - accuracy: 0.9694
# Epoch 49/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0808 - accuracy: 0.9675
# Epoch 50/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0644 - accuracy: 0.9769
# Epoch 51/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0700 - accuracy: 0.9775
# Epoch 52/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0400 - accuracy: 0.9869
# Epoch 53/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0549 - accuracy: 0.9806
# Epoch 54/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0596 - accuracy: 0.9787
# Epoch 55/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0459 - accuracy: 0.9806
# Epoch 56/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0408 - accuracy: 0.9856
# Epoch 57/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0465 - accuracy: 0.9812
# Epoch 58/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0423 - accuracy: 0.9837
# Epoch 59/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0456 - accuracy: 0.9819
# Epoch 60/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0367 - accuracy: 0.9856
# Epoch 61/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0467 - accuracy: 0.9787
# Epoch 62/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0467 - accuracy: 0.9800
# Epoch 63/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0422 - accuracy: 0.9856
# Epoch 64/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0461 - accuracy: 0.9825
# Epoch 65/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0380 - accuracy: 0.9831
# Epoch 66/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0411 - accuracy: 0.9825
# Epoch 67/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0394 - accuracy: 0.9850
# Epoch 68/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0424 - accuracy: 0.9831
# Epoch 69/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0492 - accuracy: 0.9837
# Epoch 70/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0760 - accuracy: 0.9800
# Epoch 71/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0447 - accuracy: 0.9825
# Epoch 72/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0405 - accuracy: 0.9837
# Epoch 73/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0368 - accuracy: 0.9819
# Epoch 74/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0421 - accuracy: 0.9837
# Epoch 75/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0683 - accuracy: 0.9744
# Epoch 76/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0351 - accuracy: 0.9856
# Epoch 77/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0498 - accuracy: 0.9756
# Epoch 78/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0462 - accuracy: 0.9812
# Epoch 79/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0513 - accuracy: 0.9787
# Epoch 80/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0653 - accuracy: 0.9787
# Epoch 81/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0790 - accuracy: 0.9712
# Epoch 82/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0942 - accuracy: 0.9737
# Epoch 83/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0738 - accuracy: 0.9756
# Epoch 84/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0532 - accuracy: 0.9781
# Epoch 85/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0350 - accuracy: 0.9875
# Epoch 86/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0455 - accuracy: 0.9825
# Epoch 87/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0582 - accuracy: 0.9794
# Epoch 88/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0564 - accuracy: 0.9794
# Epoch 89/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0431 - accuracy: 0.9831
# Epoch 90/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0287 - accuracy: 0.9894
# Epoch 91/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0323 - accuracy: 0.9881
# Epoch 92/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0350 - accuracy: 0.9869
# Epoch 93/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0404 - accuracy: 0.9862
# Epoch 94/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0383 - accuracy: 0.9869
# Epoch 95/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0554 - accuracy: 0.9794
# Epoch 96/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0390 - accuracy: 0.9819
# Epoch 97/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0373 - accuracy: 0.9831
# Epoch 98/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0352 - accuracy: 0.9875
# Epoch 99/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0920 - accuracy: 0.9725
# Epoch 100/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0697 - accuracy: 0.9725

# %%
model.evaluate(X_test, y_test)
# Out:
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2708 - accuracy: 0.9900
# [0.27082398533821106, 0.9900000095367432]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

y_pred = np.round(model.predict(X_test).ravel())
matrix = confusion_matrix(y_test, y_pred)
matrix
# Out:
# 13/13 [==============================] - 0s 2ms/step
# array([[185,   1],
#        [  3, 211]])

# %%
def plot_confusion_matrix(
    matrix,
    class_labels=False,
    figsize=(16, 8), 
    y_ticks_rot=0, 
    x_ticks_rot=0, 
    fs_title=20, 
    fs_label=14, 
    pallete=plt.cm.magma
):
    norm = matrix.sum(axis=1, keepdims=True).ravel()
    cm = np.array(
        [
            f"{val}\n({val / (norm[idx if idx < len(norm) else len(norm) - 1])*100:.2f}%)"
            for idx, val 
            in enumerate(matrix.ravel())
        ]
        ).reshape(matrix.shape)

    plt.figure(figsize=figsize)

    if class_labels:
        values_labels = [val for val in class_labels.values()]
    else:
        values_labels = "auto"

    sns.heatmap(
        matrix, 
        annot=cm, 
        cmap=pallete, 
        fmt='s', 
        xticklabels=values_labels, 
        yticklabels=values_labels
    )
    plt.xticks(rotation=x_ticks_rot)
    plt.yticks(rotation=y_ticks_rot)
    plt.ylabel('True Label', fontsize=fs_label)
    plt.xlabel('Predicted Label', fontsize=fs_label)
    plt.title('confusion matrix', fontsize=fs_title)
    plt.show()

# %%
plot_confusion_matrix(matrix, pallete=plt.cm.magma)

# %%
df = pd.DataFrame(np.append(X, y.reshape(-1,1), axis=1), columns=['X1', 'X2', 'y'])

plt.figure(figsize=(12, 8))
sns.scatterplot(data=df, x='X1', y='X2', hue='y', alpha=.75)
plt.grid(alpha=.6)
plt.show()

# %%
# Jika menggunakan label
labels = {
    0: 'jingga',
    1: 'biru'
}

plot_confusion_matrix(matrix, pallete=plt.cm.magma, class_labels=labels)

# %%
y_pred = np.round(model.predict(X_test))
df_compare = pd.DataFrame(np.append(y_test.reshape(-1,1), y_pred, axis=1), columns=['y test', 'y pred'])

grouping = df_compare.melt().value_counts().sort_index()
display(grouping)
grouping.unstack('variable').plot.bar()
# Out:
# 13/13 [==============================] - 0s 2ms/step
# variable  value
# y pred    0.0      188
#           1.0      212
# y test    0.0      186
#           1.0      214
# dtype: int64
# <AxesSubplot:xlabel='value'>
