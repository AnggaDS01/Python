# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from nnfs.datasets import spiral_data
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
X, y = spiral_data(1000, classes=2)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=.2,
    random_state=43
)


print(f'X_train{X_train.shape}')
print(f'X_test{X_test.shape}')
print(f'y_train{y_train.shape}')
print(f'y_test{y_test.shape}')
print(f'X{X.shape}')
print(f'y{y.shape}')
# Out:
# X_train(1600, 2)
# X_test(400, 2)
# y_train(1600,)
# y_test(400,)
# X(2000, 2)
# y(2000,)

# %%
model = keras.Sequential([
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid'),
])

model.compile(
    loss=keras.losses.BinaryCrossentropy(),
    optimizer=keras.optimizers.Adam(),
    metrics=['accuracy']
)

# membuat callbacks
lr_rate_schedular = keras.callbacks.LearningRateScheduler(lambda epoch: 1e-4 * 10**(epoch/20))

history = model.fit(
    X_train, 
    y_train, 
    epochs=50,
    callbacks=[lr_rate_schedular]
)
# Out:
# Epoch 1/50
# 2022-09-11 07:48:51.914873: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-09-11 07:48:51.914922: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-09-11 07:48:51.914954: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (anggads01): /proc/driver/nvidia/version does not exist
# 2022-09-11 07:48:51.915337: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 50/50 [==============================] - 1s 2ms/step - loss: 0.6913 - accuracy: 0.4919 - lr: 1.0000e-04
# Epoch 2/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6883 - accuracy: 0.5138 - lr: 1.1220e-04
# Epoch 3/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6856 - accuracy: 0.5706 - lr: 1.2589e-04
# Epoch 4/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6834 - accuracy: 0.5506 - lr: 1.4125e-04
# Epoch 5/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6813 - accuracy: 0.5975 - lr: 1.5849e-04
# Epoch 6/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6795 - accuracy: 0.6156 - lr: 1.7783e-04
# Epoch 7/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6776 - accuracy: 0.6181 - lr: 1.9953e-04
# Epoch 8/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6756 - accuracy: 0.6231 - lr: 2.2387e-04
# Epoch 9/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6735 - accuracy: 0.6231 - lr: 2.5119e-04
# Epoch 10/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6716 - accuracy: 0.6275 - lr: 2.8184e-04
# Epoch 11/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6695 - accuracy: 0.6375 - lr: 3.1623e-04
# Epoch 12/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6676 - accuracy: 0.6325 - lr: 3.5481e-04
# Epoch 13/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6655 - accuracy: 0.6331 - lr: 3.9811e-04
# Epoch 14/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6638 - accuracy: 0.6438 - lr: 4.4668e-04
# Epoch 15/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6623 - accuracy: 0.6400 - lr: 5.0119e-04
# Epoch 16/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6612 - accuracy: 0.6413 - lr: 5.6234e-04
# Epoch 17/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6605 - accuracy: 0.6419 - lr: 6.3096e-04
# Epoch 18/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6597 - accuracy: 0.6400 - lr: 7.0795e-04
# Epoch 19/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6592 - accuracy: 0.6381 - lr: 7.9433e-04
# Epoch 20/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6583 - accuracy: 0.6394 - lr: 8.9125e-04
# Epoch 21/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6564 - accuracy: 0.6319 - lr: 0.0010
# Epoch 22/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6538 - accuracy: 0.6394 - lr: 0.0011
# Epoch 23/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6500 - accuracy: 0.6394 - lr: 0.0013
# Epoch 24/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6447 - accuracy: 0.6369 - lr: 0.0014
# Epoch 25/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6358 - accuracy: 0.6394 - lr: 0.0016
# Epoch 26/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6214 - accuracy: 0.6475 - lr: 0.0018
# Epoch 27/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6001 - accuracy: 0.6431 - lr: 0.0020
# Epoch 28/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5767 - accuracy: 0.7063 - lr: 0.0022
# Epoch 29/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5484 - accuracy: 0.7406 - lr: 0.0025
# Epoch 30/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5245 - accuracy: 0.7594 - lr: 0.0028
# Epoch 31/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4936 - accuracy: 0.7825 - lr: 0.0032
# Epoch 32/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4698 - accuracy: 0.7794 - lr: 0.0035
# Epoch 33/50
# 50/50 [==============================] - 0s 998us/step - loss: 0.4312 - accuracy: 0.8031 - lr: 0.0040
# Epoch 34/50
# 50/50 [==============================] - 0s 946us/step - loss: 0.3910 - accuracy: 0.8369 - lr: 0.0045
# Epoch 35/50
# 50/50 [==============================] - 0s 987us/step - loss: 0.3379 - accuracy: 0.8775 - lr: 0.0050
# Epoch 36/50
# 50/50 [==============================] - 0s 980us/step - loss: 0.3004 - accuracy: 0.8825 - lr: 0.0056
# Epoch 37/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.2338 - accuracy: 0.9369 - lr: 0.0063
# Epoch 38/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1988 - accuracy: 0.9413 - lr: 0.0071
# Epoch 39/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1560 - accuracy: 0.9606 - lr: 0.0079
# Epoch 40/50
# 50/50 [==============================] - 0s 980us/step - loss: 0.1486 - accuracy: 0.9538 - lr: 0.0089
# Epoch 41/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1496 - accuracy: 0.9569 - lr: 0.0100
# Epoch 42/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1222 - accuracy: 0.9631 - lr: 0.0112
# Epoch 43/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1808 - accuracy: 0.9438 - lr: 0.0126
# Epoch 44/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1227 - accuracy: 0.9556 - lr: 0.0141
# Epoch 45/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1167 - accuracy: 0.9544 - lr: 0.0158
# Epoch 46/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.2048 - accuracy: 0.9287 - lr: 0.0178
# Epoch 47/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0998 - accuracy: 0.9669 - lr: 0.0200
# Epoch 48/50
# 50/50 [==============================] - 0s 969us/step - loss: 0.1279 - accuracy: 0.9594 - lr: 0.0224
# Epoch 49/50
# 50/50 [==============================] - 0s 972us/step - loss: 0.1852 - accuracy: 0.9300 - lr: 0.0251
# Epoch 50/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1709 - accuracy: 0.9337 - lr: 0.0282

# %%
pd.DataFrame(history.history).plot()
# Out:
# <AxesSubplot:>

# %%
# Tuning lr ideally

lrs =  1e-4 * (10**(tf.range(50) / 20))
loss = np.array(history.history['loss'])

history_lr = pd.DataFrame(np.c_[lrs, np.array(history.history['loss'])])
x_lr, y_loss = history_lr.iloc[np.argmin(loss), :] 

plt.semilogx(lrs, loss)
plt.xlabel('Learning rate')
plt.ylabel('Loss')
plt.title('Learning rate vs. Loss')

plt.annotate(
    f"loss: {round(y_loss, 2)}\n lr: {round(x_lr, 3)}", 
    xy=(x_lr, y_loss), 
    xytext=(y_loss, y_loss), 
    arrowprops=dict(arrowstyle="->", 
    color="green", 
    lw=2,
   )
)

plt.show()

# %% [markdown]
# ## Melatih dan mengevaluasi model dengan learning rate yang ideal

# %%
model_2 = keras.Sequential([
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid'),
])

model_2.compile(
    loss=keras.losses.BinaryCrossentropy(),
    optimizer=keras.optimizers.Adam(learning_rate=0.01),
    metrics=['accuracy']
)

history_2 = model_2.fit(
    X_train, 
    y_train, 
    epochs=20,
)
# Out:
# Epoch 1/20
# 50/50 [==============================] - 1s 2ms/step - loss: 0.6779 - accuracy: 0.5725
# Epoch 2/20
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6635 - accuracy: 0.6162
# Epoch 3/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6535 - accuracy: 0.6219
# Epoch 4/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6307 - accuracy: 0.6237
# Epoch 5/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5970 - accuracy: 0.6406
# Epoch 6/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5451 - accuracy: 0.7031
# Epoch 7/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4789 - accuracy: 0.7606
# Epoch 8/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3909 - accuracy: 0.8425
# Epoch 9/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2839 - accuracy: 0.9038
# Epoch 10/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.2254 - accuracy: 0.9250
# Epoch 11/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1617 - accuracy: 0.9525
# Epoch 12/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1451 - accuracy: 0.9581
# Epoch 13/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1301 - accuracy: 0.9581
# Epoch 14/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1283 - accuracy: 0.9581
# Epoch 15/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1069 - accuracy: 0.9644
# Epoch 16/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0888 - accuracy: 0.9750
# Epoch 17/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0982 - accuracy: 0.9669
# Epoch 18/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1049 - accuracy: 0.9613
# Epoch 19/20
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0895 - accuracy: 0.9650
# Epoch 20/20
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0794 - accuracy: 0.9712
