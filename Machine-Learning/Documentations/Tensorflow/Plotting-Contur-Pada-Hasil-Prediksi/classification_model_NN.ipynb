# %%
from nnfs.datasets import spiral_data
from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split
from tensorflow import keras
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import shutil
import os
sns.set()

# %%
# X, y = make_circles(10000, noise=.03, random_state=43)
X, y = spiral_data(samples=5000, classes=2)

# %%
X.shape, y.shape
# Out:
# ((10000, 2), (10000,))

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=.2,
    random_state=42
)

X_train.shape, y_train.shape
# Out:
# ((8000, 2), (8000,))

# %%
df = pd.DataFrame(np.append(X, y.reshape(-1, 1), axis=1), columns=['X1', 'X2', 'y'])
df
# Out:
#             X1        X2    y
# 0     0.000000  0.000000  0.0
# 1    -0.000087  0.000180  0.0
# 2    -0.000074  0.000393  0.0
# 3    -0.000155  0.000580  0.0
# 4     0.000339  0.000725  0.0
# ...        ...       ...  ...
# 9995  0.746675 -0.663985  1.0
# 9996  0.744151  0.667113  1.0
# 9997  0.854578  0.518552  1.0
# 9998  0.633681  0.773336  1.0
# 9999  0.997881 -0.065060  1.0
#
# [10000 rows x 3 columns]

# %%
pallete = {
  0: 'tab:red',
  1: 'tab:green',
  2: 'tab:blue'
}

plt.figure(figsize=(12, 8))
sns.scatterplot(data=df, x='X1', y='X2', hue='y', palette='magma', alpha=.75)
plt.show()

# %%
class StoreContent:
  def __init__(self, name_dir):
    self.name_dir = name_dir
    self.pwd = os.getcwd()

  def delete_dir(self):
    if os.path.isdir(self.name_dir):
      shutil.rmtree(self.name_dir)
    else:
      print('folder telah dihapus')

  def store_data(self, data, separate=False, second_dir={}):
    '''
    paramater data harus merupakan dictionary, misal data={nama_file:nilai_data}
    '''
    
    dir_name = os.path.join(self.pwd, self.name_dir)

    if separate:
      for folder_names, values in second_dir.items():
        if not os.path.isdir(f'{dir_name}/{folder_names}'):
          os.makedirs(f'{dir_name}/{folder_names}')
        
        np.save(f'{dir_name}/{folder_names}/epoch_{data}.npy', values)
    
    else:
      assert type(data) == dict, 'nilai data harus bertipe dictionary'
      if not os.path.isdir(self.name_dir):
        os.mkdir(dir_name)
      for filename, value in data.items():
        np.save(f'{dir_name}/{filename}.npy', value)


class PerformancePlotCallback(StoreContent, keras.callbacks.Callback):
    def __init__(self, name_dir, x, y):
      super().__init__(name_dir)
      self.x = x
      self.y = y

        
    def on_epoch_end(self, epoch, logs=None):
        x_min, x_max = self.x[:, 0].min() - 0.1, self.x[:, 0].max() + 0.1
        y_min, y_max = self.x[:, 1].min() - 0.1, self.x[:, 1].max() + 0.1
        xx, yy = np.meshgrid(
          np.linspace(x_min, x_max, 100),
          np.linspace(y_min, y_max, 100)
        )

        x_in = np.c_[xx.ravel(), yy.ravel()]
        
        y_pred = self.model.predict(x_in)

        if len(y_pred[0]) > 1:
          y_pred = np.argmax(y_pred, axis=1).reshape(xx.shape)
        else:
          y_pred = np.round(y_pred).reshape(xx.shape)
        
        self.store_data(
          epoch, 
          separate=True, 
          second_dir={
            'loss_history': logs['loss'], 
            'accuracy': logs['accuracy'], 
            'prediction_history': y_pred
          })
        
        # JIKA KASUS REGRESI
        '''
          # df = pd.DataFrame()
          # series = pd.Series(y_pred.ravel())
          # df[epoch] = series
          # df.to_csv(f'../datasets/training/epoch_{epoch}.csv')
        '''

def plot_decision_boundary(model, X, y):
    np.random.seed(43)
    x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
    y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
    xx, yy = np.meshgrid(
        np.linspace(x_min, x_max, 100),
        np.linspace(y_min, y_max, 100)
    )
    
    x_in = np.c_[xx.ravel(), yy.ravel()]
    y_pred = model.predict(x_in)

    if len(y_pred[0]) > 1:
      y_pred = np.argmax(y_pred, axis=1).reshape(xx.shape)
    else:
      y_pred = np.round(y_pred).reshape(xx.shape)

    plt.contourf(xx, yy, y_pred, cmap=plt.cm.RdYlBu, alpha=.8)
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.RdYlBu, edgecolors='white', linewidths=.05)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.show()


# 'Datasets_Classification'

# %%
create_container = StoreContent('data_source')
create_container.delete_dir()
create_container.store_data({
    'X':X, 
    'y':y, 
    'X_train':X_train, 
    'y_train':y_train,
    'X_test':X_test,
    'y_test':y_test
})

# %%
checkpoint = keras.callbacks.ModelCheckpoint("../models/spiral_data.h5", save_best_only=True)
performance = PerformancePlotCallback('history', x=X, y=y)

# performance.delete_dir()
model = keras.Sequential([
  keras.layers.Dense(32, activation='relu'),
  keras.layers.Dense(32, activation='relu'),
  keras.layers.Dense(1, activation='sigmoid')
])

model.compile(
  loss=keras.losses.BinaryCrossentropy(),
  optimizer=keras.optimizers.Adam(),
  metrics=['accuracy']
)

history = model.fit(
  X_train, 
  y_train, 
  epochs=60, 
  verbose=1,
  callbacks=[checkpoint, performance],
  # batch_size=32,
)
# Out:
# Epoch 1/60
# 249/250 [============================>.] - ETA: 0s - loss: 0.6726 - accuracy: 0.6037WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 676us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.6727 - accuracy: 0.6035
# Epoch 2/60
# 239/250 [===========================>..] - ETA: 0s - loss: 0.6619 - accuracy: 0.6207WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 1ms/step
# 250/250 [==============================] - 1s 4ms/step - loss: 0.6624 - accuracy: 0.6200
# Epoch 3/60
# 221/250 [=========================>....] - ETA: 0s - loss: 0.6600 - accuracy: 0.6179WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 899us/step
# 250/250 [==============================] - 1s 3ms/step - loss: 0.6593 - accuracy: 0.6210
# Epoch 4/60
# 245/250 [============================>.] - ETA: 0s - loss: 0.6539 - accuracy: 0.6228WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 986us/step
# 250/250 [==============================] - 1s 3ms/step - loss: 0.6530 - accuracy: 0.6240
# Epoch 5/60
# 214/250 [========================>.....] - ETA: 0s - loss: 0.6419 - accuracy: 0.6294WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 931us/step
# 250/250 [==============================] - 1s 3ms/step - loss: 0.6404 - accuracy: 0.6298
# Epoch 6/60
# 232/250 [==========================>...] - ETA: 0s - loss: 0.6160 - accuracy: 0.6366WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 678us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.6149 - accuracy: 0.6361
# Epoch 7/60
# 223/250 [=========================>....] - ETA: 0s - loss: 0.5763 - accuracy: 0.6627WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 605us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.5746 - accuracy: 0.6643
# Epoch 8/60
# 243/250 [============================>.] - ETA: 0s - loss: 0.5184 - accuracy: 0.7522WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 652us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.5175 - accuracy: 0.7544
# Epoch 9/60
# 230/250 [==========================>...] - ETA: 0s - loss: 0.4460 - accuracy: 0.8470WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 650us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4434 - accuracy: 0.8510
# Epoch 10/60
# 238/250 [===========================>..] - ETA: 0s - loss: 0.3676 - accuracy: 0.9118WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 628us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3662 - accuracy: 0.9120
# Epoch 11/60
# 221/250 [=========================>....] - ETA: 0s - loss: 0.3052 - accuracy: 0.9379WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 633us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3007 - accuracy: 0.9410
# Epoch 12/60
# 212/250 [========================>.....] - ETA: 0s - loss: 0.2554 - accuracy: 0.9533WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 883us/step
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2497 - accuracy: 0.9553
# Epoch 13/60
# 218/250 [=========================>....] - ETA: 0s - loss: 0.2156 - accuracy: 0.9599WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 822us/step
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2142 - accuracy: 0.9589
# Epoch 14/60
# 218/250 [=========================>....] - ETA: 0s - loss: 0.1853 - accuracy: 0.9650WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 592us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.1849 - accuracy: 0.9644
# Epoch 15/60
# 245/250 [============================>.] - ETA: 0s - loss: 0.1619 - accuracy: 0.9677WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 632us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.1617 - accuracy: 0.9676
# Epoch 16/60
# 240/250 [===========================>..] - ETA: 0s - loss: 0.1436 - accuracy: 0.9690WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 654us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.1435 - accuracy: 0.9686
# Epoch 17/60
# 230/250 [==========================>...] - ETA: 0s - loss: 0.1310 - accuracy: 0.9716WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 620us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.1296 - accuracy: 0.9720
# Epoch 18/60
# 231/250 [==========================>...] - ETA: 0s - loss: 0.1166 - accuracy: 0.9762WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 613us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.1163 - accuracy: 0.9765
# Epoch 19/60
# 249/250 [============================>.] - ETA: 0s - loss: 0.1050 - accuracy: 0.9769WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 612us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.1053 - accuracy: 0.9768
# Epoch 20/60
# 229/250 [==========================>...] - ETA: 0s - loss: 0.0978 - accuracy: 0.9780WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 663us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0984 - accuracy: 0.9778
# Epoch 21/60
# 238/250 [===========================>..] - ETA: 0s - loss: 0.0899 - accuracy: 0.9810WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 663us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0899 - accuracy: 0.9809
# Epoch 22/60
# 224/250 [=========================>....] - ETA: 0s - loss: 0.0841 - accuracy: 0.9798WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 665us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0845 - accuracy: 0.9787
# Epoch 23/60
# 228/250 [==========================>...] - ETA: 0s - loss: 0.0784 - accuracy: 0.9822WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 652us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0780 - accuracy: 0.9825
# Epoch 24/60
# 210/250 [========================>.....] - ETA: 0s - loss: 0.0712 - accuracy: 0.9817WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 617us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0738 - accuracy: 0.9819
# Epoch 25/60
# 249/250 [============================>.] - ETA: 0s - loss: 0.0696 - accuracy: 0.9826WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 666us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0697 - accuracy: 0.9825
# Epoch 26/60
# 242/250 [============================>.] - ETA: 0s - loss: 0.0645 - accuracy: 0.9854WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 614us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0644 - accuracy: 0.9854
# Epoch 27/60
# 246/250 [============================>.] - ETA: 0s - loss: 0.0625 - accuracy: 0.9840WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 620us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0627 - accuracy: 0.9839
# Epoch 28/60
# 224/250 [=========================>....] - ETA: 0s - loss: 0.0582 - accuracy: 0.9855WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 627us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0584 - accuracy: 0.9852
# Epoch 29/60
# 236/250 [===========================>..] - ETA: 0s - loss: 0.0542 - accuracy: 0.9858WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 661us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0559 - accuracy: 0.9858
# Epoch 30/60
# 241/250 [===========================>..] - ETA: 0s - loss: 0.0543 - accuracy: 0.9857WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 631us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0540 - accuracy: 0.9859
# Epoch 31/60
# 230/250 [==========================>...] - ETA: 0s - loss: 0.0527 - accuracy: 0.9870WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 661us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0524 - accuracy: 0.9870
# Epoch 32/60
# 238/250 [===========================>..] - ETA: 0s - loss: 0.0487 - accuracy: 0.9879WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 621us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0495 - accuracy: 0.9876
# Epoch 33/60
# 244/250 [============================>.] - ETA: 0s - loss: 0.0474 - accuracy: 0.9873WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 599us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0475 - accuracy: 0.9872
# Epoch 34/60
# 222/250 [=========================>....] - ETA: 0s - loss: 0.0442 - accuracy: 0.9880WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 665us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0456 - accuracy: 0.9872
# Epoch 35/60
# 231/250 [==========================>...] - ETA: 0s - loss: 0.0449 - accuracy: 0.9893WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 672us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0445 - accuracy: 0.9890
# Epoch 36/60
# 235/250 [===========================>..] - ETA: 0s - loss: 0.0430 - accuracy: 0.9884WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 676us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0427 - accuracy: 0.9885
# Epoch 37/60
# 208/250 [=======================>......] - ETA: 0s - loss: 0.0422 - accuracy: 0.9878WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 652us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0420 - accuracy: 0.9880
# Epoch 38/60
# 249/250 [============================>.] - ETA: 0s - loss: 0.0409 - accuracy: 0.9880WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 603us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0408 - accuracy: 0.9880
# Epoch 39/60
# 227/250 [==========================>...] - ETA: 0s - loss: 0.0400 - accuracy: 0.9884WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 816us/step
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0392 - accuracy: 0.9887
# Epoch 40/60
# 235/250 [===========================>..] - ETA: 0s - loss: 0.0389 - accuracy: 0.9891WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 728us/step
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0394 - accuracy: 0.9889
# Epoch 41/60
# 224/250 [=========================>....] - ETA: 0s - loss: 0.0385 - accuracy: 0.9890WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 718us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0381 - accuracy: 0.9890
# Epoch 42/60
# 233/250 [==========================>...] - ETA: 0s - loss: 0.0357 - accuracy: 0.9901WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 651us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0368 - accuracy: 0.9895
# Epoch 43/60
# 210/250 [========================>.....] - ETA: 0s - loss: 0.0362 - accuracy: 0.9879WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 672us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0362 - accuracy: 0.9883
# Epoch 44/60
# 227/250 [==========================>...] - ETA: 0s - loss: 0.0369 - accuracy: 0.9886WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 665us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0355 - accuracy: 0.9893
# Epoch 45/60
# 212/250 [========================>.....] - ETA: 0s - loss: 0.0347 - accuracy: 0.9900WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 701us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0345 - accuracy: 0.9900
# Epoch 46/60
# 242/250 [============================>.] - ETA: 0s - loss: 0.0340 - accuracy: 0.9904WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 675us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0343 - accuracy: 0.9901
# Epoch 47/60
# 226/250 [==========================>...] - ETA: 0s - loss: 0.0341 - accuracy: 0.9898WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 670us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0337 - accuracy: 0.9901
# Epoch 48/60
# 206/250 [=======================>......] - ETA: 0s - loss: 0.0321 - accuracy: 0.9906WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 682us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0322 - accuracy: 0.9906
# Epoch 49/60
# 228/250 [==========================>...] - ETA: 0s - loss: 0.0315 - accuracy: 0.9886WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 647us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0314 - accuracy: 0.9891
# Epoch 50/60
# 246/250 [============================>.] - ETA: 0s - loss: 0.0316 - accuracy: 0.9907WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 617us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0315 - accuracy: 0.9909
# Epoch 51/60
# 209/250 [========================>.....] - ETA: 0s - loss: 0.0307 - accuracy: 0.9907WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 677us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0307 - accuracy: 0.9905
# Epoch 52/60
# 234/250 [===========================>..] - ETA: 0s - loss: 0.0310 - accuracy: 0.9911WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 709us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0311 - accuracy: 0.9911
# Epoch 53/60
# 220/250 [=========================>....] - ETA: 0s - loss: 0.0304 - accuracy: 0.9902WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 602us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0301 - accuracy: 0.9906
# Epoch 54/60
# 229/250 [==========================>...] - ETA: 0s - loss: 0.0287 - accuracy: 0.9911WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 643us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0292 - accuracy: 0.9910
# Epoch 55/60
# 225/250 [==========================>...] - ETA: 0s - loss: 0.0284 - accuracy: 0.9912WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 666us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0284 - accuracy: 0.9914
# Epoch 56/60
# 216/250 [========================>.....] - ETA: 0s - loss: 0.0282 - accuracy: 0.9931WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 717us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0285 - accuracy: 0.9925
# Epoch 57/60
# 234/250 [===========================>..] - ETA: 0s - loss: 0.0299 - accuracy: 0.9897WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 797us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0295 - accuracy: 0.9900
# Epoch 58/60
# 222/250 [=========================>....] - ETA: 0s - loss: 0.0279 - accuracy: 0.9918WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 743us/step
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0277 - accuracy: 0.9919
# Epoch 59/60
# 250/250 [==============================] - ETA: 0s - loss: 0.0278 - accuracy: 0.9919WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 702us/step
# 250/250 [==============================] - 1s 3ms/step - loss: 0.0278 - accuracy: 0.9919
# Epoch 60/60
# 222/250 [=========================>....] - ETA: 0s - loss: 0.0280 - accuracy: 0.9928WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 313/313 [==============================] - 0s 668us/step
# 250/250 [==============================] - 1s 2ms/step - loss: 0.0273 - accuracy: 0.9930

# %%
model.evaluate(X_test, y_test)
# Out:
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0452 - accuracy: 0.9890
# [0.04521135240793228, 0.9890000224113464]

# %%
plot_decision_boundary(model, X, y)
# Out:
# 313/313 [==============================] - 0s 635us/step

# %%
y_pred = np.round(model.predict(X_test))

df_compare = pd.DataFrame(np.c_[y_pred, y_test], columns=['y pred', 'y test'])

zero, one = df_compare['y pred'].value_counts()

# ax = sns.countplot(df_compare['y pred'])

# ax.annotate(
#     f'{zero}', 
#     xy=(0, zero), 
#     xytext=(0, zero + int(zero/8)), 
#     fontsize=12,
#     arrowprops=dict(facecolor='black', shrink=0.001)
# )

# ax.annotate(
#     f'{one}', 
#     xy=(1, one), 
#     xytext=(1, one + int(one/8)), 
#     fontsize=12,
#     arrowprops=dict(facecolor='black', shrink=0.001)
# )

# sns.catplot(data=df_compare.melt(), x='value', col='variable', kind='count', palette='magma_r')

df_plot = df_compare.melt().value_counts().sort_index()
display(df_plot.unstack('variable'))


df_plot.unstack('variable').plot.bar(rot=0, figsize=(12, 8))
plt.legend(loc='upper right')
plt.ylim([0, 1300])

plt.show()
# Out:
# 63/63 [==============================] - 0s 659us/step
# variable  y pred  y test
# value
# 0.0         1001    1012
# 1.0          999     988

# %%
pd.DataFrame(history.history).plot()
# Out:
# <AxesSubplot:>
