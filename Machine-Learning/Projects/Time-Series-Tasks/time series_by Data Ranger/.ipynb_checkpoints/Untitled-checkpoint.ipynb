# %%
import numpy as np
import pandas as pd
import scipy
import statsmodels.api as sm
import matplotlib.pyplot as plt
import sklearn
import statsmodels.tsa.stattools as sts
import statsmodels.graphics.tsaplots as sgt
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima.arima import auto_arima
from arch import arch_model
import yfinance
import warnings
warnings.filterwarnings('ignore')

# %%
raw_data = yfinance.download(
    tickers="^GSPC ^FTSE ^N225 ^GDAXI", 
    start="1994-01-07",
    end="2019-09-01",
    interval="1d",
    group_by='ticker',
    auto_adjust=True,
    treads=True
)
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
df_comp = raw_data.copy(deep=True)

# %%
df_comp = df_comp.assign(
    spx = df_comp['^GSPC'].Close,
    dax = df_comp['^FTSE'].Close,
    ftse = df_comp['^N225'].Close,
    nikkei = df_comp['^GDAXI'].Close
)

df_comp
# Out:
#                    ^N225                                            \
#                     Open          High           Low         Close
# Date
# 1994-01-06           NaN           NaN           NaN           NaN
# 1994-01-07  17842.980469  18131.410156  17787.480469  18124.009766
# 1994-01-10  18186.519531  18567.060547  18186.519531  18443.439453
# 1994-01-11  18481.849609  18671.669922  18373.039062  18485.250000
# 1994-01-12  18447.339844  18807.080078  18301.929688  18793.880859
# ...                  ...           ...           ...           ...
# 2019-08-26  20325.439453  20329.009766  20173.759766  20261.039062
# 2019-08-27  20467.220703  20529.939453  20439.919922  20456.080078
# 2019-08-28  20474.310547  20511.210938  20433.310547  20479.419922
# 2019-08-29  20500.500000  20520.679688  20361.119141  20460.929688
# 2019-08-30  20641.490234  20748.349609  20633.300781  20704.369141
#
#                               ^FTSE                                         \
#                 Volume         Open         High          Low        Close
# Date
# 1994-01-06         NaN  3355.300049  3407.699951  3355.300049  3403.000000
# 1994-01-07         0.0  3401.399902  3446.800049  3398.699951  3446.000000
# 1994-01-10         0.0  3465.699951  3468.100098  3430.000000  3440.600098
# 1994-01-11         0.0  3442.500000  3442.500000  3413.500000  3413.800049
# 1994-01-12         0.0  3394.800049  3402.399902  3372.000000  3372.000000
# ...                ...          ...          ...          ...          ...
# 2019-08-26  69900000.0          NaN          NaN          NaN          NaN
# 2019-08-27  60800000.0  7095.000000  7110.799805  7044.700195  7089.600098
# 2019-08-28  51500000.0  7089.600098  7131.200195  7050.000000  7114.700195
# 2019-08-29  55100000.0  7114.700195  7199.200195  7103.100098  7184.299805
# 2019-08-30  72000000.0  7184.299805  7240.399902  7179.700195  7207.200195
#
#                          ...      ^GDAXI        ^GSPC               \
#                  Volume  ...      Volume         Open         High
# Date                     ...
# 1994-01-06          0.0  ...         0.0   467.549988   469.000000
# 1994-01-07          0.0  ...         0.0   467.089996   470.260010
# 1994-01-10          0.0  ...         0.0   469.899994   475.269989
# 1994-01-11          0.0  ...         0.0   475.269989   475.279999
# 1994-01-12          0.0  ...         0.0   474.130005   475.059998
# ...                 ...  ...         ...          ...          ...
# 2019-08-26          NaN  ...  54752500.0  2866.699951  2879.270020
# 2019-08-27  851399100.0  ...  82363700.0  2893.139893  2898.790039
# 2019-08-28  675638900.0  ...  59962600.0  2861.280029  2890.030029
# 2019-08-29  635681800.0  ...  72992700.0  2910.370117  2930.500000
# 2019-08-30  727868800.0  ...  77686500.0  2937.090088  2940.429932
#
#                                                             spx          dax  \
#                     Low        Close        Volume
# Date
# 1994-01-06   467.019989   467.119995  3.659600e+08   467.119995  3403.000000
# 1994-01-07   467.029999   469.899994  3.249200e+08   469.899994  3446.000000
# 1994-01-10   469.549988   475.269989  3.194900e+08   475.269989  3440.600098
# 1994-01-11   473.269989   474.130005  3.054900e+08   474.130005  3413.800049
# 1994-01-12   472.140015   474.170013  3.106900e+08   474.170013  3372.000000
# ...                 ...          ...           ...          ...          ...
# 2019-08-26  2856.000000  2878.379883  2.857600e+09  2878.379883          NaN
# 2019-08-27  2860.590088  2869.159912  3.533630e+09  2869.159912  7089.600098
# 2019-08-28  2853.050049  2887.939941  3.097420e+09  2887.939941  7114.700195
# 2019-08-29  2905.669922  2924.580078  3.176190e+09  2924.580078  7184.299805
# 2019-08-30  2913.320068  2926.459961  3.008450e+09  2926.459961  7207.200195
#
#                     ftse        nikkei
#
# Date
# 1994-01-06           NaN   2220.629883
# 1994-01-07  18124.009766   2224.949951
# 1994-01-10  18443.439453   2225.000000
# 1994-01-11  18485.250000   2228.100098
# 1994-01-12  18793.880859   2182.060059
# ...                  ...           ...
# 2019-08-26  20261.039062  11658.040039
# 2019-08-27  20456.080078  11730.019531
# 2019-08-28  20479.419922  11701.019531
# 2019-08-29  20460.929688  11838.879883
# 2019-08-30  20704.369141  11939.280273
#
# [6674 rows x 24 columns]

# %%
df_comp = df_comp[1:]
df_comp.drop(columns=['^GSPC', '^FTSE', '^N225', '^GDAXI'], inplace=True)
df_comp = df_comp.asfreq('b')
df_comp = df_comp.fillna(method='ffill')
df_comp
# Out:
#                     spx          dax          ftse        nikkei
#
# Date
# 1994-01-07   469.899994  3446.000000  18124.009766   2224.949951
# 1994-01-10   475.269989  3440.600098  18443.439453   2225.000000
# 1994-01-11   474.130005  3413.800049  18485.250000   2228.100098
# 1994-01-12   474.170013  3372.000000  18793.880859   2182.060059
# 1994-01-13   472.470001  3360.000000  18577.259766   2142.370117
# ...                 ...          ...           ...           ...
# 2019-08-26  2878.379883  7095.000000  20261.039062  11658.040039
# 2019-08-27  2869.159912  7089.600098  20456.080078  11730.019531
# 2019-08-28  2887.939941  7114.700195  20479.419922  11701.019531
# 2019-08-29  2924.580078  7184.299805  20460.929688  11838.879883
# 2019-08-30  2926.459961  7207.200195  20704.369141  11939.280273
#
# [6691 rows x 4 columns]

# %%
df_comp.isnull().sum()
# Out:
# spx         0
# dax         0
# ftse        0
# nikkei      0
# dtype: int64

# %%
df_comp = df_comp.assign(
    ret_spx = df_comp['spx'].pct_change(1).mul(100),
    ret_ftse = df_comp['ftse'].pct_change(1).mul(100),
    ret_dax = df_comp['dax'].pct_change(1).mul(100),
    ret_nikkei = df_comp['nikkei'].pct_change(1).mul(100),
)
df_comp
# Out:
#                     spx          dax          ftse        nikkei   ret_spx  \
#
# Date
# 1994-01-07   469.899994  3446.000000  18124.009766   2224.949951       NaN
# 1994-01-10   475.269989  3440.600098  18443.439453   2225.000000  1.142795
# 1994-01-11   474.130005  3413.800049  18485.250000   2228.100098 -0.239860
# 1994-01-12   474.170013  3372.000000  18793.880859   2182.060059  0.008438
# 1994-01-13   472.470001  3360.000000  18577.259766   2142.370117 -0.358524
# ...                 ...          ...           ...           ...       ...
# 2019-08-26  2878.379883  7095.000000  20261.039062  11658.040039  1.098299
# 2019-08-27  2869.159912  7089.600098  20456.080078  11730.019531 -0.320318
# 2019-08-28  2887.939941  7114.700195  20479.419922  11701.019531  0.654548
# 2019-08-29  2924.580078  7184.299805  20460.929688  11838.879883  1.268729
# 2019-08-30  2926.459961  7207.200195  20704.369141  11939.280273  0.064279
#
#             ret_ftse   ret_dax ret_nikkei
#
# Date
# 1994-01-07       NaN       NaN        NaN
# 1994-01-10  1.762467 -0.156701   0.002249
# 1994-01-11  0.226696 -0.778935   0.139330
# 1994-01-12  1.669606 -1.224443  -2.066336
# 1994-01-13 -1.152615 -0.355872  -1.818921
# ...              ...       ...        ...
# 2019-08-26 -2.172145  0.000000   0.400725
# 2019-08-27  0.962641 -0.076109   0.617424
# 2019-08-28  0.114097  0.354041  -0.247229
# 2019-08-29 -0.090287  0.978251   1.178191
# 2019-08-30  1.189777  0.318756   0.848057
#
# [6691 rows x 8 columns]

# %%
df_comp = df_comp.assign(
    norm_ret_spx = df_comp['ret_spx'].div(df_comp['ret_spx'][1])*100,
    norm_ret_ftse = df_comp['ret_ftse'].div(df_comp['ret_ftse'][1])*100,
    norm_ret_dax = df_comp['ret_dax'].div(df_comp['ret_dax'][1])*100,
    norm_ret_nikkei = df_comp['ret_nikkei'].div(df_comp['ret_nikkei'][1])*100,
)
df_comp
# Out:
#                     spx          dax          ftse        nikkei   ret_spx  \
#
# Date
# 1994-01-07   469.899994  3446.000000  18124.009766   2224.949951       NaN
# 1994-01-10   475.269989  3440.600098  18443.439453   2225.000000  1.142795
# 1994-01-11   474.130005  3413.800049  18485.250000   2228.100098 -0.239860
# 1994-01-12   474.170013  3372.000000  18793.880859   2182.060059  0.008438
# 1994-01-13   472.470001  3360.000000  18577.259766   2142.370117 -0.358524
# ...                 ...          ...           ...           ...       ...
# 2019-08-26  2878.379883  7095.000000  20261.039062  11658.040039  1.098299
# 2019-08-27  2869.159912  7089.600098  20456.080078  11730.019531 -0.320318
# 2019-08-28  2887.939941  7114.700195  20479.419922  11701.019531  0.654548
# 2019-08-29  2924.580078  7184.299805  20460.929688  11838.879883  1.268729
# 2019-08-30  2926.459961  7207.200195  20704.369141  11939.280273  0.064279
#
#             ret_ftse   ret_dax ret_nikkei norm_ret_spx norm_ret_ftse  \
#
# Date
# 1994-01-07       NaN       NaN        NaN          NaN           NaN
# 1994-01-10  1.762467 -0.156701   0.002249   100.000000    100.000000
# 1994-01-11  0.226696 -0.778935   0.139330   -20.988914     12.862428
# 1994-01-12  1.669606 -1.224443  -2.066336     0.738392     94.731198
# 1994-01-13 -1.152615 -0.355872  -1.818921   -31.372527    -65.397822
# ...              ...       ...        ...          ...           ...
# 2019-08-26 -2.172145  0.000000   0.400725    96.106342   -123.244604
# 2019-08-27  0.962641 -0.076109   0.617424   -28.029347     54.618937
# 2019-08-28  0.114097  0.354041  -0.247229    57.276050      6.473729
# 2019-08-29 -0.090287  0.978251   1.178191   111.019809     -5.122757
# 2019-08-30  1.189777  0.318756   0.848057     5.624693     67.506348
#
#            norm_ret_dax norm_ret_nikkei
#
# Date
# 1994-01-07          NaN             NaN
# 1994-01-10   100.000000      100.000000
# 1994-01-11   497.085111     6194.007011
# 1994-01-12   781.390409   -91860.185677
# 1994-01-13   227.103092   -80861.183055
# ...                 ...             ...
# 2019-08-26    -0.000000    17814.483944
# 2019-08-27    48.569415    27447.928201
# 2019-08-28  -225.934754   -10990.706129
# 2019-08-29  -624.280206    52377.167742
# 2019-08-30  -203.417265    37700.848225
#
# [6691 rows x 12 columns]

# %%
def splitting_data(df, train_size):
    size = int(df.shape[0] * train_size)
    return df.iloc[:size], df.iloc[size:]
    
train_df, test_df = splitting_data(df_comp, .8)

# %%
display(train_df)
display(test_df)
# Out:
#                     spx          dax          ftse       nikkei   ret_spx  \
#
# Date
# 1994-01-07   469.899994  3446.000000  18124.009766  2224.949951       NaN
# 1994-01-10   475.269989  3440.600098  18443.439453  2225.000000  1.142795
# 1994-01-11   474.130005  3413.800049  18485.250000  2228.100098 -0.239860
# 1994-01-12   474.170013  3372.000000  18793.880859  2182.060059  0.008438
# 1994-01-13   472.470001  3360.000000  18577.259766  2142.370117 -0.358524
# ...                 ...          ...           ...          ...       ...
# 2014-07-08  1963.709961  6738.500000  15314.410156  9772.669922 -0.704880
# 2014-07-09  1972.829956  6718.000000  15302.650391  9808.200195  0.464427
# 2014-07-10  1964.680054  6672.399902  15216.469727  9659.129883 -0.413107
# 2014-07-11  1967.569946  6690.200195  15164.040039  9666.339844  0.147092
# 2014-07-14  1977.099976  6746.100098  15296.820312  9783.009766  0.484355
#
#             ret_ftse   ret_dax ret_nikkei norm_ret_spx norm_ret_ftse  \
#
# Date
# 1994-01-07       NaN       NaN        NaN          NaN           NaN
# 1994-01-10  1.762467 -0.156701   0.002249   100.000000    100.000000
# 1994-01-11  0.226696 -0.778935   0.139330   -20.988914     12.862428
# 1994-01-12  1.669606 -1.224443  -2.066336     0.738392     94.731198
# 1994-01-13 -1.152615 -0.355872  -1.818921   -31.372527    -65.397822
# ...              ...       ...        ...          ...           ...
# 2014-07-08 -0.422839 -1.245695  -1.346653   -61.680354    -23.991315
# 2014-07-09 -0.076789 -0.304222   0.363568    40.639543     -4.356898
# 2014-07-10 -0.563175 -0.678775  -1.519854   -36.148835    -31.953776
# 2014-07-11 -0.344559  0.266775   0.074644    12.871270    -19.549802
# 2014-07-14  0.875626  0.835549   1.206971    42.383382     49.681837
#
#            norm_ret_dax norm_ret_nikkei
#
# Date
# 1994-01-07          NaN             NaN
# 1994-01-10   100.000000      100.000000
# 1994-01-11   497.085111     6194.007011
# 1994-01-12   781.390409   -91860.185677
# 1994-01-13   227.103092   -80861.183055
# ...                 ...             ...
# 2014-07-08   794.952349   -59866.246313
# 2014-07-09   194.142222    16162.615912
# 2014-07-10   433.166778   -67565.994483
# 2014-07-11  -170.245033     3318.342727
# 2014-07-14  -533.213704    53656.603796
#
# [5352 rows x 12 columns]
#                     spx          dax          ftse        nikkei   ret_spx  \
#
# Date
# 2014-07-15  1973.280029  6710.500000  15395.160156   9719.410156 -0.193210
# 2014-07-16  1981.569946  6784.700195  15379.299805   9859.269531  0.420108
# 2014-07-17  1958.119995  6738.299805  15370.259766   9753.879883 -1.183403
# 2014-07-18  1978.219971  6749.500000  15215.709961   9720.019531  1.026494
# 2014-07-21  1973.630005  6728.399902  15215.709961   9612.049805 -0.232025
# ...                 ...          ...           ...           ...       ...
# 2019-08-26  2878.379883  7095.000000  20261.039062  11658.040039  1.098299
# 2019-08-27  2869.159912  7089.600098  20456.080078  11730.019531 -0.320318
# 2019-08-28  2887.939941  7114.700195  20479.419922  11701.019531  0.654548
# 2019-08-29  2924.580078  7184.299805  20460.929688  11838.879883  1.268729
# 2019-08-30  2926.459961  7207.200195  20704.369141  11939.280273  0.064279
#
#             ret_ftse   ret_dax ret_nikkei norm_ret_spx norm_ret_ftse  \
#
# Date
# 2014-07-15  0.642878 -0.527714  -0.650103   -16.906752     36.476013
# 2014-07-16 -0.103022  1.105733   1.438970    36.761482     -5.845311
# 2014-07-17 -0.058781 -0.683897  -1.068940  -103.553334     -3.335130
# 2014-07-18 -1.005512  0.166217  -0.347148    89.823046    -57.051394
# 2014-07-21  0.000000 -0.312617  -1.110797   -20.303290      0.000000
# ...              ...       ...        ...          ...           ...
# 2019-08-26 -2.172145  0.000000   0.400725    96.106342   -123.244604
# 2019-08-27  0.962641 -0.076109   0.617424   -28.029347     54.618937
# 2019-08-28  0.114097  0.354041  -0.247229    57.276050      6.473729
# 2019-08-29 -0.090287  0.978251   1.178191   111.019809     -5.122757
# 2019-08-30  1.189777  0.318756   0.848057     5.624693     67.506348
#
#            norm_ret_dax norm_ret_nikkei
#
# Date
# 2014-07-15   336.765641   -28900.695507
# 2014-07-16  -705.634059    63970.243920
# 2014-07-17   436.435775   -47520.341116
# 2014-07-18  -106.072947   -15432.645957
# 2014-07-21   199.499693   -49381.149705
# ...                 ...             ...
# 2019-08-26    -0.000000    17814.483944
# 2019-08-27    48.569415    27447.928201
# 2019-08-28  -225.934754   -10990.706129
# 2019-08-29  -624.280206    52377.167742
# 2019-08-30  -203.417265    37700.848225
#
# [1339 rows x 12 columns]

# %%
model_arima = ARIMA(train_df['ftse'], order=(1,0,0))
results_arima = model_arima.fit()
results_arima

# %% [markdown]
# SIMPLE FORECASTING

# %%
start_date = '2014-07-15'
end_date = '2019-10-23'

# %%
df_pred = results_arima.predict(start=start_date, end=end_date)
test_df.loc[start_date:end_date, 'ftse'].plot(color='blue')
df_pred[start_date:end_date].plot(figsize=(20,5), color='red')
plt.title('Prediction Vs Actual', size='14')
# Out:
# Text(0.5, 1.0, 'Prediction Vs Actual')

# %% [markdown]
# ## AR MODEL AREN'T THE BEST ESTIMATORS OF NON-STATIONARY DATA

# %%
end_date = '2014-08-18'

model_ret_ar = ARIMA(train_df['ret_ftse'][1:], order=(5,0,0))
results_ret_ar = model_ret_ar.fit()

df_pred_ar = results_ret_ar.predict(start=start_date, end=end_date)

test_df.loc[start_date:end_date, 'ret_ftse'].plot(color='blue')
df_pred_ar[start_date:end_date].plot(figsize=(20,5), color='red')
plt.title('Prediction Vs Actual', size='14')
# Out:
# Text(0.5, 1.0, 'Prediction Vs Actual')

# %% [markdown]
# Our model makes no predictions sixe it assume all future returns will be 0, or extremely close to it

# %%
results_ret_ar.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               ret_ftse   No. Observations:                 5351
# Model:                     ARMA(1, 0)   Log Likelihood               -9674.202
# Method:                       css-mle   S.D. of innovations              1.475
# Date:                Thu, 03 Mar 2022   AIC                          19354.404
# Time:                        07:51:00   BIC                          19374.159
# Sample:                    01-10-1994   HQIC                         19361.304
#                          - 07-14-2014
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0077      0.020      0.396      0.692      -0.031       0.046
# ar.L1.ret_ftse    -0.0324      0.014     -2.369      0.018      -0.059      -0.006
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1          -30.8928           +0.0000j           30.8928            0.5000
# -----------------------------------------------------------------------------
# """

# %%
df_pred_ar.head()
# Out:
# 2014-07-15    0.005102
# 2014-07-16   -0.019276
# 2014-07-17   -0.009977
# 2014-07-18    0.012327
# 2014-07-21    0.006682
# Freq: B, dtype: float64

# %% [markdown]
# ## ARMA

# %%
model_ret_ar = ARIMA(train_df['ret_ftse'][1:], order=(5,0,0))
results_ret_ar = model_ret_ar.fit()

df_pred_ar = results_ret_ar.predict(start=start_date, end=end_date)

test_df.loc[start_date:end_date, 'ret_ftse'].plot(color='blue')
df_pred_ar[start_date:end_date].plot(figsize=(20,5), color='red')
plt.title('Prediction Vs Actual', size='14')
# Out:
# Text(0.5, 1.0, 'Prediction Vs Actual')

# %% [markdown]
# ## ARMAX

# %%
end_date = '2015-01-01'
model_ret_armax = ARIMA(
    train_df['ret_ftse'][1:], 
    exog=train_df[['ret_spx', 'ret_dax', 'ret_nikkei']][1:], 
    order=(1,0,1)
)

results_ret_armax = model_ret_armax.fit()
df_pred_armax = results_ret_armax.predict(
    start=start_date, 
    end=end_date,
    exog=test_df[['ret_spx', 'ret_dax', 'ret_nikkei']][start_date:end_date]
)

test_df.loc[start_date:end_date, 'ret_ftse'].plot(color='blue')
df_pred_armax[start_date:end_date].plot(figsize=(20,5), color='red')
plt.title('Prediction Vs Actual (Returns)', size='24')
# Out:
# Text(0.5, 1.0, 'Prediction Vs Actual (Returns)')

# %% [markdown]
# ## SARMA

# %%
end_date = '2014-08-18'
model_ret_sarma = SARIMAX(
    train_df['ret_ftse'][1:], 
    order=(3,0,4),
    seasonal_order=(3,0,2,5)
)

results_ret_sarma = model_ret_sarma.fit()
df_pred_sarma = results_ret_sarma.predict(
    start=start_date, 
    end=end_date,
)

test_df.loc[start_date:end_date, 'ret_ftse'].plot(color='blue')
df_pred_sarma[start_date:end_date].plot(figsize=(20,5), color='red')
plt.title('Prediction Vs Actual (SARMA)', size='24')
# Out:
# Text(0.5, 1.0, 'Prediction Vs Actual (SARMA)')

# %% [markdown]
# ## SARIMAX

# %%
end_date = '2015-01-01'
model_ret_sarimax = SARIMAX(
    train_df['ret_ftse'][1:], 
    order=(3,0,4),
    exog=train_df[['ret_spx', 'ret_dax', 'ret_nikkei']][1:],
    seasonal_order=(3,0,2,5)
)

results_ret_sarimax = model_ret_sarimax.fit()
df_pred_sarimax = results_ret_sarimax.predict(
    start=start_date,
    end=end_date,
    exog=test_df[['ret_spx', 'ret_dax', 'ret_nikkei']][start_date:end_date],
)

test_df.loc[start_date:end_date, 'ret_ftse'].plot(color='blue')
df_pred_sarimax[start_date:end_date].plot(figsize=(20,5), color='red')
plt.title('Prediction Vs Actual (SARIMAX)', size='24')
# Out:
# Text(0.5, 1.0, 'Prediction Vs Actual (SARMA)')

# %% [markdown]
# ## AUTO ARIMA

# %%
from pmdarima.arima import auto_arima

model_auto = auto_arima(
    train_df['ret_ftse'][1:],
    exogenous=train_df[['ret_spx', 'ret_dax', 'ret_nikkei']][1:],
    m=5,
    max_p=5,
    max_q=5,
    max_P=5,
    max_Q=5
)

# %%
df_auto_pred = pd.DataFrame(
    model_auto.predict(
        n_periods=len(test_df[start_date:end_date]),
        exogenous=test_df[['ret_spx', 'ret_dax', 'ret_nikkei']][start_date:end_date]
    ),
    index=test_df[start_date:end_date].index
)

# %%
df_auto_pred.plot(figsize=(20,5), color='red')
test_df.loc[start_date:end_date, 'ret_ftse'].plot(color='blue')
plt.title('Auto Model Predictions Vs Real Data')
plt.show()

# %%
# df_pred[start_date:end_date].plot(figsize=(20,5), color='yellow')
df_pred_ar[start_date:end_date].plot(color='pink')
df_pred_armax[start_date:end_date].plot(color='cyan')
df_pred_sarma[start_date:end_date].plot(color='magenta')
df_pred_sarimax[start_date:end_date].plot(figsize=(20,5), color='red')
test_df.loc[start_date:end_date, 'ret_ftse'].plot(color='blue')
plt.legend(['AR', 'MA', 'ARMAX', 'SARMA', 'SARMAX'])
plt.title('All the models', size=24)
plt.show()

# %% [markdown]
# ### DISCUSS HOW TO USE THE ARCH PACKAGE TO FORECAST VOLATILITY

# %%
mod_garch = arch_model(df_comp['ret_ftse'][1:], vol='GARCH', p=1, q=1, mean='constant', dist='Normal')
res_garch = mod_garch.fit(last_obs=start_date, update_freq=10)
# Out:
# Iteration:     10,   Func. Count:     65,   Neg. LLF: 9097.426555656692
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 9097.426495967538
#             Iterations: 12
#             Function evaluations: 74
#             Gradient evaluations: 12

# %%
pred_garch = res_garch.forecast(horizon=1, align='target')

# %%
pred_garch.residual_variance[start_date:].plot(figsize=(20,5), color='red')
test_df['ret_ftse'].abs().plot(color='blue', zorder=1)
plt.title('Volatility Predictions', size=24)
plt.show()

# %%
pred_garch = res_garch.forecast(horizon=100, align='target')
pred_garch.residual_variance[-1:]
# Out:
#                h.001     h.002     h.003     h.004     h.005     h.006  \
# Date
# 2019-08-30  1.041493  1.134152  1.232985  1.262433  0.937426  0.996376
#
#                h.007     h.008     h.009     h.010  ...     h.091     h.092  \
# Date                                                ...
# 2019-08-30  1.068553  1.135348  1.192535  1.237909  ...  1.936905  1.946667
#
#                h.093     h.094     h.095     h.096     h.097    h.098  \
# Date
# 2019-08-30  1.958441  1.971948  1.986382  1.998019  2.000737  2.01518
#
#                h.099     h.100
# Date
# 2019-08-30  2.030457  2.019992
#
# [1 rows x 100 columns]

# %% [markdown]
# ## Multivariate Regression Model

# %%
from statsmodels.tsa.api import VAR

# %%
df_ret = train_df[['ret_spx', 'ret_dax', 'ret_nikkei', 'ret_ftse']][1:]

# %%
model_var_ret = VAR(df_ret)
model_var_ret.select_order(20)
results_var_ret = model_var_ret.fit(ic='aic')

# %%
results_var_ret.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 03, Mar, 2022
# Time:                     09:30:33
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   0.329002
# Nobs:                     5346.00    HQIC:                  0.261684
# Log likelihood:          -30861.5    FPE:                    1.25301
# AIC:                     0.225548    Det(Omega_mle):         1.23351
# --------------------------------------------------------------------
# Results for equation ret_spx
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.039217         0.016160            2.427           0.015
# L1.ret_spx           -0.110842         0.017560           -6.312           0.000
# L1.ret_dax           -0.012983         0.024445           -0.531           0.595
# L1.ret_nikkei         0.064906         0.019025            3.412           0.001
# L1.ret_ftse          -0.014782         0.012712           -1.163           0.245
# L2.ret_spx           -0.043340         0.020259           -2.139           0.032
# L2.ret_dax           -0.037052         0.024844           -1.491           0.136
# L2.ret_nikkei         0.022406         0.019229            1.165           0.244
# L2.ret_ftse          -0.014083         0.012852           -1.096           0.273
# L3.ret_spx           -0.003097         0.020531           -0.151           0.880
# L3.ret_dax            0.012537         0.024747            0.507           0.612
# L3.ret_nikkei        -0.011760         0.019251           -0.611           0.541
# L3.ret_ftse           0.010753         0.012853            0.837           0.403
# L4.ret_spx           -0.045871         0.020413           -2.247           0.025
# L4.ret_dax            0.058614         0.024698            2.373           0.018
# L4.ret_nikkei        -0.005391         0.019231           -0.280           0.779
# L4.ret_ftse          -0.006096         0.012835           -0.475           0.635
# L5.ret_spx           -0.035094         0.019211           -1.827           0.068
# L5.ret_dax           -0.048022         0.023745           -2.022           0.043
# L5.ret_nikkei         0.011908         0.019108            0.623           0.533
# L5.ret_ftse           0.003039         0.011499            0.264           0.792
# ================================================================================
#
# Results for equation ret_dax
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.008811         0.014661            0.601           0.548
# L1.ret_spx            0.430195         0.015932           27.002           0.000
# L1.ret_dax           -0.212413         0.022179           -9.577           0.000
# L1.ret_nikkei        -0.059510         0.017261           -3.448           0.001
# L1.ret_ftse          -0.046192         0.011533           -4.005           0.000
# L2.ret_spx            0.160015         0.018381            8.705           0.000
# L2.ret_dax           -0.081735         0.022541           -3.626           0.000
# L2.ret_nikkei        -0.049151         0.017446           -2.817           0.005
# L2.ret_ftse          -0.023352         0.011661           -2.003           0.045
# L3.ret_spx            0.104669         0.018627            5.619           0.000
# L3.ret_dax           -0.086717         0.022453           -3.862           0.000
# L3.ret_nikkei        -0.034839         0.017466           -1.995           0.046
# L3.ret_ftse           0.002899         0.011661            0.249           0.804
# L4.ret_spx            0.018423         0.018520            0.995           0.320
# L4.ret_dax            0.015636         0.022409            0.698           0.485
# L4.ret_nikkei        -0.006171         0.017448           -0.354           0.724
# L4.ret_ftse           0.015264         0.011645            1.311           0.190
# L5.ret_spx            0.010344         0.017430            0.593           0.553
# L5.ret_dax           -0.108627         0.021544           -5.042           0.000
# L5.ret_nikkei         0.044521         0.017337            2.568           0.010
# L5.ret_ftse          -0.012695         0.010433           -1.217           0.224
# ================================================================================
#
# Results for equation ret_nikkei
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.030974         0.019443            1.593           0.111
# L1.ret_spx            0.414664         0.021128           19.627           0.000
# L1.ret_dax           -0.153570         0.029411           -5.221           0.000
# L1.ret_nikkei        -0.121294         0.022890           -5.299           0.000
# L1.ret_ftse          -0.043067         0.015294           -2.816           0.005
# L2.ret_spx            0.173903         0.024375            7.134           0.000
# L2.ret_dax           -0.063419         0.029891           -2.122           0.034
# L2.ret_nikkei        -0.054455         0.023135           -2.354           0.019
# L2.ret_ftse          -0.029186         0.015463           -1.887           0.059
# L3.ret_spx            0.099698         0.024702            4.036           0.000
# L3.ret_dax           -0.022453         0.029775           -0.754           0.451
# L3.ret_nikkei        -0.054206         0.023162           -2.340           0.019
# L3.ret_ftse           0.012944         0.015464            0.837           0.403
# L4.ret_spx           -0.001189         0.024560           -0.048           0.961
# L4.ret_dax            0.059153         0.029716            1.991           0.047
# L4.ret_nikkei        -0.018521         0.023138           -0.800           0.423
# L4.ret_ftse           0.010962         0.015442            0.710           0.478
# L5.ret_spx           -0.016895         0.023114           -0.731           0.465
# L5.ret_dax           -0.111615         0.028569           -3.907           0.000
# L5.ret_nikkei         0.030880         0.022990            1.343           0.179
# L5.ret_ftse           0.012540         0.013836            0.906           0.365
# ================================================================================
#
# Results for equation ret_ftse
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                -0.019074         0.017825           -1.070           0.285
# L1.ret_spx            0.434234         0.019370           22.418           0.000
# L1.ret_dax            0.149834         0.026964            5.557           0.000
# L1.ret_nikkei         0.080364         0.020985            3.830           0.000
# L1.ret_ftse          -0.150418         0.014022          -10.728           0.000
# L2.ret_spx            0.078116         0.022347            3.496           0.000
# L2.ret_dax           -0.048024         0.027404           -1.752           0.080
# L2.ret_nikkei         0.035939         0.021210            1.694           0.090
# L2.ret_ftse          -0.039938         0.014176           -2.817           0.005
# L3.ret_spx            0.057511         0.022646            2.540           0.011
# L3.ret_dax           -0.015279         0.027297           -0.560           0.576
# L3.ret_nikkei         0.000067         0.021234            0.003           0.997
# L3.ret_ftse          -0.020292         0.014177           -1.431           0.152
# L4.ret_spx            0.014705         0.022516            0.653           0.514
# L4.ret_dax            0.047441         0.027243            1.741           0.082
# L4.ret_nikkei        -0.019775         0.021212           -0.932           0.351
# L4.ret_ftse          -0.028420         0.014157           -2.007           0.045
# L5.ret_spx           -0.000917         0.021191           -0.043           0.965
# L5.ret_dax            0.016427         0.026192            0.627           0.531
# L5.ret_nikkei         0.035681         0.021077            1.693           0.090
# L5.ret_ftse          -0.008921         0.012684           -0.703           0.482
# ================================================================================
#
# Correlation matrix of residuals
#                ret_spx   ret_dax  ret_nikkei  ret_ftse
# ret_spx       1.000000  0.569710    0.605314  0.151368
# ret_dax       0.569710  1.000000    0.775852  0.210808
# ret_nikkei    0.605314  0.775852    1.000000  0.202503
# ret_ftse      0.151368  0.210808    0.202503  1.000000

# %%
lag_order_ret = results_var_ret.k_ar
var_pred_ret = results_var_ret.forecast(df_ret.values[-lag_order_ret:], len(test_df[start_date:end_date]))

df_ret_pred = pd.DataFrame(data=var_pred_ret, index=test_df[start_date:end_date].index,
                          columns=test_df[start_date:end_date].columns[4:8])
df_ret_pred.loc[start_date:end_date, 'ret_nikkei'].plot(figsize=(20,5), color='red')
test_df['ret_nikkei'][start_date:end_date].plot(color='blue')
plt.title('Real Vs Predictions', size=24)
plt.show()

# %%
var_pred_ret
# Out:
# array([[ 2.05124437e-02,  7.90075775e-02,  1.11567664e-01],
#        [-1.16692908e-05, -2.56816033e-03, -1.73964771e-02],
#        [-1.38015123e-01, -1.32735208e-01, -5.63583066e-02],
#        [-3.23312926e-02,  8.23217454e-02,  1.00238150e-01],
#        [-1.78415988e-02, -1.08445384e-01, -1.43589057e-01],
#        [ 8.21924452e-03,  7.61365255e-02,  7.52009850e-03],
#        [ 3.95221891e-02,  6.56281700e-02,  8.48318542e-02],
#        [ 4.71387958e-02,  1.89182685e-02,  6.49626730e-02],
#        [ 1.38753981e-02, -5.43976317e-02, -6.11781674e-02],
#        [ 4.57785508e-02,  8.29866265e-02,  7.99746534e-02],
#        [-1.01016870e-01, -6.40475044e-02,  2.73252902e-02],
#        [-6.79806580e-02, -5.00057714e-02, -1.09596035e-01],
#        [-1.78110775e-02, -6.27223730e-02, -4.93286565e-02],
#        [ 5.05808521e-02,  1.76941221e-01,  1.81659995e-01],
#        [ 9.23974659e-02,  6.28526153e-03,  6.64521165e-02],
#        [ 1.83246957e-01,  1.33543855e-01,  1.37895355e-01],
#        [-6.93922657e-03,  6.13175069e-02,  1.43524520e-01],
#        [ 4.51451889e-02, -4.47942739e-02,  2.02460209e-02],
#        [ 4.35168354e-03, -3.16702681e-02, -3.32014483e-02],
#        [ 3.49841387e-02,  4.37530274e-02,  2.98993606e-02],
#        [-7.09609646e-02,  9.72498357e-03,  9.32336835e-03],
#        [-6.87400040e-02, -2.96232698e-02, -5.81692638e-03],
#        [-1.19281615e-02, -5.72293279e-02, -8.08940468e-02],
#        [ 6.68143981e-02,  3.41222723e-02,  7.40154461e-02],
#        [ 1.03259729e-01,  1.00286788e-01,  1.47322771e-01],
#        [ 7.15270310e-02,  2.07746370e-02,  3.58378810e-02],
#        [ 4.45724393e-02,  1.35045845e-02,  3.21483597e-02],
#        [ 4.15709245e-02,  2.21880986e-02,  4.78301902e-02],
#        [ 4.99887264e-02,  3.81763788e-02,  5.67011963e-02],
#        [ 2.88899174e-02,  2.19304953e-02,  3.02983609e-02],
#        [ 4.36492877e-02,  1.96911531e-02,  4.23855541e-02],
#        [ 4.19417823e-02,  3.46402922e-02,  5.29942841e-02],
#        [ 3.42186946e-02,  2.10840718e-02,  3.96568324e-02],
#        [ 1.84237304e-02, -8.24609439e-03,  1.32286402e-02],
#        [ 3.10924649e-02,  1.97099805e-02,  4.71041581e-02],
#        [ 4.59978146e-02,  2.41787045e-02,  4.09223511e-02],
#        [ 3.90157140e-02,  2.47460489e-02,  3.24827333e-02],
#        [ 3.44396025e-02,  1.86655787e-02,  4.10560645e-02],
#        [ 4.35740046e-02,  2.94669773e-02,  5.27090221e-02],
#        [ 3.84471550e-02,  3.04352680e-02,  4.84943384e-02],
#        [ 4.73600616e-02,  2.82482611e-02,  4.61319189e-02],
#        [ 2.83300408e-02,  2.27834656e-02,  4.54989671e-02],
#        [ 3.17925567e-02,  9.66342692e-03,  2.95191189e-02],
#        [ 2.55303771e-02,  6.32606112e-03,  2.25771642e-02],
#        [ 3.62373042e-02,  2.37534481e-02,  4.17763066e-02],
#        [ 4.04030272e-02,  2.51221755e-02,  4.50724862e-02],
#        [ 3.79164718e-02,  1.95579497e-02,  4.00297333e-02],
#        [ 3.30037097e-02,  1.78063833e-02,  3.85048769e-02],
#        [ 3.40089395e-02,  2.04589945e-02,  4.56462223e-02],
#        [ 3.14011547e-02,  2.28818083e-02,  4.37168161e-02],
#        [ 2.89653820e-02,  1.54927604e-02,  3.45315185e-02],
#        [ 3.15037601e-02,  1.46023388e-02,  3.49784538e-02],
#        [ 3.42932229e-02,  2.04878623e-02,  4.10036357e-02],
#        [ 3.64378935e-02,  2.16013142e-02,  4.04854731e-02],
#        [ 3.27073786e-02,  1.84016576e-02,  3.86922869e-02],
#        [ 3.48342066e-02,  1.91509460e-02,  4.13012856e-02],
#        [ 3.56292577e-02,  2.03282573e-02,  4.07013424e-02],
#        [ 3.38582502e-02,  2.14738841e-02,  4.04195385e-02],
#        [ 3.16143532e-02,  1.57748729e-02,  3.60662284e-02],
#        [ 3.18301846e-02,  1.71374778e-02,  3.81198080e-02],
#        [ 3.31905808e-02,  2.01598320e-02,  3.96322890e-02],
#        [ 3.44605398e-02,  2.07287299e-02,  4.00778155e-02],
#        [ 3.37915734e-02,  1.94531384e-02,  4.04635924e-02],
#        [ 3.48389710e-02,  1.92177585e-02,  3.99785171e-02],
#        [ 3.40173869e-02,  1.91822096e-02,  3.94484312e-02],
#        [ 3.46383480e-02,  2.07478228e-02,  4.07324409e-02],
#        [ 3.35645810e-02,  1.94301298e-02,  3.95371958e-02],
#        [ 3.32542216e-02,  1.91143782e-02,  3.86677752e-02],
#        [ 3.32296413e-02,  1.83363942e-02,  3.82733539e-02],
#        [ 3.41706935e-02,  2.03158755e-02,  4.02263762e-02],
#        [ 3.39534207e-02,  2.05401467e-02,  4.03841122e-02],
#        [ 3.39917371e-02,  1.92723862e-02,  3.92465394e-02],
#        [ 3.36615372e-02,  1.90759762e-02,  3.91522559e-02],
#        [ 3.43393576e-02,  1.96504963e-02,  3.99336163e-02],
#        [ 3.43271687e-02,  1.98099517e-02,  3.95124377e-02],
#        [ 3.35577922e-02,  1.93145521e-02,  3.91342940e-02],
#        [ 3.37732780e-02,  1.92136324e-02,  3.92985396e-02],
#        [ 3.40080078e-02,  1.97416254e-02,  3.97868153e-02],
#        [ 3.41735042e-02,  2.01858311e-02,  3.99417632e-02],
#        [ 3.37169067e-02,  1.92788799e-02,  3.93017022e-02],
#        [ 3.37112982e-02,  1.91478503e-02,  3.93784396e-02],
#        [ 3.39913491e-02,  1.94210909e-02,  3.94103839e-02],
#        [ 3.40690108e-02,  1.99105416e-02,  3.97070226e-02],
#        [ 3.37630122e-02,  1.94512265e-02,  3.93822242e-02],
#        [ 3.39359304e-02,  1.91355983e-02,  3.92508440e-02],
#        [ 3.40512351e-02,  1.96473316e-02,  3.96117738e-02],
#        [ 3.41695945e-02,  1.99458733e-02,  3.98677639e-02],
#        [ 3.39410032e-02,  1.95390821e-02,  3.95877192e-02],
#        [ 3.38065737e-02,  1.93686343e-02,  3.94133792e-02],
#        [ 3.38401455e-02,  1.93286515e-02,  3.93483210e-02],
#        [ 3.39752327e-02,  1.96164157e-02,  3.95911893e-02],
#        [ 3.39720056e-02,  1.95919045e-02,  3.95504626e-02],
#        [ 3.39349545e-02,  1.94557739e-02,  3.94246906e-02],
#        [ 3.39050187e-02,  1.94758109e-02,  3.95226383e-02],
#        [ 3.40761285e-02,  1.96049164e-02,  3.96429546e-02],
#        [ 3.40045305e-02,  1.96771058e-02,  3.96530157e-02],
#        [ 3.39409958e-02,  1.94967650e-02,  3.95176615e-02],
#        [ 3.38773163e-02,  1.94299382e-02,  3.94636742e-02],
#        [ 3.39143616e-02,  1.95472276e-02,  3.95550994e-02],
#        [ 3.39623744e-02,  1.96005514e-02,  3.95545707e-02],
#        [ 3.39024750e-02,  1.94930704e-02,  3.94863643e-02],
#        [ 3.39244345e-02,  1.94849060e-02,  3.95202344e-02],
#        [ 3.39910654e-02,  1.95350581e-02,  3.95601041e-02],
#        [ 3.40009362e-02,  1.96319727e-02,  3.96150879e-02],
#        [ 3.39253151e-02,  1.95392236e-02,  3.95427032e-02],
#        [ 3.38920730e-02,  1.94428301e-02,  3.94755412e-02],
#        [ 3.39154728e-02,  1.94969797e-02,  3.95097204e-02],
#        [ 3.39737943e-02,  1.95931036e-02,  3.95794309e-02],
#        [ 3.39257718e-02,  1.95584326e-02,  3.95495104e-02],
#        [ 3.39109987e-02,  1.94764054e-02,  3.95002107e-02],
#        [ 3.39340540e-02,  1.94989685e-02,  3.95222317e-02],
#        [ 3.39599332e-02,  1.95857330e-02,  3.95877903e-02],
#        [ 3.39505542e-02,  1.95428146e-02,  3.95460435e-02],
#        [ 3.39207810e-02,  1.94943519e-02,  3.95063596e-02],
#        [ 3.39175570e-02,  1.95035059e-02,  3.95169106e-02],
#        [ 3.39444436e-02,  1.95406735e-02,  3.95449547e-02],
#        [ 3.39381922e-02,  1.95505870e-02,  3.95485104e-02],
#        [ 3.39315090e-02,  1.95194252e-02,  3.95258516e-02],
#        [ 3.39260945e-02,  1.95098501e-02,  3.95278839e-02],
#        [ 3.39447850e-02,  1.95361212e-02,  3.95465325e-02],
#        [ 3.39437874e-02,  1.95430893e-02,  3.95431706e-02],
#        [ 3.39293165e-02,  1.95243478e-02,  3.95302426e-02],
#        [ 3.39279703e-02,  1.95066364e-02,  3.95200035e-02]])
