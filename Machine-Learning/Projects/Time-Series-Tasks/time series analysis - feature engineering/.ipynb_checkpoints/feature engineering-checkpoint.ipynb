# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
birth_df = pd.read_csv('./dataset/daily-total-female-births-CA.csv', index_col='date', parse_dates=['date'])
birth_df.head()
# Out:
#             births
# date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44

# %%
birth_df = birth_df.assign(
    lag1 = birth_df['births'].shift(1),
    lag2 = birth_df['births'].shift(2),
    lag3 = birth_df['births'].shift(3),
)

# %%
birth_df
# Out:
#             births  lag1  lag2  lag3
# date
# 1959-01-01      35   NaN   NaN   NaN
# 1959-01-02      32  35.0   NaN   NaN
# 1959-01-03      30  32.0  35.0   NaN
# 1959-01-04      31  30.0  32.0  35.0
# 1959-01-05      44  31.0  30.0  32.0
# ...            ...   ...   ...   ...
# 1959-12-27      37  34.0  44.0  38.0
# 1959-12-28      52  37.0  34.0  44.0
# 1959-12-29      48  52.0  37.0  34.0
# 1959-12-30      55  48.0  52.0  37.0
# 1959-12-31      50  55.0  48.0  52.0
#
# [365 rows x 4 columns]

# %%
birth_df['births'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
birth_df['births'].rolling(10).mean().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
birth_df = birth_df.assign(
    MA3 = birth_df['births'].rolling(3).mean(),
    STD4 = birth_df['births'].rolling(4).std(),
    MAX5 = birth_df['births'].rolling(5).max(),
)

birth_df
# Out:
#             births  lag1  lag2  lag3        MA3      STD4  MAX5
# date
# 1959-01-01      35   NaN   NaN   NaN        NaN       NaN   NaN
# 1959-01-02      32  35.0   NaN   NaN        NaN       NaN   NaN
# 1959-01-03      30  32.0  35.0   NaN  32.333333       NaN   NaN
# 1959-01-04      31  30.0  32.0  35.0  31.000000  2.160247   NaN
# 1959-01-05      44  31.0  30.0  32.0  35.000000  6.551081  44.0
# ...            ...   ...   ...   ...        ...       ...   ...
# 1959-12-27      37  34.0  44.0  38.0  38.333333  4.193249  44.0
# 1959-12-28      52  37.0  34.0  44.0  41.000000  8.015610  52.0
# 1959-12-29      48  52.0  37.0  34.0  45.666667  8.616844  52.0
# 1959-12-30      55  48.0  52.0  37.0  51.666667  7.874008  55.0
# 1959-12-31      50  55.0  48.0  52.0  51.000000  2.986079  55.0
#
# [365 rows x 7 columns]

# %%
birth_df['day'] = birth_df.index.day_name()
birth_df
# Out:
#             births  lag1  lag2  lag3        MA3      STD4  MAX5        day
# date
# 1959-01-01      35   NaN   NaN   NaN        NaN       NaN   NaN   Thursday
# 1959-01-02      32  35.0   NaN   NaN        NaN       NaN   NaN     Friday
# 1959-01-03      30  32.0  35.0   NaN  32.333333       NaN   NaN   Saturday
# 1959-01-04      31  30.0  32.0  35.0  31.000000  2.160247   NaN     Sunday
# 1959-01-05      44  31.0  30.0  32.0  35.000000  6.551081  44.0     Monday
# ...            ...   ...   ...   ...        ...       ...   ...        ...
# 1959-12-27      37  34.0  44.0  38.0  38.333333  4.193249  44.0     Sunday
# 1959-12-28      52  37.0  34.0  44.0  41.000000  8.015610  52.0     Monday
# 1959-12-29      48  52.0  37.0  34.0  45.666667  8.616844  52.0    Tuesday
# 1959-12-30      55  48.0  52.0  37.0  51.666667  7.874008  55.0  Wednesday
# 1959-12-31      50  55.0  48.0  52.0  51.000000  2.986079  55.0   Thursday
#
# [365 rows x 8 columns]
