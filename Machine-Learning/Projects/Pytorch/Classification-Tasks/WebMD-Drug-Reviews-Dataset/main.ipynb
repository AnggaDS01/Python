# %%
import pandas as pd
import numpy as np
import csv
import re

# %%
DATASET_PATH = './Assets/Datasets/dataset_'

# %%
with open(DATASET_PATH, 'r') as file:
    for idx, line in enumerate(file):
        line = line.strip()
        print(f'{line} --> idx: {idx}')
        if idx == 24:
            break

    reader = csv.reader(file, delimiter=',', quotechar="'", doublequote=True)
    for idx, row in enumerate(reader):
        if idx >= 10:
            break

        print(f'length of data: {len(row)} --> value list: {row}')
# Out:
# % Context --> idx: 0
# % The dataset provides user reviews on specific drugs along with related conditions, side effects, age, sex, and ratings reflecting overall patient satisfaction. --> idx: 1
# % Content --> idx: 2
# % Data was acquired by scraping WebMD site. There are around 0.36 million rows of unique reviews and is updated till Mar 2020. --> idx: 3
# % Inspiration --> idx: 4
# % This dataset intended to answer following questions: --> idx: 5
# % I. Identifying the condition of the patient based on drug reviews? --> idx: 6
# % II. How to predict drug rating based on patients reviews? --> idx: 7
# % III. How to visualize drug rating, kind of drugs, types of conditions a patient can have, sentiments based on reviews --> idx: 8
# @RELATION WebMD-Drug-Reviews-Dataset --> idx: 9
#  --> idx: 10
# @ATTRIBUTE Age STRING --> idx: 11
# @ATTRIBUTE Condition STRING --> idx: 12
# @ATTRIBUTE Date STRING --> idx: 13
# @ATTRIBUTE Drug STRING --> idx: 14
# @ATTRIBUTE DrugId INTEGER --> idx: 15
# @ATTRIBUTE EaseofUse INTEGER --> idx: 16
# @ATTRIBUTE Effectiveness INTEGER --> idx: 17
# @ATTRIBUTE Reviews STRING --> idx: 18
# @ATTRIBUTE Satisfaction INTEGER --> idx: 19
# @ATTRIBUTE Sex STRING --> idx: 20
# @ATTRIBUTE Sides STRING --> idx: 21
# @ATTRIBUTE UsefulCount INTEGER --> idx: 22
#  --> idx: 23
# @DATA --> idx: 24
# length of data: 12 --> value list: ['75 or over', 'Stuffy Nose', '9/21/2014', '25dph-7.5peh', '146724', '5', '5', "I\\m a retired physician and of all the meds I have tried for my allergies (seasonal and not) - this one is the most effective for me.  When I first began using this drug some years ago - tiredness as a problem but is not currently.'", '5', 'Male', 'Drowsiness,  dizziness ,  dry mouth /nose/throat,  headache ,  upset stomach ,  constipation , or  trouble sleeping  may occur.', '0']
# length of data: 12 --> value list: ['25-34', 'Cold Symptoms', '1/13/2011', '25dph-7.5peh', '146724', '5', '5', 'cleared me right up even with my throat hurting it went away after taking the medicine', '5', 'Female', 'Drowsiness,  dizziness ,  dry mouth /nose/throat,  headache ,  upset stomach ,  constipation , or  trouble sleeping  may occur.', '1']
# length of data: 12 --> value list: ['65-74', 'Other', '7/16/2012', 'warfarin (bulk) 100  powder', '144731', '2', '3', 'why did my PTINR go from a normal of 2.5 to over \\n100?', '3', 'Female', ' ', '0']
# length of data: 12 --> value list: ['75 or over', 'Other', '9/23/2010', 'warfarin (bulk) 100  powder', '144731', '2', '2', "FALLING AND DON\\T REALISE IT'", '1', 'Female', ' ', '0']
# length of data: 12 --> value list: ['35-44', 'Other', '1/6/2009', 'warfarin (bulk) 100  powder', '144731', '1', '1', 'My grandfather was prescribed this medication (Coumadin) to assist in blood thinning due to a heart and thyroid condition.  His primary doctor was aware that he was on an aspirin regiment and still prescribed this medicine, it caused his blood to thin out to much and he ended up internally bleeding to death.  If you are going to take this medicine please ask your doctors about possible side effects or drug interactions.', '1', 'Male', ' ', '1']
# length of data: 12 --> value list: ['55-64', 'Other', '7/19/2008', 'warfarin (bulk) 100  powder', '144731', '4', '4', 'help heart condition operation well', '4', 'Male', ' ', '0']
# length of data: 13 --> value list: ['25-34', 'Birth Control', '6/15/2017', 'wymzya fe', '163180', '5', '5', "Haven\\t gotten pregnant so it does it\\'s job. I was switched to this brand from another generic. I get nauseous and generally feel tired on this", " also more headaches.'", '2', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, swelling of the  ankles /feet (fluid retention), or  weight  change may occur.', '0']
# length of data: 12 --> value list: ['45-54', 'Disease of Ovaries with Cysts', '1/30/2017', 'wymzya fe', '163180', '5', '5', 'I have take this for 5 years age 45-50 to prevent ovarian cysts (I had 2 burst). Now stopped because of age. No side effects. ', '5', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, swelling of the  ankles /feet (fluid retention), or  weight  change may occur.', '0']
# length of data: 12 --> value list: ['25-34', 'Acne', '4/27/2016', 'wymzya fe', '163180', '4', '2', ' ', '2', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, swelling of the  ankles /feet (fluid retention), or  weight  change may occur.', '1']
# length of data: 12 --> value list: ['55-64', 'Stuffy Nose', '10/29/2012', '12 hour nasal relief spray, non-aerosol', '9800', '4', '2', 'The 12 hour spray only works for me for 6 hours.', '2', 'Male', 'Temporary burning, stinging, dryness in the nose,  runny nose , and  sneezing  may occur.', '0']

# %%
messy_data = []
true_data = []
with open(DATASET_PATH, 'r') as file:
    for idx, line in enumerate(file):
        if line.strip() == '@DATA':
            break

    reader = csv.reader(file, delimiter=',', quotechar="'", doublequote=True)
    for idx, row in enumerate(reader):
        if len(row) != 12: # the number of attributes is 12, so if the length of the list is not equal to 12, then something is wrong.
            messy_data.append(row)
        else:
            true_data.append(row)

# %%
print(f'Number of True data: {len(true_data)}')
print(f'Number of Messy data: {len(messy_data)}')
# Out:
# Number of True data: 297967
# Number of Messy data: 64839

# %%
for value in true_data[:5]:
    print(f'length of data: {len(value)} --> value list: {value}')
# Out:
# length of data: 12 --> value list: ['75 or over', 'Stuffy Nose', '9/21/2014', '25dph-7.5peh', '146724', '5', '5', "I\\m a retired physician and of all the meds I have tried for my allergies (seasonal and not) - this one is the most effective for me.  When I first began using this drug some years ago - tiredness as a problem but is not currently.'", '5', 'Male', 'Drowsiness,  dizziness ,  dry mouth /nose/throat,  headache ,  upset stomach ,  constipation , or  trouble sleeping  may occur.', '0']
# length of data: 12 --> value list: ['25-34', 'Cold Symptoms', '1/13/2011', '25dph-7.5peh', '146724', '5', '5', 'cleared me right up even with my throat hurting it went away after taking the medicine', '5', 'Female', 'Drowsiness,  dizziness ,  dry mouth /nose/throat,  headache ,  upset stomach ,  constipation , or  trouble sleeping  may occur.', '1']
# length of data: 12 --> value list: ['65-74', 'Other', '7/16/2012', 'warfarin (bulk) 100  powder', '144731', '2', '3', 'why did my PTINR go from a normal of 2.5 to over \\n100?', '3', 'Female', ' ', '0']
# length of data: 12 --> value list: ['75 or over', 'Other', '9/23/2010', 'warfarin (bulk) 100  powder', '144731', '2', '2', "FALLING AND DON\\T REALISE IT'", '1', 'Female', ' ', '0']
# length of data: 12 --> value list: ['35-44', 'Other', '1/6/2009', 'warfarin (bulk) 100  powder', '144731', '1', '1', 'My grandfather was prescribed this medication (Coumadin) to assist in blood thinning due to a heart and thyroid condition.  His primary doctor was aware that he was on an aspirin regiment and still prescribed this medicine, it caused his blood to thin out to much and he ended up internally bleeding to death.  If you are going to take this medicine please ask your doctors about possible side effects or drug interactions.', '1', 'Male', ' ', '1']

# %%
for value in messy_data[:5]:
    fix_length_data = value[:7] + [''.join(value[7:-4])] + value[-4:]
    print(f'length of data: {len(value)} --> value list: {value}')
    print(f'length of fix data: {len(fix_length_data)} --> value list: {fix_length_data}')
    print()

print()
fix_data = []
for value in messy_data:
    fix_length_data = value[:7] + [''.join(value[7:-4])] + value[-4:]
    fix_data.append(fix_length_data)
# Out:
# length of data: 13 --> value list: ['25-34', 'Birth Control', '6/15/2017', 'wymzya fe', '163180', '5', '5', "Haven\\t gotten pregnant so it does it\\'s job. I was switched to this brand from another generic. I get nauseous and generally feel tired on this", " also more headaches.'", '2', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, swelling of the  ankles /feet (fluid retention), or  weight  change may occur.', '0']
# length of fix data: 12 --> value list: ['25-34', 'Birth Control', '6/15/2017', 'wymzya fe', '163180', '5', '5', "Haven\\t gotten pregnant so it does it\\'s job. I was switched to this brand from another generic. I get nauseous and generally feel tired on this also more headaches.'", '2', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, swelling of the  ankles /feet (fluid retention), or  weight  change may occur.', '0']
#
# length of data: 17 --> value list: ['25-34', 'Birth Control', '10/7/2017', 'lyza', '164750', '1', '1', "LYZA BIRTH CONTROL\\nThese are the WORST birth control pills I have ever taken!  I\\ve only been taking them for a couple of weeks and I feel like a crazy person.  I\\'ve been crying", ' (for no reason)', ' been super depressed', ' my anxiety is terrible', " along with daily headaches and break outs.   I realize everyone\\'s body reacts differently to medication", "  but I\\'ve read nothing but negative reviews.  I can surely attest to that.  I wouldn\\'t advise anyone to take these.   Absolutely awful.\\n'", '1', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, or  weight  gain may occur.', '1']
# length of fix data: 12 --> value list: ['25-34', 'Birth Control', '10/7/2017', 'lyza', '164750', '1', '1', "LYZA BIRTH CONTROL\\nThese are the WORST birth control pills I have ever taken!  I\\ve only been taking them for a couple of weeks and I feel like a crazy person.  I\\'ve been crying (for no reason) been super depressed my anxiety is terrible along with daily headaches and break outs.   I realize everyone\\'s body reacts differently to medication  but I\\'ve read nothing but negative reviews.  I can surely attest to that.  I wouldn\\'t advise anyone to take these.   Absolutely awful.\\n'", '1', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, or  weight  gain may occur.', '1']
#
# length of data: 13 --> value list: ['25-34', 'Birth Control', '1/30/2017', 'lyza', '164750', '5', '5', 'I have been taking Lyza for two months now. I was very anxious about going back on the pill after have an IUD for the past several years. I have noticed acne which I have never had before, but nothing extreme. I eat healthy and exercise about three times a week, I haven\\t noticed any water weight or bloating. Other than the mild acne', " I\\'m pretty happy. '", '4', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, or  weight  gain may occur.', '1']
# length of fix data: 12 --> value list: ['25-34', 'Birth Control', '1/30/2017', 'lyza', '164750', '5', '5', "I have been taking Lyza for two months now. I was very anxious about going back on the pill after have an IUD for the past several years. I have noticed acne which I have never had before, but nothing extreme. I eat healthy and exercise about three times a week, I haven\\t noticed any water weight or bloating. Other than the mild acne I\\'m pretty happy. '", '4', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, or  weight  gain may occur.', '1']
#
# length of data: 13 --> value list: ['35-44', 'Birth Control', '5/6/2016', 'lyza', '164750', '5', '5', "I took this pill for a month. It was so awful that I can\\t take it any more. The mood swings are 10 times worse than I\\'ve ever experienced before. I eat really healthy and I\\'m very active but had so much bloating and a fair amount of weight gain. I had less cramping but 7 days of heavy bleeding. The nausea was unbearable most of the time. While this pill was effective", " the side effects were so horrible that I quit taking it. My husband and I decided one more baby and then sterilization. No more pills!'", '1', ' ', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, or  weight  gain may occur.', '3']
# length of fix data: 12 --> value list: ['35-44', 'Birth Control', '5/6/2016', 'lyza', '164750', '5', '5', "I took this pill for a month. It was so awful that I can\\t take it any more. The mood swings are 10 times worse than I\\'ve ever experienced before. I eat really healthy and I\\'m very active but had so much bloating and a fair amount of weight gain. I had less cramping but 7 days of heavy bleeding. The nausea was unbearable most of the time. While this pill was effective the side effects were so horrible that I quit taking it. My husband and I decided one more baby and then sterilization. No more pills!'", '1', ' ', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, or  weight  gain may occur.', '3']
#
# length of data: 14 --> value list: ['25-34', 'Birth Control', '4/29/2016', 'lyza', '164750', '5', '5', 'My OB/GYN placed me on this pill because I was at risk for a stroke while being on estrogen birth controls. I have been taking this medication for 2 months with no side effects: migraines have stopped, no acne, no mood swings, no weight gain, no spotting, and sex drive is still intact. The first month of taking this pill my period was extremely light (almost nonexistant) and lasted only two days. This month I didn\\t have a period and took a pregnancy test', ' it was negative. I read reviews that this is normal while taking this pill... Not sure if I like this factor? All in all', " i\\'m pretty pleased with this birth control. Please note that this is a progestin only pill and it is important to take at it at the same time daily.'", '4', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, or  weight  gain may occur.', '10']
# length of fix data: 12 --> value list: ['25-34', 'Birth Control', '4/29/2016', 'lyza', '164750', '5', '5', "My OB/GYN placed me on this pill because I was at risk for a stroke while being on estrogen birth controls. I have been taking this medication for 2 months with no side effects: migraines have stopped, no acne, no mood swings, no weight gain, no spotting, and sex drive is still intact. The first month of taking this pill my period was extremely light (almost nonexistant) and lasted only two days. This month I didn\\t have a period and took a pregnancy test it was negative. I read reviews that this is normal while taking this pill... Not sure if I like this factor? All in all i\\'m pretty pleased with this birth control. Please note that this is a progestin only pill and it is important to take at it at the same time daily.'", '4', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, or  weight  gain may occur.', '10']
#
# length of data: 14 --> value list: ['19-24', 'Birth Control', '1/20/2016', 'lyza', '164750', '5', '5', 'I started taking Lyza birth control because the combined pill I was on previously (Aubra) was causing me to get migraines. Since I\\ve been on Lyza I have noticed that I have been VERY bloated. Also I have never had back acne before and now I do', ' but it is very mild. Not to mention I have had one period since I have been on this pill. I got a period after the first month and I have taken several pregnancy tests that all come up negative. Also...I have been totally moody. I constantly think my period is coming', " but it never does. BUT on the bright side I don\\'t get migraines anymore.'", '3', ' ', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, or  weight  gain may occur.', '5']
# length of fix data: 12 --> value list: ['19-24', 'Birth Control', '1/20/2016', 'lyza', '164750', '5', '5', "I started taking Lyza birth control because the combined pill I was on previously (Aubra) was causing me to get migraines. Since I\\ve been on Lyza I have noticed that I have been VERY bloated. Also I have never had back acne before and now I do but it is very mild. Not to mention I have had one period since I have been on this pill. I got a period after the first month and I have taken several pregnancy tests that all come up negative. Also...I have been totally moody. I constantly think my period is coming but it never does. BUT on the bright side I don\\'t get migraines anymore.'", '3', ' ', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, or  weight  gain may occur.', '5']
#
# length of data: 17 --> value list: ['19-24', 'Birth Control', '12/7/2015', 'lyza', '164750', '5', '5', 'I switched from the Mirena to Lyza and the relief from horrendous cramps was amazing and instantaneous. However, I have noticed slight weight gain (about 5 pounds), and have had severely tender breasts. Sometimes it will last over 1 month and they are sore to the point that moving my arms makes me cringe. The only other major side effect has been frequent bleeding and much heavier periods than usual.  I normally have a fairly light, short period (2 days normal bleeding, 1-2 of spotting). But there have been two occasions since starting Lyza in which I have woken up in a pool of blood on the bed because the bleeding is so heavy and unexpected. There has been some bloating as well, but I\\m not sure if that is due to the pill because I had the same issue with Mirena. I have my suspicions about ovarian cysts', ' so that could be causing the bloating', ' breast tenderness', ' and abnormal bleeding. I rated ease of use as one star because it has been very difficult for me to remember to take the pill on time even though I set an alarm on my phone. However', " it is still effective because I haven\\'t gotten pregnant yet. I just make sure to use back up protection", " or abstain for 3 days after taking a pill late. '", '3', ' ', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, or  weight  gain may occur.', '1']
# length of fix data: 12 --> value list: ['19-24', 'Birth Control', '12/7/2015', 'lyza', '164750', '5', '5', "I switched from the Mirena to Lyza and the relief from horrendous cramps was amazing and instantaneous. However, I have noticed slight weight gain (about 5 pounds), and have had severely tender breasts. Sometimes it will last over 1 month and they are sore to the point that moving my arms makes me cringe. The only other major side effect has been frequent bleeding and much heavier periods than usual.  I normally have a fairly light, short period (2 days normal bleeding, 1-2 of spotting). But there have been two occasions since starting Lyza in which I have woken up in a pool of blood on the bed because the bleeding is so heavy and unexpected. There has been some bloating as well, but I\\m not sure if that is due to the pill because I had the same issue with Mirena. I have my suspicions about ovarian cysts so that could be causing the bloating breast tenderness and abnormal bleeding. I rated ease of use as one star because it has been very difficult for me to remember to take the pill on time even though I set an alarm on my phone. However it is still effective because I haven\\'t gotten pregnant yet. I just make sure to use back up protection or abstain for 3 days after taking a pill late. '", '3', ' ', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, or  weight  gain may occur.', '1']
#
# length of data: 13 --> value list: ['35-44', 'Abnormally Long or Heavy Periods', '9/12/2017', 'lysteda', '154120', '5', '4', 'Not a miracle, but a definite game changer. The pain is still strong, but not to the point where I can\\t stand up anymore. Give it time. The first few months there was little change', " but after several months it really made a difference. '", '4', 'Female', 'Nausea ,  vomiting ,  diarrhea , and  muscle pain  may occur.', '0']
# length of fix data: 12 --> value list: ['35-44', 'Abnormally Long or Heavy Periods', '9/12/2017', 'lysteda', '154120', '5', '4', "Not a miracle, but a definite game changer. The pain is still strong, but not to the point where I can\\t stand up anymore. Give it time. The first few months there was little change but after several months it really made a difference. '", '4', 'Female', 'Nausea ,  vomiting ,  diarrhea , and  muscle pain  may occur.', '0']
#
# length of data: 15 --> value list: ['35-44', 'Abnormally Long or Heavy Periods', '3/4/2016', 'lysteda', '154120', '1', '1', 'I have experienced very heavy and long periods (12-14 days with a period, 14-16 days without each and every month) for the past three years. I\\m always very reluctant to seek medical help', " but I finally got my answer: an overgrown endometrium (endometrial hyperplasia). I wanted to try this product because it\\'s non-hormonal. This is my second month using this product", " and it doesn\\'t work for me. The first month I had my usual ridiculously heavy flow for five days of my 14-day period. I thought maybe it was a fluke and that I should try again. That was a waste of money. I\\'ll be going back to the doctor to see if she can possibly recommend treatment for the cause of my problem instead of seeking to simply treat the symptoms", " which in my case didn\\'t treat them anyway.   '", '1', ' ', 'Nausea ,  vomiting ,  diarrhea , and  muscle pain  may occur.', '3']
# length of fix data: 12 --> value list: ['35-44', 'Abnormally Long or Heavy Periods', '3/4/2016', 'lysteda', '154120', '1', '1', "I have experienced very heavy and long periods (12-14 days with a period, 14-16 days without each and every month) for the past three years. I\\m always very reluctant to seek medical help but I finally got my answer: an overgrown endometrium (endometrial hyperplasia). I wanted to try this product because it\\'s non-hormonal. This is my second month using this product and it doesn\\'t work for me. The first month I had my usual ridiculously heavy flow for five days of my 14-day period. I thought maybe it was a fluke and that I should try again. That was a waste of money. I\\'ll be going back to the doctor to see if she can possibly recommend treatment for the cause of my problem instead of seeking to simply treat the symptoms which in my case didn\\'t treat them anyway.   '", '1', ' ', 'Nausea ,  vomiting ,  diarrhea , and  muscle pain  may occur.', '3']
#
# length of data: 15 --> value list: ['45-54', 'Abnormally Long or Heavy Periods', '1/2/2016', 'lysteda', '154120', '4', '4', 'I have adenomyosis, and a failed oblation, with very heavy periods.I am 52 and not close to menopause yet and have resisted having a hysterectomy bacause my uterus is too big for the easier type of surgery.  I have used Lysteda for two cycles, and so far, I think it is working and I\\m pleased.  I was able to go to a 7am yoga class on morning three and have no problems!!  I do think I might be experiencing some back pain as a side effect', ' and I did have a very heavy day 6 which was unusual. I think you may have to be very consistent about taking three doses a day for the five days.  I will try to come back and update this review after a couple more months', ' but if I continue like this', " I will be very happy to continue getting a cycle and avoiding menopause for a little longer!'", '4', 'Female', 'Nausea ,  vomiting ,  diarrhea , and  muscle pain  may occur.', '6']
# length of fix data: 12 --> value list: ['45-54', 'Abnormally Long or Heavy Periods', '1/2/2016', 'lysteda', '154120', '4', '4', "I have adenomyosis, and a failed oblation, with very heavy periods.I am 52 and not close to menopause yet and have resisted having a hysterectomy bacause my uterus is too big for the easier type of surgery.  I have used Lysteda for two cycles, and so far, I think it is working and I\\m pleased.  I was able to go to a 7am yoga class on morning three and have no problems!!  I do think I might be experiencing some back pain as a side effect and I did have a very heavy day 6 which was unusual. I think you may have to be very consistent about taking three doses a day for the five days.  I will try to come back and update this review after a couple more months but if I continue like this I will be very happy to continue getting a cycle and avoiding menopause for a little longer!'", '4', 'Female', 'Nausea ,  vomiting ,  diarrhea , and  muscle pain  may occur.', '6']

# %%
concat_data = true_data + fix_data

# %%
print(f'Number of full data: {len(concat_data)}')
# Out:
# Number of full data: 362807

# %%
columns = [
    'Age', 
    'Condition', 
    'Date', 
    'Drug', 
    'DrugId', 
    'EaseofUse', 
    'Effectiveness', 
    'Reviews', 
    'Satisfaction', 
    'Sex', 
    'Sides', 
    'UsefulCount'
]

# %%
df = pd.DataFrame(concat_data)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 df = pd.DataFrame(concat_data)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:806, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     804     if columns is not None:
#     805         columns = ensure_index(columns)
# --> 806     arrays, columns, index = nested_data_to_arrays(
#     807         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     808         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#     809         data,
#     810         columns,
#     811         index,  # type: ignore[arg-type]
#     812         dtype,
#     813     )
#     814     mgr = arrays_to_mgr(
#     815         arrays,
#     816         columns,
#    (...)
#     819         typ=manager,
#     820     )
#     821 else:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\internals\construction.py:520, in nested_data_to_arrays(data, columns, index, dtype)
#     517 if is_named_tuple(data[0]) and columns is None:
#     518     columns = ensure_index(data[0]._fields)
# --> 520 arrays, columns = to_arrays(data, columns, dtype=dtype)
#     521 columns = ensure_index(columns)
#     523 if index is None:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\internals\construction.py:835, in to_arrays(data, columns, dtype)
#     832     return arrays, columns
#     834 if isinstance(data[0], (list, tuple)):
# --> 835     arr = _list_to_arrays(data)
#     836 elif isinstance(data[0], abc.Mapping):
#     837     arr, columns = _list_of_dict_to_arrays(data, columns)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\internals\construction.py:856, in _list_to_arrays(data)
#     853     content = lib.to_object_array_tuples(data)
#     854 else:
#     855     # list of lists
# --> 856     content = lib.to_object_array(data)
#     857 return content
#
# File lib.pyx:2966, in pandas._libs.lib.to_object_array()
#
# MemoryError: Unable to allocate 175. GiB for an array with shape (362807, 64839) and data type object

# %%
final_data = []
exper_data = []
columns = [
    'Age', 
    'Condition', 
    'Date', 
    'Drug', 
    'DrugId', 
    'EaseofUse', 
    'Effectiveness', 
    'Reviews', 
    'Satisfaction', 
    'Sex', 
    'Sides', 
    'UsefulCount'
]

with open(DATASET_PATH, 'r') as file:
    # Skip lines until the '@DATA' line
    for line in file:
        if line.strip() == '@DATA':
            break
        
    # Read the actual data lines
    reader = csv.reader(file, delimiter=',', quotechar="'", doublequote=True)
    for idx, row in enumerate(reader):
        data_prep=row[:7] + [''.join(row[7:-4])] + row[-4:]
        sex_value = data_prep[-3].strip()

        # print(row[:7])

        if (re.fullmatch(r'male|female', sex_value, flags=re.I)) or (sex_value == ''):
            final_data.append(data_prep)
            # print(data_prep[-3:])
        else:
            exper_data.append(data_prep)
            # print(data_prep[-3:])
            # print()

# %%
df = pd.DataFrame(final_data, columns=columns)

# %%
df[:5]
# Out:
#           Age      Condition       Date                         Drug  DrugId  \
# 0  75 or over    Stuffy Nose  9/21/2014                 25dph-7.5peh  146724
# 1       25-34  Cold Symptoms  1/13/2011                 25dph-7.5peh  146724
# 2       65-74          Other  7/16/2012  warfarin (bulk) 100  powder  144731
# 3  75 or over          Other  9/23/2010  warfarin (bulk) 100  powder  144731
# 4       35-44          Other   1/6/2009  warfarin (bulk) 100  powder  144731
#
#   EaseofUse Effectiveness                                            Reviews  \
# 0         5             5  I\m a retired physician and of all the meds I ...
# 1         5             5  cleared me right up even with my throat hurtin...
# 2         2             3  why did my PTINR go from a normal of 2.5 to ov...
# 3         2             2                      FALLING AND DON\T REALISE IT'
# 4         1             1  My grandfather was prescribed this medication ...
#
#   Satisfaction     Sex                                              Sides  \
# 0            5    Male  Drowsiness,  dizziness ,  dry mouth /nose/thro...
# 1            5  Female  Drowsiness,  dizziness ,  dry mouth /nose/thro...
# 2            3  Female
# 3            1  Female
# 4            1    Male
#
#   UsefulCount
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362639 entries, 0 to 362638
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Age            362639 non-null  object
#  1   Condition      362639 non-null  object
#  2   Date           362639 non-null  object
#  3   Drug           362639 non-null  object
#  4   DrugId         362639 non-null  object
#  5   EaseofUse      362639 non-null  object
#  6   Effectiveness  362639 non-null  object
#  7   Reviews        362639 non-null  object
#  8   Satisfaction   362639 non-null  object
#  9   Sex            362639 non-null  object
#  10  Sides          362639 non-null  object
#  11  UsefulCount    362639 non-null  object
# dtypes: object(12)
# memory usage: 399.5 MB

# %%
df.nunique()
# Out:
# Age                  12
# Condition          1806
# Date               4525
# Drug               7096
# DrugId             6573
# EaseofUse            13
# Effectiveness         7
# Reviews          250042
# Satisfaction          7
# Sex                   3
# Sides              1651
# UsefulCount         148
# dtype: int64

# %%
display(df['Age'].value_counts())
display(df['EaseofUse'].value_counts())
display(df['Effectiveness'].value_counts())
display(df['Satisfaction'].value_counts())
display(df['Sex'].value_counts())
# Out:
# Age
# 45-54         80007
# 55-64         75075
# 35-44         54982
# 25-34         49707
# 65-74         41201
# 19-24         24229
# 75 or over    15218
#               12201
# 13-18          7040
# 7-12           1644
# 3-6             838
# 0-2             497
# Name: count, dtype: int64
# EaseofUse
# 5         192527
# 4          74708
# 3          41286
# 1          35906
# 2          18179
# 62261         18
# 154215         6
# 11147          3
# 6              2
# 10149          1
# 10             1
# 169930         1
# 57948          1
# Name: count, dtype: int64
# Effectiveness
# 5     130321
# 4      81785
# 3      60386
# 1      59354
# 2      30790
# 6          2
# 10         1
# Name: count, dtype: int64
# Satisfaction
# 5     111487
# 1     100856
# 4      63128
# 3      51837
# 2      35328
# 6          2
# 10         1
# Name: count, dtype: int64
# Sex
# Female    238119
# Male       98000
#            26520
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# Age              0
# Condition        0
# Date             0
# Drug             0
# DrugId           0
# EaseofUse        0
# Effectiveness    0
# Reviews          0
# Satisfaction     0
# Sex              0
# Sides            0
# UsefulCount      0
# dtype: int64

# %%
# df[['Condition', 'Date', 'Drug', 'DrugId', 'EaseofUse', 'Effectiveness']].sample(n=40)
df[['Drug']].sample(n=50)
# Out:
#                                                      Drug
# 63455                                   nexplanon implant
# 262021                                         effexor xr
# 264420                                             gianvi
# 199713                                    terbinafine hcl
# 113725                                         prefera ob
# 46090                                             norvasc
# 126658                                    pepcid complete
# 312006                                            benicar
# 95247                                       metformin hcl
# 356799                                           celebrex
# 250935                              acetaminophen-codeine
# 123876                                 pravastatin sodium
# 282136               fentanyl patch, transdermal 72 hours
# 67843                                             niaspan
# 88107   methylphenidate er tablet, extended release 24 hr
# 279565                                             fanapt
# 23486                                               lasix
# 304695                                           klonopin
# 255478                                             evista
# 51246                             oxycodone-acetaminophen
# 16476                                          lisinopril
# 37488                                             levitra
# 8475                                            lorazepam
# 225240                                      alprazolam er
# 173128                                             zoloft
# 346789                       clobetasol propionate lotion
# 44893                                          np thyroid
# 155987                                 sitagliptin tablet
# 258263                                        entocort ec
# 19440                                             linzess
# 214018                                           vistaril
# 75418                           morphine sulfate solution
# 235345                     analpram-hc 1 -1  rectal cream
# 152706                          skyla intrauterine device
# 183222                                      trazodone hcl
# 85835                              metformin hcl solution
# 191272                     topiramate (bulk) 99.7  powder
# 16692                                          lisinopril
# 133581                                             plavix
# 34787                                             lexapro
# 21336   lupron depot (3 month) 22.5 mg intramuscular s...
# 191807                                         topiramate
# 29148                                levothyroxine sodium
# 224014                                     alprazolam odt
# 325978                                           dexilant
# 244950                 actonel tablet osteoporosis agents
# 98557                                         misoprostol
# 332583                                    dicyclomine hcl
# 285232                                  hydromorphone hcl
# 207750                                             ultram

# %%
# df[df['Reviews'].str.match(r'^\d{1,}[a-z]')]

# %%
display(df['EaseofUse'].value_counts())
# Out:
# EaseofUse
# 5         192527
# 4          74708
# 3          41286
# 1          35906
# 2          18179
# 62261         18
# 154215         6
# 11147          3
# 6              2
# 10149          1
# 10             1
# 169930         1
# 57948          1
# Name: count, dtype: int64

# %%
prep_df = df[df['EaseofUse'].isin(['62261', '154215', '11147', '10149', '169930', '57948'])]

# %%
prep_df[:10]
# Out:
#                Age                                          Condition  \
# 127375       55-64  Treatment of Depletion of Body\s Supply of Sodium
# 127377       45-54  Treatment of Depletion of Body\s Supply of Sodium
# 127378       25-34  Treatment of Depletion of Body\s Supply of Sodium
# 174145  75 or over  Treatment of Depletion of Body\s Supply of Sodium
# 307059       55-64                                      Plantar Warts
# 307060       25-34                                      Plantar Warts
# 307061       19-24                                               Corn
# 307062       19-24                                        Common Wart
# 307063       55-64                                      Plantar Warts
# 307066       25-34                                        Common Wart
#
#                             Date                                   Drug  \
# 127375   Potassium and Chloride'                              4/25/2016
# 127377   Potassium and Chloride'                              4/26/2014
# 127378   Potassium and Chloride'                               4/5/2014
# 174145   Potassium and Chloride'                               8/6/2009
# 307059                12/16/2016  dr scholl\s clear away adhesive patch
# 307060                  3/6/2014  dr scholl\s clear away adhesive patch
# 307061                  2/8/2013  dr scholl\s clear away adhesive patch
# 307062                 1/29/2012  dr scholl\s clear away adhesive patch
# 307063                 7/26/2011  dr scholl\s clear away adhesive patch
# 307066                 4/22/2011  dr scholl\s clear away adhesive patch
#
#                          DrugId EaseofUse Effectiveness  \
# 127375  pedialyte oral solution     11147             3
# 127377  pedialyte oral solution     11147             5
# 127378  pedialyte oral solution     11147             3
# 174145                      yte     10149             4
# 307059               medicated'    154215             1
# 307060               medicated'    154215             2
# 307061               medicated'    154215             5
# 307062               medicated'    154215             4
# 307063               medicated'    154215             2
# 307066               medicated'    154215             3
#
#                                                   Reviews Satisfaction  \
# 127375  3After small bowel resection, I had diarrhea a...            1
# 127377  4Felt once I drank this liquid I felt more ene...            5
# 127378  2my 2 yr old son has been sick with diarhea an...            1
# 174145  5I have low sodium and this has helped, altho ...            4
# 307059  1small discs did not stay in place - pads were...            1
# 307060  2I have used Dr. Scholl\s salicylic acid and t...            1
# 307061  4I\ve had a small hard corn on both of my pink...            3
# 307062  5I had two common warts on my hands and used D...            5
# 307063  1Medicated pads do not adhere well to skin and...            1
# 307066  2it will take the wart way for about 6 weeks t...            1
#
#            Sex                                              Sides UsefulCount
# 127375                      Mild  nausea and vomiting  may occur.           0
# 127377  Female              Mild  nausea and vomiting  may occur.           1
# 127378  Female              Mild  nausea and vomiting  may occur.           1
# 174145  Female              Mild  nausea and vomiting  may occur.           1
# 307059    Male  Slight burning,  skin  redness, and peeling ma...           2
# 307060  Female  Slight burning,  skin  redness, and peeling ma...           3
# 307061  Female  Slight burning,  skin  redness, and peeling ma...           1
# 307062  Female  Slight burning,  skin  redness, and peeling ma...           0
# 307063    Male  Slight burning,  skin  redness, and peeling ma...           2
# 307066  Female  Slight burning,  skin  redness, and peeling ma...           1

# %%
prep_df.iloc[:4].loc[:, 'Condition'] = prep_df[:4]['Condition'] + '' +  prep_df[:4]['Date']
prep_df.iloc[:4].loc[:, 'Date'] = prep_df[:4]['Drug']
prep_df.iloc[:4].loc[:, 'Drug'] = prep_df[:4]['DrugId']
prep_df.iloc[:4].loc[:, 'DrugId'] = prep_df[:4]['EaseofUse']

# %%
prep_df[:15]
# Out:
#                Age                                          Condition  \
# 127375       55-64  Treatment of Depletion of Body\s Supply of Sod...
# 127377       45-54  Treatment of Depletion of Body\s Supply of Sod...
# 127378       25-34  Treatment of Depletion of Body\s Supply of Sod...
# 174145  75 or over  Treatment of Depletion of Body\s Supply of Sod...
# 307059       55-64                                      Plantar Warts
# 307060       25-34                                      Plantar Warts
# 307061       19-24                                               Corn
# 307062       19-24                                        Common Wart
# 307063       55-64                                      Plantar Warts
# 307066       25-34                                        Common Wart
# 350975       45-54                                  Skin Disinfection
# 350976  75 or over                                              Other
# 350977       55-64                                  Skin Disinfection
# 350983       45-54                                  Skin Disinfection
# 350984       55-64                                              Other
#
#               Date                                   Drug       DrugId  \
# 127375   4/25/2016                pedialyte oral solution        11147
# 127377   4/26/2014                pedialyte oral solution        11147
# 127378    4/5/2014                pedialyte oral solution        11147
# 174145    8/6/2009                                    yte        10149
# 307059  12/16/2016  dr scholl\s clear away adhesive patch   medicated'
# 307060    3/6/2014  dr scholl\s clear away adhesive patch   medicated'
# 307061    2/8/2013  dr scholl\s clear away adhesive patch   medicated'
# 307062   1/29/2012  dr scholl\s clear away adhesive patch   medicated'
# 307063   7/26/2011  dr scholl\s clear away adhesive patch   medicated'
# 307066   4/22/2011  dr scholl\s clear away adhesive patch   medicated'
# 350975    5/7/2019                       dakin\s solution        non-'
# 350976   7/20/2015                       dakin\s solution        non-'
# 350977  10/15/2014                       dakin\s solution        non-'
# 350983   5/30/2014                       dakin\s solution        non-'
# 350984  12/20/2013                       dakin\s solution        non-'
#
#        EaseofUse Effectiveness  \
# 127375     11147             3
# 127377     11147             5
# 127378     11147             3
# 174145     10149             4
# 307059    154215             1
# 307060    154215             2
# 307061    154215             5
# 307062    154215             4
# 307063    154215             2
# 307066    154215             3
# 350975     62261             5
# 350976     62261             1
# 350977     62261             5
# 350983     62261             5
# 350984     62261             5
#
#                                                   Reviews Satisfaction  \
# 127375  3After small bowel resection, I had diarrhea a...            1
# 127377  4Felt once I drank this liquid I felt more ene...            5
# 127378  2my 2 yr old son has been sick with diarhea an...            1
# 174145  5I have low sodium and this has helped, altho ...            4
# 307059  1small discs did not stay in place - pads were...            1
# 307060  2I have used Dr. Scholl\s salicylic acid and t...            1
# 307061  4I\ve had a small hard corn on both of my pink...            3
# 307062  5I had two common warts on my hands and used D...            5
# 307063  1Medicated pads do not adhere well to skin and...            1
# 307066  2it will take the wart way for about 6 weeks t...            1
# 350975  5My mother has stage 4 breast cancer. Lowered ...            5
# 350976  1I had an accident resulting in a wound on my ...            1
# 350977  5Following surgery in February 2014 on left fo...            5
# 350983  5I had lung surgery and developed a wound infe...            5
# 350984  5Had MRSA in stasis ulcer (have had this ulcer...            5
#
#            Sex                                              Sides UsefulCount
# 127375                      Mild  nausea and vomiting  may occur.           0
# 127377  Female              Mild  nausea and vomiting  may occur.           1
# 127378  Female              Mild  nausea and vomiting  may occur.           1
# 174145  Female              Mild  nausea and vomiting  may occur.           1
# 307059    Male  Slight burning,  skin  redness, and peeling ma...           2
# 307060  Female  Slight burning,  skin  redness, and peeling ma...           3
# 307061  Female  Slight burning,  skin  redness, and peeling ma...           1
# 307062  Female  Slight burning,  skin  redness, and peeling ma...           0
# 307063    Male  Slight burning,  skin  redness, and peeling ma...           2
# 307066  Female  Slight burning,  skin  redness, and peeling ma...           1
# 350975  Female  Redness, irritation, swelling, and pain may oc...           1
# 350976  Female  Redness, irritation, swelling, and pain may oc...           1
# 350977    Male  Redness, irritation, swelling, and pain may oc...           8
# 350983  Female  Redness, irritation, swelling, and pain may oc...           8
# 350984  Female  Redness, irritation, swelling, and pain may oc...           1

# %%
Effectiveness = []
Reviews = []

for idx, value in enumerate(prep_df['Reviews']):
    match = re.match(r'(\d+)(.*)', value)
    # if idx >= 10:
    #     break
    # print(match.group(1), match.group(2))

    Effectiveness.append(match.group(1))
    Reviews.append(match.group(2))

# %%
Effectiveness[:5], Reviews[:5]
# Out:
# (['3', '4', '2', '5', '1'],
#  ["After small bowel resection, I had diarrhea and nausea. My doctor recommended Pedialyte but the taste is so nasty I can\\t drink it. Why do you make it so sweet and fake? It coats my mouth with sugar and red dye. Doesn\\'t sound very therapeutic to me. Ugh'",
#   'Felt once I drank this liquid I felt more energized, my body was functioning better, and felt like my body was filling up in a goodway, like my pores were happy to be receiving such vitamins and help',
#   'my 2 yr old son has been sick with diarhea and did not want to continue drinking this product. ive insisted that he keep drinking and during dinner he vomitted ALL of the liquid that was in his stomach. i will not be giving this to him again. he has experienced many of the side effects that i think should be CLEARLY printed on the label of this product. i only learned about the side effects from this website. i do not recommend this product for toddlers the side effects are too severe. side effects included: restlessness(up all hours of the night for no reason) ',
#   "I have low sodium and this has helped, altho my sodium is still too low. I don\\t know how much to take - I take 1/2 cup and  am getting a bit tired of the taste. I wish there were a tablet to take instead.'",
#   'small discs did not stay in place - pads were bulky'])

# %%
prep_df.iloc[4:].loc[:, 'Drug'] = prep_df.iloc[4:].loc[:, 'Drug'] + '' + prep_df.iloc[4:].loc[:, 'DrugId'] 
prep_df.iloc[4:].loc[:, 'DrugId'] = prep_df.iloc[4:].loc[:, 'EaseofUse']
prep_df.loc[:, 'EaseofUse'] = prep_df['Effectiveness']
prep_df.loc[:, 'Effectiveness'] = Effectiveness
prep_df.loc[:, 'Reviews'] = Reviews

# %%
prep_df[:15]
# Out:
#                Age                                          Condition  \
# 127375       55-64  Treatment of Depletion of Body\s Supply of Sod...
# 127377       45-54  Treatment of Depletion of Body\s Supply of Sod...
# 127378       25-34  Treatment of Depletion of Body\s Supply of Sod...
# 174145  75 or over  Treatment of Depletion of Body\s Supply of Sod...
# 307059       55-64                                      Plantar Warts
# 307060       25-34                                      Plantar Warts
# 307061       19-24                                               Corn
# 307062       19-24                                        Common Wart
# 307063       55-64                                      Plantar Warts
# 307066       25-34                                        Common Wart
# 350975       45-54                                  Skin Disinfection
# 350976  75 or over                                              Other
# 350977       55-64                                  Skin Disinfection
# 350983       45-54                                  Skin Disinfection
# 350984       55-64                                              Other
#
#               Date                                              Drug  DrugId  \
# 127375   4/25/2016                           pedialyte oral solution   11147
# 127377   4/26/2014                           pedialyte oral solution   11147
# 127378    4/5/2014                           pedialyte oral solution   11147
# 174145    8/6/2009                                               yte   10149
# 307059  12/16/2016  dr scholl\s clear away adhesive patch medicated'  154215
# 307060    3/6/2014  dr scholl\s clear away adhesive patch medicated'  154215
# 307061    2/8/2013  dr scholl\s clear away adhesive patch medicated'  154215
# 307062   1/29/2012  dr scholl\s clear away adhesive patch medicated'  154215
# 307063   7/26/2011  dr scholl\s clear away adhesive patch medicated'  154215
# 307066   4/22/2011  dr scholl\s clear away adhesive patch medicated'  154215
# 350975    5/7/2019                            dakin\s solution non-'   62261
# 350976   7/20/2015                            dakin\s solution non-'   62261
# 350977  10/15/2014                            dakin\s solution non-'   62261
# 350983   5/30/2014                            dakin\s solution non-'   62261
# 350984  12/20/2013                            dakin\s solution non-'   62261
#
#        EaseofUse Effectiveness  \
# 127375         3             3
# 127377         5             4
# 127378         3             2
# 174145         4             5
# 307059         1             1
# 307060         2             2
# 307061         5             4
# 307062         4             5
# 307063         2             1
# 307066         3             2
# 350975         5             5
# 350976         1             1
# 350977         5             5
# 350983         5             5
# 350984         5             5
#
#                                                   Reviews Satisfaction  \
# 127375  After small bowel resection, I had diarrhea an...            1
# 127377  Felt once I drank this liquid I felt more ener...            5
# 127378  my 2 yr old son has been sick with diarhea and...            1
# 174145  I have low sodium and this has helped, altho m...            4
# 307059  small discs did not stay in place - pads were ...            1
# 307060  I have used Dr. Scholl\s salicylic acid and th...            1
# 307061  I\ve had a small hard corn on both of my pinky...            3
# 307062  I had two common warts on my hands and used Dr...            5
# 307063  Medicated pads do not adhere well to skin and ...            1
# 307066  it will take the wart way for about 6 weeks th...            1
# 350975  My mother has stage 4 breast cancer. Lowered i...            5
# 350976  I had an accident resulting in a wound on my l...            1
# 350977  Following surgery in February 2014 on left foo...            5
# 350983  I had lung surgery and developed a wound infec...            5
# 350984  Had MRSA in stasis ulcer (have had this ulcer ...            5
#
#            Sex                                              Sides UsefulCount
# 127375                      Mild  nausea and vomiting  may occur.           0
# 127377  Female              Mild  nausea and vomiting  may occur.           1
# 127378  Female              Mild  nausea and vomiting  may occur.           1
# 174145  Female              Mild  nausea and vomiting  may occur.           1
# 307059    Male  Slight burning,  skin  redness, and peeling ma...           2
# 307060  Female  Slight burning,  skin  redness, and peeling ma...           3
# 307061  Female  Slight burning,  skin  redness, and peeling ma...           1
# 307062  Female  Slight burning,  skin  redness, and peeling ma...           0
# 307063    Male  Slight burning,  skin  redness, and peeling ma...           2
# 307066  Female  Slight burning,  skin  redness, and peeling ma...           1
# 350975  Female  Redness, irritation, swelling, and pain may oc...           1
# 350976  Female  Redness, irritation, swelling, and pain may oc...           1
# 350977    Male  Redness, irritation, swelling, and pain may oc...           8
# 350983  Female  Redness, irritation, swelling, and pain may oc...           8
# 350984  Female  Redness, irritation, swelling, and pain may oc...           1

# %%
df.loc[prep_df.index] = prep_df

# %%
display(df['Age'].value_counts())
display(df['EaseofUse'].value_counts())
display(df['Effectiveness'].value_counts())
display(df['Satisfaction'].value_counts())
display(df['Sex'].value_counts())
# Out:
# Age
# 45-54         80007
# 55-64         75075
# 35-44         54982
# 25-34         49707
# 65-74         41201
# 19-24         24229
# 75 or over    15218
#               12201
# 13-18          7040
# 7-12           1644
# 3-6             838
# 0-2             497
# Name: count, dtype: int64
# EaseofUse
# 5     192545
# 4      74712
# 3      41290
# 1      35908
# 2      18181
# 6          2
# 10         1
# Name: count, dtype: int64
# Effectiveness
# 5     130320
# 4      81785
# 3      60383
# 1      59357
# 2      30791
# 6          2
# 10         1
# Name: count, dtype: int64
# Satisfaction
# 5     111487
# 1     100856
# 4      63128
# 3      51837
# 2      35328
# 6          2
# 10         1
# Name: count, dtype: int64
# Sex
# Female    238119
# Male       98000
#            26520
# Name: count, dtype: int64

# %%
df.nunique()
# Out:
# Age                  12
# Condition          1806
# Date               4524
# Drug               7093
# DrugId             6572
# EaseofUse             7
# Effectiveness         7
# Reviews          250041
# Satisfaction          7
# Sex                   3
# Sides              1651
# UsefulCount         148
# dtype: int64

# %%
df.loc[362351]
# Out:
# Age                                                          35-44
# Condition                                             Stop Smoking
# Date                                                     3/31/2010
# Drug                                                       chantix
# DrugId                                                      144470
# EaseofUse                                                        5
# Effectiveness                                                    5
# Reviews          25 years of smoking. Smoked the first week lik...
# Satisfaction                                                     5
# Sex                                                         Female
# Sides            Nausea ,  headache ,  vomiting , drowsiness, g...
# UsefulCount                                                     16
# Name: 362351, dtype: object

# %%
cleaned_df = df.map(lambda x: np.NaN if re.search(r'^\s*$', x, flags=re.I) else x)

# %%
cleaned_df[:5]
# Out:
#           Age      Condition       Date                         Drug  DrugId  \
# 0  75 or over    Stuffy Nose  9/21/2014                 25dph-7.5peh  146724
# 1       25-34  Cold Symptoms  1/13/2011                 25dph-7.5peh  146724
# 2       65-74          Other  7/16/2012  warfarin (bulk) 100  powder  144731
# 3  75 or over          Other  9/23/2010  warfarin (bulk) 100  powder  144731
# 4       35-44          Other   1/6/2009  warfarin (bulk) 100  powder  144731
#
#   EaseofUse Effectiveness                                            Reviews  \
# 0         5             5  I\m a retired physician and of all the meds I ...
# 1         5             5  cleared me right up even with my throat hurtin...
# 2         2             3  why did my PTINR go from a normal of 2.5 to ov...
# 3         2             2                      FALLING AND DON\T REALISE IT'
# 4         1             1  My grandfather was prescribed this medication ...
#
#   Satisfaction     Sex                                              Sides  \
# 0            5    Male  Drowsiness,  dizziness ,  dry mouth /nose/thro...
# 1            5  Female  Drowsiness,  dizziness ,  dry mouth /nose/thro...
# 2            3  Female                                                NaN
# 3            1  Female                                                NaN
# 4            1    Male                                                NaN
#
#   UsefulCount
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1

# %%
cleaned_df.shape
# Out:
# (362639, 12)

# %%
cleaned_df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362639 entries, 0 to 362638
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Age            350438 non-null  object
#  1   Condition      362596 non-null  object
#  2   Date           362639 non-null  object
#  3   Drug           362639 non-null  object
#  4   DrugId         362639 non-null  object
#  5   EaseofUse      362639 non-null  object
#  6   Effectiveness  362639 non-null  object
#  7   Reviews        320808 non-null  object
#  8   Satisfaction   362639 non-null  object
#  9   Sex            336119 non-null  object
#  10  Sides          345184 non-null  object
#  11  UsefulCount    362639 non-null  object
# dtypes: object(12)
# memory usage: 397.1 MB

# %%
cleaned_df.isna().sum()
# Out:
# Age              12201
# Condition           43
# Date                 0
# Drug                 0
# DrugId               0
# EaseofUse            0
# Effectiveness        0
# Reviews          41831
# Satisfaction         0
# Sex              26520
# Sides            17455
# UsefulCount          0
# dtype: int64

# %%
cleaned_df[cleaned_df['Sides'].isna()]
# Out:
#                Age                                   Condition       Date  \
# 2            65-74                                       Other  7/16/2012
# 3       75 or over                                       Other  9/23/2010
# 4            35-44                                       Other   1/6/2009
# 5            55-64                                       Other  7/19/2008
# 10           65-74                                       Other  3/15/2016
# ...            ...                                         ...        ...
# 361408       25-34  Poisoning from Swallowed Unknown Substance  7/15/2010
# 361409         NaN                                       Other   3/3/2010
# 361410  75 or over                                         Gas  2/12/2009
# 361411       45-54  Poisoning from Swallowed Unknown Substance  11/5/2007
# 361430       19-24                                       Other  10/4/2011
#
#                                Drug  DrugId EaseofUse Effectiveness  \
# 2       warfarin (bulk) 100  powder  144731         2             3
# 3       warfarin (bulk) 100  powder  144731         2             2
# 4       warfarin (bulk) 100  powder  144731         1             1
# 5       warfarin (bulk) 100  powder  144731         4             4
# 10              pyrogallol crystals   12112         5             5
# ...                             ...     ...       ...           ...
# 361408          charcoal, activated     948         3             3
# 361409          charcoal, activated     948         2             2
# 361410          charcoal, activated     948         3             1
# 361411          charcoal, activated     948         5             5
# 361430            chamosyn ointment  153889         1             1
#
#                                                   Reviews Satisfaction  \
# 2       why did my PTINR go from a normal of 2.5 to ov...            3
# 3                           FALLING AND DON\T REALISE IT'            1
# 4       My grandfather was prescribed this medication ...            1
# 5                     help heart condition operation well            4
# 10      Excellent in reducing inlamation associated wi...            5
# ...                                                   ...          ...
# 361408                            It\s helped me before.'            3
# 361409                                                NaN            2
# 361410  It leaves a bad metalic taste in your mouth th...            1
# 361411                                                NaN            5
# 361430                                                NaN            1
#
#            Sex Sides UsefulCount
# 2       Female   NaN           0
# 3       Female   NaN           0
# 4         Male   NaN           1
# 5         Male   NaN           0
# 10        Male   NaN           0
# ...        ...   ...         ...
# 361408    Male   NaN           0
# 361409     NaN   NaN           0
# 361410    Male   NaN           0
# 361411    Male   NaN           3
# 361430  Female   NaN           0
#
# [17455 rows x 12 columns]

# %%
cleaned_df[cleaned_df['Sex'].isna()]
# Out:
#           Age      Condition        Date     Drug  DrugId EaseofUse  \
# 11      19-24  Birth Control  11/17/2018     lyza  164750         5
# 14      35-44  Birth Control   2/13/2018     lyza  164750         5
# 15      25-34  Birth Control   12/9/2017     lyza  164750         2
# 17      25-34  Birth Control   9/27/2017     lyza  164750         4
# 20      35-44  Birth Control    5/6/2016     lyza  164750         5
# ...       ...            ...         ...      ...     ...       ...
# 362404    NaN   Stop Smoking   1/19/2010  chantix  144470         5
# 362478    NaN   Stop Smoking   2/26/2009  chantix  144470         5
# 362506  45-54   Stop Smoking   7/27/2009  chantix  144470         5
# 362633  55-64   Stop Smoking  11/14/2008  chantix  144470         5
# 362635    NaN          Other  11/14/2008  chantix  144470         2
#
#        Effectiveness                                            Reviews  \
# 11                 5  Taking Lyza made me break out HORRIBLY. I trie...
# 14                 5  I was concerned about starting a bc pill due t...
# 15                 2  The birth control was very easy to use and it ...
# 17                 4  I??ve been taking Lyza for years now and I abs...
# 20                 5  I took this pill for a month. It was so awful ...
# ...              ...                                                ...
# 362404             5                                                NaN
# 362478             3  I have just started to take this medication. T...
# 362506             5  Was on Chantix for 3 months beginning Feb 07. ...
# 362633             5  I goofed,it was june 16th of 2007 that I had m...
# 362635             3  My dad strated taking Chantix about 1 month ag...
#
#        Satisfaction  Sex                                              Sides  \
# 11                2  NaN  Nausea ,  vomiting ,  headache ,  bloating ,  ...
# 14                5  NaN  Nausea ,  vomiting ,  headache ,  bloating ,  ...
# 15                1  NaN  Nausea ,  vomiting ,  headache ,  bloating ,  ...
# 17                1  NaN  Nausea ,  vomiting ,  headache ,  bloating ,  ...
# 20                1  NaN  Nausea ,  vomiting ,  headache ,  bloating ,  ...
# ...             ...  ...                                                ...
# 362404            3  NaN  Nausea ,  headache ,  vomiting , drowsiness, g...
# 362478            3  NaN  Nausea ,  headache ,  vomiting , drowsiness, g...
# 362506            5  NaN  Nausea ,  headache ,  vomiting , drowsiness, g...
# 362633            5  NaN  Nausea ,  headache ,  vomiting , drowsiness, g...
# 362635            1  NaN  Nausea ,  headache ,  vomiting , drowsiness, g...
#
#        UsefulCount
# 11               0
# 14               0
# 15               1
# 17               1
# 20               3
# ...            ...
# 362404           0
# 362478           9
# 362506           9
# 362633           0
# 362635          16
#
# [26520 rows x 12 columns]

# %%
cleaned_df.nunique()
# Out:
# Age                  11
# Condition          1805
# Date               4524
# Drug               7093
# DrugId             6572
# EaseofUse             7
# Effectiveness         7
# Reviews          250038
# Satisfaction          7
# Sex                   2
# Sides              1650
# UsefulCount         148
# dtype: int64

# %%
display(cleaned_df['Age'].value_counts())
display(cleaned_df['EaseofUse'].value_counts())
display(cleaned_df['Effectiveness'].value_counts())
display(cleaned_df['Satisfaction'].value_counts())
display(cleaned_df['Sex'].value_counts())
# Out:
# Age
# 45-54         80007
# 55-64         75075
# 35-44         54982
# 25-34         49707
# 65-74         41201
# 19-24         24229
# 75 or over    15218
# 13-18          7040
# 7-12           1644
# 3-6             838
# 0-2             497
# Name: count, dtype: int64
# EaseofUse
# 5     192545
# 4      74712
# 3      41290
# 1      35908
# 2      18181
# 6          2
# 10         1
# Name: count, dtype: int64
# Effectiveness
# 5     130320
# 4      81785
# 3      60383
# 1      59357
# 2      30791
# 6          2
# 10         1
# Name: count, dtype: int64
# Satisfaction
# 5     111487
# 1     100856
# 4      63128
# 3      51837
# 2      35328
# 6          2
# 10         1
# Name: count, dtype: int64
# Sex
# Female    238119
# Male       98000
# Name: count, dtype: int64

# %%
cleaned_df['Condition'].value_counts()
# Out:
# Condition
# Other                                                                             47648
# Pain                                                                              23624
# High Blood Pressure                                                               21627
# Depression                                                                        13807
# Birth Control                                                                     11192
#                                                                                   ...
# Hospital-Acquired Pseudomonas Aeruginosa Pneumonia Treated with Multiple Drugs        1
# Bacterial Blood Infection caused by Pseudomonas Aeruginosa                            1
# Defect of Connective Tissue - Noonan\s Syndrome'                                      1
# Infection of Female Pelvic Organs caused by Klebsiella                                1
# Complicated Skin Infection due to Peptostreptococcus Bacteria                         1
# Name: count, Length: 1753, dtype: int64

# %%
hipertension_condition = cleaned_df[cleaned_df['Condition'] == 'Depression'][['Age', 'Drug', 'Condition', 'Sides']]
hipertension_condition[['Age', 'Drug']].value_counts().unstack().T.replace(np.nan, 0).sum(axis=1).idxmax() # 'lexapro'
# hipertension_condition[hipertension_condition['Drug'] == 'lexapro']['Age'].value_counts()
# Out:
# 'lexapro'

# %%
exper_df = pd.DataFrame(exper_data, columns=columns)

# %%
exper_df.shape
# Out:
# (167, 12)

# %%
exper_df[:5]
# Out:
#      Age                                          Condition       Date  \
# 0  45-54  Disorder characterized by Stiff, Tender  Painf...  2/18/2010
# 1  55-64                                   Neuropathic Pain  3/12/2008
# 2  65-74           High Amount of Triglyceride in the Blood  12/8/2008
# 3  55-64                                High Blood Pressure  3/16/2009
# 4  55-64                                High Blood Pressure  2/21/2010
#
#                   Drug  DrugId EaseofUse Effectiveness  \
# 0               lyrica   93965         5             5
# 1               lyrica   93965         5             5
# 2               lovaza  148529         5             2
# 3  lisinopril solution    6873         5             3
# 4  lisinopril solution    6873         4             4
#
#                                              Reviews  \
# 0  I hope I never stop taking this med. It takes ...
# 1  I have compressed nerve in my lower back due t...
# 2  2 years ago I took lovaza and my colestrol wen...
# 3  The first couple of months Lisinopril worked f...
# 4  Really don\t know if the issues I have is a si...
#
#                Satisfaction                        Sex  \
# 0             constipation    difficulty concentrating
# 1             constipation    difficulty concentrating
# 2  ,2,Female,Upset stomach                     burping
# 3          lightheadedness                   tiredness
# 4          lightheadedness                   tiredness
#
#                                                Sides UsefulCount
# 0                       or  weight  gain may occur.'           1
# 1                       or  weight  gain may occur.'          21
# 2           and strange taste in  mouth  may occur.'           6
# 3   or  headache  may occur as your body adjusts ...          12
# 4   or  headache  may occur as your body adjusts ...           0

# %%
exper_df.nunique()
# Out:
# Age                9
# Condition         60
# Date             120
# Drug             136
# DrugId           103
# EaseofUse          5
# Effectiveness      5
# Reviews          120
# Satisfaction      67
# Sex               63
# Sides             88
# UsefulCount       27
# dtype: int64

# %%
display(exper_df['Satisfaction'].value_counts())
display(exper_df['Sex'].value_counts())
display(exper_df['Sides'].value_counts())
# Out:
# Satisfaction
#   lightheadedness                          27
#   constipation                             12
# 5                                          11
#   dizziness                                10
#   breast  tenderness                        8
#                                            ..
#   muscle pain                               1
# 4                                           1
#  it causes my blood sugar to bottom out     1
#   heartburn                                 1
# 2                                           1
# Name: count, Length: 67, dtype: int64
# Sex
#   dizziness                                                                                                                                        24
#   headache                                                                                                                                         14
#  drowsiness                                                                                                                                         8
#  tiredness                                                                                                                                          7
#   weight  gain                                                                                                                                      6
#                                                                                                                                                    ..
#  I have been on Theragran more than six months and it is the longest I\ve gone without a urinary tract infection!  For me it is a miracle pill      1
# ,3, '                                                                                                                                               1
#  irritability                                                                                                                                       1
#  peeling/flaking/scabbing/crusting                                                                                                                  1
#  unusual  dreams                                                                                                                                    1
# Name: count, Length: 63, dtype: int64
# Sides
#  or drowsiness may occur.'                                              19
#  or  headache  may occur.'                                               6
#  or  weight  changes may occur.'                                         5
#  or  trouble sleeping  may occur.'                                       5
#  or change in  sex drive /ability may occur.'                            4
#                                                                         ..
# ,5,Female,Dizziness  may occur.'                                         1
# ,4,Male,Dizziness  may occur.'                                           1
# ,5,Female, '                                                             1
#  or  dizziness  during and after placement of the device may occur.'     1
#  or changes in taste may occur.'                                         1
# Name: count, Length: 88, dtype: int64

# %%
target_columns = ['Reviews', 'Satisfaction', 'Sex', 'Sides']
fix_exper_df = exper_df.loc[:, target_columns]
rest_exper_df = exper_df.drop(columns=target_columns)

# %%
fix_exper_df.shape, rest_exper_df.shape
# Out:
# ((167, 4), (167, 8))

# %%
pattern = r'^(.+?),(\d+),(\w+),(.+)$'
fix_exper_list = []
rest_exper_list = []
for value_fix, value_rest in zip(fix_exper_df.values, rest_exper_df.values):
    new_value = ''.join(value_fix)
    match = re.match(pattern, new_value)
    # print(new_value)
    if match:
        fix_exper_list.append(match.groups())
        rest_exper_list.append(value_rest)
        # print(list(match.groups()))
    # else:
        # test_data.append(new_value)
        # print(new_value)

# %%
len(fix_exper_list), len(rest_exper_list)
# Out:
# (150, 150)

# %%
for value in fix_exper_list[:4]:
    print(value)
# Out:
# ("I hope I never stop taking this med. It takes a way the crippling stiff muscles, with out it I can\\t roll over in bed without being in sever pain my skin doesn\\'t feel raw.I can get a hug without cringing from pain. I stoped taking it because I thought it wasn\\'t helping. I was quick to take it again to me it has been a god send. I have NO side effects from it. I just can\\'t tell you how much it has helped me with Fibral mialgie.The cramps that your body goes through is crushateing. Mucles get hard as rocks  gets huge bumps. I hope this has helped some one. It takes a little time to work. But it does work ", '5', 'Female', "Drowsiness  dizziness   dry mouth   constipation  difficulty concentrating or  weight  gain may occur.'")
# ('I have compressed nerve in my lower back due to a fall and I was having a hard time functioning and one morning I got up and the pain was so bad I could not move. I was really scared. I went to my family dr. and she presribed this and only 1 pill and I felt such relief. I have been on this for about 1 and half years and probsbly will be on it for the rest of my life.I don\\t want surgery unless it is the last resort', '5', 'Female', "Drowsiness  dizziness   dry mouth   constipation  difficulty concentrating or  weight  gain may occur.'")
# ('2 years ago I took lovaza and my colestrol went down to  160  from 260 I took it for three months  It went back up to 260 within a year after I quit taking it.  Now its back up to 267, I have been taking it for six months this year and it has not went down at all I dont eat meat , butter or fried foods, Mostly egg whites and  very little fruits and veggies I dont eat the latter because when I do My leggs get realy restless at night after I lay down and relax never bother\\s me in the day time only at night', '2', 'Female', "Upset stomach  burping and strange taste in  mouth  may occur.'")
# ('The first couple of months Lisinopril worked fine then I started aching, couldn\\t sleep all night. Now I have extreme anxiety and pressure spikes bad enough to pass out. The worst spike was 175 over 134 with a pulse of 127 while not doing anything but sitting. This hurt so bad I thought I was going to die. Later I was just evil acting to my loved ones for no reason other than being truly scared', '1', 'Female', "Dizziness   lightheadedness  tiredness or  headache  may occur as your body adjusts to the  medication . Dry  cough  may also occur.'")

# %%
exper_df.columns
# Out:
# Index(['Age', 'Condition', 'Date', 'Drug', 'DrugId', 'EaseofUse',
#        'Effectiveness', 'Reviews', 'Satisfaction', 'Sex', 'Sides',
#        'UsefulCount'],
#       dtype='object')

# %%
fix_exper_df_final = pd.DataFrame(fix_exper_list, columns=target_columns)
rest_exper_df_final = pd.DataFrame(rest_exper_list, columns=rest_exper_df.columns)

# %%
concatenate_df = pd.concat([rest_exper_df_final, fix_exper_df_final], axis=1)
concatenate_df = concatenate_df[cleaned_df.columns]

# %%
cleaned_df[:5]
# Out:
#           Age      Condition       Date                         Drug  DrugId  \
# 0  75 or over    Stuffy Nose  9/21/2014                 25dph-7.5peh  146724
# 1       25-34  Cold Symptoms  1/13/2011                 25dph-7.5peh  146724
# 2       65-74          Other  7/16/2012  warfarin (bulk) 100  powder  144731
# 3  75 or over          Other  9/23/2010  warfarin (bulk) 100  powder  144731
# 4       35-44          Other   1/6/2009  warfarin (bulk) 100  powder  144731
#
#   EaseofUse Effectiveness                                            Reviews  \
# 0         5             5  I\m a retired physician and of all the meds I ...
# 1         5             5  cleared me right up even with my throat hurtin...
# 2         2             3  why did my PTINR go from a normal of 2.5 to ov...
# 3         2             2                      FALLING AND DON\T REALISE IT'
# 4         1             1  My grandfather was prescribed this medication ...
#
#   Satisfaction     Sex                                              Sides  \
# 0            5    Male  Drowsiness,  dizziness ,  dry mouth /nose/thro...
# 1            5  Female  Drowsiness,  dizziness ,  dry mouth /nose/thro...
# 2            3  Female                                                NaN
# 3            1  Female                                                NaN
# 4            1    Male                                                NaN
#
#   UsefulCount
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1

# %%
concatenate_df[:5]
# Out:
#      Age                                          Condition       Date  \
# 0  45-54  Disorder characterized by Stiff, Tender  Painf...  2/18/2010
# 1  55-64                                   Neuropathic Pain  3/12/2008
# 2  65-74           High Amount of Triglyceride in the Blood  12/8/2008
# 3  55-64                                High Blood Pressure  3/16/2009
# 4  55-64                                High Blood Pressure  2/21/2010
#
#                   Drug  DrugId EaseofUse Effectiveness  \
# 0               lyrica   93965         5             5
# 1               lyrica   93965         5             5
# 2               lovaza  148529         5             2
# 3  lisinopril solution    6873         5             3
# 4  lisinopril solution    6873         4             4
#
#                                              Reviews Satisfaction     Sex  \
# 0  I hope I never stop taking this med. It takes ...            5  Female
# 1  I have compressed nerve in my lower back due t...            5  Female
# 2  2 years ago I took lovaza and my colestrol wen...            2  Female
# 3  The first couple of months Lisinopril worked f...            1  Female
# 4  Really don\t know if the issues I have is a si...            4    Male
#
#                                                Sides UsefulCount
# 0  Drowsiness  dizziness   dry mouth   constipati...           1
# 1  Drowsiness  dizziness   dry mouth   constipati...          21
# 2  Upset stomach  burping and strange taste in  m...           6
# 3  Dizziness   lightheadedness  tiredness or  hea...          12
# 4  Dizziness   lightheadedness  tiredness or  hea...           0

# %%
final_df = pd.concat([cleaned_df, concatenate_df], ignore_index=True)
final_df
# Out:
#                Age                                          Condition  \
# 0       75 or over                                        Stuffy Nose
# 1            25-34                                      Cold Symptoms
# 2            65-74                                              Other
# 3       75 or over                                              Other
# 4            35-44                                              Other
# ...            ...                                                ...
# 362784       55-64                                         Depression
# 362785       55-64  Acute Maxillary Sinus S. Pneumoniae Bacteria I...
# 362786       55-64  Acute Maxillary Sinus S. Pneumoniae Bacteria I...
# 362787  75 or over  Acute Maxillary Sinus S. Pneumoniae Bacteria I...
# 362788       35-44                                       Stop Smoking
#
#               Date                         Drug  DrugId EaseofUse  \
# 0        9/21/2014                 25dph-7.5peh  146724         5
# 1        1/13/2011                 25dph-7.5peh  146724         5
# 2        7/16/2012  warfarin (bulk) 100  powder  144731         2
# 3        9/23/2010  warfarin (bulk) 100  powder  144731         2
# 4         1/6/2009  warfarin (bulk) 100  powder  144731         1
# ...            ...                          ...     ...       ...
# 362784    1/7/2012                       celexa    8603         1
# 362785   12/8/2007             cefdinir capsule    5543         5
# 362786   12/8/2007                     cefdinir    5543         5
# 362787   1/27/2012                     cefdinir    5543         5
# 362788  11/19/2007                      chantix  144470         5
#
#        Effectiveness                                            Reviews  \
# 0                  5  I\m a retired physician and of all the meds I ...
# 1                  5  cleared me right up even with my throat hurtin...
# 2                  3  why did my PTINR go from a normal of 2.5 to ov...
# 3                  2                      FALLING AND DON\T REALISE IT'
# 4                  1  My grandfather was prescribed this medication ...
# ...              ...                                                ...
# 362784             1      Can\t sleep at night and difficult to urinate
# 362785             3  so far i believe the drug is working but my mo...
# 362786             3  so far i believe the drug is working but my mo...
# 362787             4  The one strange side effect is - it has colore...
# 362788             5  I have tried to quit chewing and then smoking ...
#
#        Satisfaction     Sex  \
# 0                 5    Male
# 1                 5  Female
# 2                 3  Female
# 3                 1  Female
# 4                 1    Male
# ...             ...     ...
# 362784            1  Female
# 362785            3  Female
# 362786            3  Female
# 362787            5  Female
# 362788            5    Male
#
#                                                     Sides UsefulCount
# 0       Drowsiness,  dizziness ,  dry mouth /nose/thro...           0
# 1       Drowsiness,  dizziness ,  dry mouth /nose/thro...           1
# 2                                                     NaN           0
# 3                                                     NaN           0
# 4                                                     NaN           1
# ...                                                   ...         ...
# 362784  Nausea   dry mouth  loss of appetite tiredness...           5
# 362785       Diarrhea   headache  or  nausea  may occur.'           9
# 362786  Diarrhea   nausea   vomiting   headache  or  d...           9
# 362787  Diarrhea   nausea   vomiting   headache  or  d...           1
# 362788  Nausea   headache   vomiting  drowsiness gas  ...           7
#
# [362789 rows x 12 columns]
