# %%
import pandas as pd
import numpy as np
import csv
import re

# %%
DATASET_PATH = './Assets/Datasets/dataset_'

# %%
with open(DATASET_PATH, 'r') as file:
    for idx, line in enumerate(file):
        line = line.strip()
        print(f'{line} --> idx: {idx}')
        if idx == 24:
            break

    reader = csv.reader(file, delimiter=',', quotechar="'", doublequote=True)
    for idx, row in enumerate(reader):
        if idx >= 10:
            break

        print(f'length of data: {len(row)} --> value list: {row}')
# Out:
# % Context --> idx: 0
# % The dataset provides user reviews on specific drugs along with related conditions, side effects, age, sex, and ratings reflecting overall patient satisfaction. --> idx: 1
# % Content --> idx: 2
# % Data was acquired by scraping WebMD site. There are around 0.36 million rows of unique reviews and is updated till Mar 2020. --> idx: 3
# % Inspiration --> idx: 4
# % This dataset intended to answer following questions: --> idx: 5
# % I. Identifying the condition of the patient based on drug reviews? --> idx: 6
# % II. How to predict drug rating based on patients reviews? --> idx: 7
# % III. How to visualize drug rating, kind of drugs, types of conditions a patient can have, sentiments based on reviews --> idx: 8
# @RELATION WebMD-Drug-Reviews-Dataset --> idx: 9
#  --> idx: 10
# @ATTRIBUTE Age STRING --> idx: 11
# @ATTRIBUTE Condition STRING --> idx: 12
# @ATTRIBUTE Date STRING --> idx: 13
# @ATTRIBUTE Drug STRING --> idx: 14
# @ATTRIBUTE DrugId INTEGER --> idx: 15
# @ATTRIBUTE EaseofUse INTEGER --> idx: 16
# @ATTRIBUTE Effectiveness INTEGER --> idx: 17
# @ATTRIBUTE Reviews STRING --> idx: 18
# @ATTRIBUTE Satisfaction INTEGER --> idx: 19
# @ATTRIBUTE Sex STRING --> idx: 20
# @ATTRIBUTE Sides STRING --> idx: 21
# @ATTRIBUTE UsefulCount INTEGER --> idx: 22
#  --> idx: 23
# @DATA --> idx: 24
# length of data: 12 --> value list: ['75 or over', 'Stuffy Nose', '9/21/2014', '25dph-7.5peh', '146724', '5', '5', "I\\m a retired physician and of all the meds I have tried for my allergies (seasonal and not) - this one is the most effective for me.  When I first began using this drug some years ago - tiredness as a problem but is not currently.'", '5', 'Male', 'Drowsiness,  dizziness ,  dry mouth /nose/throat,  headache ,  upset stomach ,  constipation , or  trouble sleeping  may occur.', '0']
# length of data: 12 --> value list: ['25-34', 'Cold Symptoms', '1/13/2011', '25dph-7.5peh', '146724', '5', '5', 'cleared me right up even with my throat hurting it went away after taking the medicine', '5', 'Female', 'Drowsiness,  dizziness ,  dry mouth /nose/throat,  headache ,  upset stomach ,  constipation , or  trouble sleeping  may occur.', '1']
# length of data: 12 --> value list: ['65-74', 'Other', '7/16/2012', 'warfarin (bulk) 100  powder', '144731', '2', '3', 'why did my PTINR go from a normal of 2.5 to over \\n100?', '3', 'Female', ' ', '0']
# length of data: 12 --> value list: ['75 or over', 'Other', '9/23/2010', 'warfarin (bulk) 100  powder', '144731', '2', '2', "FALLING AND DON\\T REALISE IT'", '1', 'Female', ' ', '0']
# length of data: 12 --> value list: ['35-44', 'Other', '1/6/2009', 'warfarin (bulk) 100  powder', '144731', '1', '1', 'My grandfather was prescribed this medication (Coumadin) to assist in blood thinning due to a heart and thyroid condition.  His primary doctor was aware that he was on an aspirin regiment and still prescribed this medicine, it caused his blood to thin out to much and he ended up internally bleeding to death.  If you are going to take this medicine please ask your doctors about possible side effects or drug interactions.', '1', 'Male', ' ', '1']
# length of data: 12 --> value list: ['55-64', 'Other', '7/19/2008', 'warfarin (bulk) 100  powder', '144731', '4', '4', 'help heart condition operation well', '4', 'Male', ' ', '0']
# length of data: 13 --> value list: ['25-34', 'Birth Control', '6/15/2017', 'wymzya fe', '163180', '5', '5', "Haven\\t gotten pregnant so it does it\\'s job. I was switched to this brand from another generic. I get nauseous and generally feel tired on this", " also more headaches.'", '2', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, swelling of the  ankles /feet (fluid retention), or  weight  change may occur.', '0']
# length of data: 12 --> value list: ['45-54', 'Disease of Ovaries with Cysts', '1/30/2017', 'wymzya fe', '163180', '5', '5', 'I have take this for 5 years age 45-50 to prevent ovarian cysts (I had 2 burst). Now stopped because of age. No side effects. ', '5', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, swelling of the  ankles /feet (fluid retention), or  weight  change may occur.', '0']
# length of data: 12 --> value list: ['25-34', 'Acne', '4/27/2016', 'wymzya fe', '163180', '4', '2', ' ', '2', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, swelling of the  ankles /feet (fluid retention), or  weight  change may occur.', '1']
# length of data: 12 --> value list: ['55-64', 'Stuffy Nose', '10/29/2012', '12 hour nasal relief spray, non-aerosol', '9800', '4', '2', 'The 12 hour spray only works for me for 6 hours.', '2', 'Male', 'Temporary burning, stinging, dryness in the nose,  runny nose , and  sneezing  may occur.', '0']

# %%
columns = [
    'Age',
    'Condition',
    'Date',
    'Drug',
    'DrugId',
    'EaseofUse',
    'Effectiveness',
    'Reviews',
    'Satisfaction',
    'Sex',
    'Sides',
    'UsefulCount',
]

# %%
messy_data = []
true_data = []
with open(DATASET_PATH, 'r') as file:
    for idx, line in enumerate(file):
        if line.strip() == '@DATA':
            break

    reader = csv.reader(file, delimiter=',', quotechar="'", doublequote=True)
    for idx, row in enumerate(reader):
        if len(row) != 12: # the number of attributes is 12, so if the length of the list is not equal to 12, then something is wrong.
            messy_data.append(row)
        else:
            true_data.append(row)

# %%
print(f'Number of True data: {len(true_data)}')
print(f'Number of Messy data: {len(messy_data)}')
# Out:
# Number of True data: 297967
# Number of Messy data: 64839

# %%
for value in true_data[:5]:
    print(f'length of data: {len(value)} --> value list: {value}')
# Out:
# length of data: 12 --> value list: ['75 or over', 'Stuffy Nose', '9/21/2014', '25dph-7.5peh', '146724', '5', '5', "I\\m a retired physician and of all the meds I have tried for my allergies (seasonal and not) - this one is the most effective for me.  When I first began using this drug some years ago - tiredness as a problem but is not currently.'", '5', 'Male', 'Drowsiness,  dizziness ,  dry mouth /nose/throat,  headache ,  upset stomach ,  constipation , or  trouble sleeping  may occur.', '0']
# length of data: 12 --> value list: ['25-34', 'Cold Symptoms', '1/13/2011', '25dph-7.5peh', '146724', '5', '5', 'cleared me right up even with my throat hurting it went away after taking the medicine', '5', 'Female', 'Drowsiness,  dizziness ,  dry mouth /nose/throat,  headache ,  upset stomach ,  constipation , or  trouble sleeping  may occur.', '1']
# length of data: 12 --> value list: ['65-74', 'Other', '7/16/2012', 'warfarin (bulk) 100  powder', '144731', '2', '3', 'why did my PTINR go from a normal of 2.5 to over \\n100?', '3', 'Female', ' ', '0']
# length of data: 12 --> value list: ['75 or over', 'Other', '9/23/2010', 'warfarin (bulk) 100  powder', '144731', '2', '2', "FALLING AND DON\\T REALISE IT'", '1', 'Female', ' ', '0']
# length of data: 12 --> value list: ['35-44', 'Other', '1/6/2009', 'warfarin (bulk) 100  powder', '144731', '1', '1', 'My grandfather was prescribed this medication (Coumadin) to assist in blood thinning due to a heart and thyroid condition.  His primary doctor was aware that he was on an aspirin regiment and still prescribed this medicine, it caused his blood to thin out to much and he ended up internally bleeding to death.  If you are going to take this medicine please ask your doctors about possible side effects or drug interactions.', '1', 'Male', ' ', '1']

# %%
for value in messy_data[:5]:
    print(f'length of data: {len(value)} --> value list: {value}')
# Out:
# length of data: 13 --> value list: ['25-34', 'Birth Control', '6/15/2017', 'wymzya fe', '163180', '5', '5', "Haven\\t gotten pregnant so it does it\\'s job. I was switched to this brand from another generic. I get nauseous and generally feel tired on this", " also more headaches.'", '2', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, swelling of the  ankles /feet (fluid retention), or  weight  change may occur.', '0']
# length of data: 17 --> value list: ['25-34', 'Birth Control', '10/7/2017', 'lyza', '164750', '1', '1', "LYZA BIRTH CONTROL\\nThese are the WORST birth control pills I have ever taken!  I\\ve only been taking them for a couple of weeks and I feel like a crazy person.  I\\'ve been crying", ' (for no reason)', ' been super depressed', ' my anxiety is terrible', " along with daily headaches and break outs.   I realize everyone\\'s body reacts differently to medication", "  but I\\'ve read nothing but negative reviews.  I can surely attest to that.  I wouldn\\'t advise anyone to take these.   Absolutely awful.\\n'", '1', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, or  weight  gain may occur.', '1']
# length of data: 13 --> value list: ['25-34', 'Birth Control', '1/30/2017', 'lyza', '164750', '5', '5', 'I have been taking Lyza for two months now. I was very anxious about going back on the pill after have an IUD for the past several years. I have noticed acne which I have never had before, but nothing extreme. I eat healthy and exercise about three times a week, I haven\\t noticed any water weight or bloating. Other than the mild acne', " I\\'m pretty happy. '", '4', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, or  weight  gain may occur.', '1']
# length of data: 13 --> value list: ['35-44', 'Birth Control', '5/6/2016', 'lyza', '164750', '5', '5', "I took this pill for a month. It was so awful that I can\\t take it any more. The mood swings are 10 times worse than I\\'ve ever experienced before. I eat really healthy and I\\'m very active but had so much bloating and a fair amount of weight gain. I had less cramping but 7 days of heavy bleeding. The nausea was unbearable most of the time. While this pill was effective", " the side effects were so horrible that I quit taking it. My husband and I decided one more baby and then sterilization. No more pills!'", '1', ' ', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, or  weight  gain may occur.', '3']
# length of data: 14 --> value list: ['25-34', 'Birth Control', '4/29/2016', 'lyza', '164750', '5', '5', 'My OB/GYN placed me on this pill because I was at risk for a stroke while being on estrogen birth controls. I have been taking this medication for 2 months with no side effects: migraines have stopped, no acne, no mood swings, no weight gain, no spotting, and sex drive is still intact. The first month of taking this pill my period was extremely light (almost nonexistant) and lasted only two days. This month I didn\\t have a period and took a pregnancy test', ' it was negative. I read reviews that this is normal while taking this pill... Not sure if I like this factor? All in all', " i\\'m pretty pleased with this birth control. Please note that this is a progestin only pill and it is important to take at it at the same time daily.'", '4', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, or  weight  gain may occur.', '10']

# %%
for value in messy_data[:5]:
    fix_length_data = value[:7] + [''.join(value[7:-4])] + value[-4:]
    print(f'length of data: {len(value)} --> value list: {value}')
    print(f'length of fix data: {len(fix_length_data)} --> value list: {fix_length_data}')
    print()
# Out:
# length of data: 13 --> value list: ['25-34', 'Birth Control', '6/15/2017', 'wymzya fe', '163180', '5', '5', "Haven\\t gotten pregnant so it does it\\'s job. I was switched to this brand from another generic. I get nauseous and generally feel tired on this", " also more headaches.'", '2', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, swelling of the  ankles /feet (fluid retention), or  weight  change may occur.', '0']
# length of fix data: 12 --> value list: ['25-34', 'Birth Control', '6/15/2017', 'wymzya fe', '163180', '5', '5', "Haven\\t gotten pregnant so it does it\\'s job. I was switched to this brand from another generic. I get nauseous and generally feel tired on this also more headaches.'", '2', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, swelling of the  ankles /feet (fluid retention), or  weight  change may occur.', '0']
#
# length of data: 17 --> value list: ['25-34', 'Birth Control', '10/7/2017', 'lyza', '164750', '1', '1', "LYZA BIRTH CONTROL\\nThese are the WORST birth control pills I have ever taken!  I\\ve only been taking them for a couple of weeks and I feel like a crazy person.  I\\'ve been crying", ' (for no reason)', ' been super depressed', ' my anxiety is terrible', " along with daily headaches and break outs.   I realize everyone\\'s body reacts differently to medication", "  but I\\'ve read nothing but negative reviews.  I can surely attest to that.  I wouldn\\'t advise anyone to take these.   Absolutely awful.\\n'", '1', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, or  weight  gain may occur.', '1']
# length of fix data: 12 --> value list: ['25-34', 'Birth Control', '10/7/2017', 'lyza', '164750', '1', '1', "LYZA BIRTH CONTROL\\nThese are the WORST birth control pills I have ever taken!  I\\ve only been taking them for a couple of weeks and I feel like a crazy person.  I\\'ve been crying (for no reason) been super depressed my anxiety is terrible along with daily headaches and break outs.   I realize everyone\\'s body reacts differently to medication  but I\\'ve read nothing but negative reviews.  I can surely attest to that.  I wouldn\\'t advise anyone to take these.   Absolutely awful.\\n'", '1', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, or  weight  gain may occur.', '1']
#
# length of data: 13 --> value list: ['25-34', 'Birth Control', '1/30/2017', 'lyza', '164750', '5', '5', 'I have been taking Lyza for two months now. I was very anxious about going back on the pill after have an IUD for the past several years. I have noticed acne which I have never had before, but nothing extreme. I eat healthy and exercise about three times a week, I haven\\t noticed any water weight or bloating. Other than the mild acne', " I\\'m pretty happy. '", '4', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, or  weight  gain may occur.', '1']
# length of fix data: 12 --> value list: ['25-34', 'Birth Control', '1/30/2017', 'lyza', '164750', '5', '5', "I have been taking Lyza for two months now. I was very anxious about going back on the pill after have an IUD for the past several years. I have noticed acne which I have never had before, but nothing extreme. I eat healthy and exercise about three times a week, I haven\\t noticed any water weight or bloating. Other than the mild acne I\\'m pretty happy. '", '4', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, or  weight  gain may occur.', '1']
#
# length of data: 13 --> value list: ['35-44', 'Birth Control', '5/6/2016', 'lyza', '164750', '5', '5', "I took this pill for a month. It was so awful that I can\\t take it any more. The mood swings are 10 times worse than I\\'ve ever experienced before. I eat really healthy and I\\'m very active but had so much bloating and a fair amount of weight gain. I had less cramping but 7 days of heavy bleeding. The nausea was unbearable most of the time. While this pill was effective", " the side effects were so horrible that I quit taking it. My husband and I decided one more baby and then sterilization. No more pills!'", '1', ' ', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, or  weight  gain may occur.', '3']
# length of fix data: 12 --> value list: ['35-44', 'Birth Control', '5/6/2016', 'lyza', '164750', '5', '5', "I took this pill for a month. It was so awful that I can\\t take it any more. The mood swings are 10 times worse than I\\'ve ever experienced before. I eat really healthy and I\\'m very active but had so much bloating and a fair amount of weight gain. I had less cramping but 7 days of heavy bleeding. The nausea was unbearable most of the time. While this pill was effective the side effects were so horrible that I quit taking it. My husband and I decided one more baby and then sterilization. No more pills!'", '1', ' ', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, or  weight  gain may occur.', '3']
#
# length of data: 14 --> value list: ['25-34', 'Birth Control', '4/29/2016', 'lyza', '164750', '5', '5', 'My OB/GYN placed me on this pill because I was at risk for a stroke while being on estrogen birth controls. I have been taking this medication for 2 months with no side effects: migraines have stopped, no acne, no mood swings, no weight gain, no spotting, and sex drive is still intact. The first month of taking this pill my period was extremely light (almost nonexistant) and lasted only two days. This month I didn\\t have a period and took a pregnancy test', ' it was negative. I read reviews that this is normal while taking this pill... Not sure if I like this factor? All in all', " i\\'m pretty pleased with this birth control. Please note that this is a progestin only pill and it is important to take at it at the same time daily.'", '4', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, or  weight  gain may occur.', '10']
# length of fix data: 12 --> value list: ['25-34', 'Birth Control', '4/29/2016', 'lyza', '164750', '5', '5', "My OB/GYN placed me on this pill because I was at risk for a stroke while being on estrogen birth controls. I have been taking this medication for 2 months with no side effects: migraines have stopped, no acne, no mood swings, no weight gain, no spotting, and sex drive is still intact. The first month of taking this pill my period was extremely light (almost nonexistant) and lasted only two days. This month I didn\\t have a period and took a pregnancy test it was negative. I read reviews that this is normal while taking this pill... Not sure if I like this factor? All in all i\\'m pretty pleased with this birth control. Please note that this is a progestin only pill and it is important to take at it at the same time daily.'", '4', 'Female', 'Nausea ,  vomiting ,  headache ,  bloating ,  breast  tenderness, or  weight  gain may occur.', '10']

# %%
fix_data = []
for value in messy_data:
    fix_length_data = value[:7] + [''.join(value[7:-4])] + value[-4:]
    fix_data.append(fix_length_data)

# %%
fix_df = pd.DataFrame(fix_data, columns=columns)
true_df = pd.DataFrame(true_data, columns=columns)

# %%
print(f'shape of true_df: {true_df.shape}, shape of fix_df: {fix_df.shape}')
# Out:
# shape of true_df: (297967, 12), shape of fix_df: (64839, 12)

# %%
true_df[:5]
# Out:
#           Age      Condition       Date                         Drug  DrugId  \
# 0  75 or over    Stuffy Nose  9/21/2014                 25dph-7.5peh  146724
# 1       25-34  Cold Symptoms  1/13/2011                 25dph-7.5peh  146724
# 2       65-74          Other  7/16/2012  warfarin (bulk) 100  powder  144731
# 3  75 or over          Other  9/23/2010  warfarin (bulk) 100  powder  144731
# 4       35-44          Other   1/6/2009  warfarin (bulk) 100  powder  144731
#
#   EaseofUse Effectiveness                                            Reviews  \
# 0         5             5  I\m a retired physician and of all the meds I ...
# 1         5             5  cleared me right up even with my throat hurtin...
# 2         2             3  why did my PTINR go from a normal of 2.5 to ov...
# 3         2             2                      FALLING AND DON\T REALISE IT'
# 4         1             1  My grandfather was prescribed this medication ...
#
#   Satisfaction     Sex                                              Sides  \
# 0            5    Male  Drowsiness,  dizziness ,  dry mouth /nose/thro...
# 1            5  Female  Drowsiness,  dizziness ,  dry mouth /nose/thro...
# 2            3  Female
# 3            1  Female
# 4            1    Male
#
#   UsefulCount
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1

# %%
true_df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297967 entries, 0 to 297966
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Age            297967 non-null  object
#  1   Condition      297967 non-null  object
#  2   Date           297967 non-null  object
#  3   Drug           297967 non-null  object
#  4   DrugId         297967 non-null  object
#  5   EaseofUse      297967 non-null  object
#  6   Effectiveness  297967 non-null  object
#  7   Reviews        297967 non-null  object
#  8   Satisfaction   297967 non-null  object
#  9   Sex            297967 non-null  object
#  10  Sides          297967 non-null  object
#  11  UsefulCount    297967 non-null  object
# dtypes: object(12)
# memory usage: 306.8 MB

# %%
fix_df[:5]
# Out:
#      Age      Condition       Date       Drug  DrugId EaseofUse Effectiveness  \
# 0  25-34  Birth Control  6/15/2017  wymzya fe  163180         5             5
# 1  25-34  Birth Control  10/7/2017       lyza  164750         1             1
# 2  25-34  Birth Control  1/30/2017       lyza  164750         5             5
# 3  35-44  Birth Control   5/6/2016       lyza  164750         5             5
# 4  25-34  Birth Control  4/29/2016       lyza  164750         5             5
#
#                                              Reviews Satisfaction     Sex  \
# 0  Haven\t gotten pregnant so it does it\'s job. ...            2  Female
# 1  LYZA BIRTH CONTROL\nThese are the WORST birth ...            1  Female
# 2  I have been taking Lyza for two months now. I ...            4  Female
# 3  I took this pill for a month. It was so awful ...            1
# 4  My OB/GYN placed me on this pill because I was...            4  Female
#
#                                                Sides UsefulCount
# 0  Nausea ,  vomiting ,  headache ,  bloating ,  ...           0
# 1  Nausea ,  vomiting ,  headache ,  bloating ,  ...           1
# 2  Nausea ,  vomiting ,  headache ,  bloating ,  ...           1
# 3  Nausea ,  vomiting ,  headache ,  bloating ,  ...           3
# 4  Nausea ,  vomiting ,  headache ,  bloating ,  ...          10

# %%
fix_df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64839 entries, 0 to 64838
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            64839 non-null  object
#  1   Condition      64839 non-null  object
#  2   Date           64839 non-null  object
#  3   Drug           64839 non-null  object
#  4   DrugId         64839 non-null  object
#  5   EaseofUse      64839 non-null  object
#  6   Effectiveness  64839 non-null  object
#  7   Reviews        64839 non-null  object
#  8   Satisfaction   64839 non-null  object
#  9   Sex            64839 non-null  object
#  10  Sides          64839 non-null  object
#  11  UsefulCount    64839 non-null  object
# dtypes: object(12)
# memory usage: 92.9 MB

# %%
concat_df = pd.concat([true_df, fix_df], axis=0, ignore_index=True)

# %%
concat_df[:15]
# Out:
#            Age                      Condition        Date  \
# 0   75 or over                    Stuffy Nose   9/21/2014
# 1        25-34                  Cold Symptoms   1/13/2011
# 2        65-74                          Other   7/16/2012
# 3   75 or over                          Other   9/23/2010
# 4        35-44                          Other    1/6/2009
# 5        55-64                          Other   7/19/2008
# 6        45-54  Disease of Ovaries with Cysts   1/30/2017
# 7        25-34                           Acne   4/27/2016
# 8        55-64                    Stuffy Nose  10/29/2012
# 9        65-74                          Other   3/15/2016
# 10       19-24                  Birth Control  11/17/2018
# 11                              Birth Control    7/3/2018
# 12       19-24                  Birth Control    3/6/2018
# 13       35-44                  Birth Control   2/13/2018
# 14       25-34                  Birth Control   12/9/2017
#
#                                        Drug  DrugId EaseofUse Effectiveness  \
# 0                              25dph-7.5peh  146724         5             5
# 1                              25dph-7.5peh  146724         5             5
# 2               warfarin (bulk) 100  powder  144731         2             3
# 3               warfarin (bulk) 100  powder  144731         2             2
# 4               warfarin (bulk) 100  powder  144731         1             1
# 5               warfarin (bulk) 100  powder  144731         4             4
# 6                                 wymzya fe  163180         5             5
# 7                                 wymzya fe  163180         4             2
# 8   12 hour nasal relief spray, non-aerosol    9800         4             2
# 9                       pyrogallol crystals   12112         5             5
# 10                                     lyza  164750         5             5
# 11                                     lyza  164750         2             1
# 12                                     lyza  164750         2             3
# 13                                     lyza  164750         5             5
# 14                                     lyza  164750         2             2
#
#                                               Reviews Satisfaction     Sex  \
# 0   I\m a retired physician and of all the meds I ...            5    Male
# 1   cleared me right up even with my throat hurtin...            5  Female
# 2   why did my PTINR go from a normal of 2.5 to ov...            3  Female
# 3                       FALLING AND DON\T REALISE IT'            1  Female
# 4   My grandfather was prescribed this medication ...            1    Male
# 5                 help heart condition operation well            4    Male
# 6   I have take this for 5 years age 45-50 to prev...            5  Female
# 7                                                                2  Female
# 8    The 12 hour spray only works for me for 6 hours.            2    Male
# 9   Excellent in reducing inlamation associated wi...            5    Male
# 10  Taking Lyza made me break out HORRIBLY. I trie...            2
# 11  This stuff needs to be removed from the market...            1  Female
# 12  I usually have zero to little acne, a few mont...            1  Female
# 13  I was concerned about starting a bc pill due t...            5
# 14  The birth control was very easy to use and it ...            1
#
#                                                 Sides UsefulCount
# 0   Drowsiness,  dizziness ,  dry mouth /nose/thro...           0
# 1   Drowsiness,  dizziness ,  dry mouth /nose/thro...           1
# 2                                                               0
# 3                                                               0
# 4                                                               1
# 5                                                               0
# 6   Nausea ,  vomiting ,  headache ,  bloating ,  ...           0
# 7   Nausea ,  vomiting ,  headache ,  bloating ,  ...           1
# 8   Temporary burning, stinging, dryness in the no...           0
# 9                                                               0
# 10  Nausea ,  vomiting ,  headache ,  bloating ,  ...           0
# 11  Nausea ,  vomiting ,  headache ,  bloating ,  ...           0
# 12  Nausea ,  vomiting ,  headache ,  bloating ,  ...           0
# 13  Nausea ,  vomiting ,  headache ,  bloating ,  ...           0
# 14  Nausea ,  vomiting ,  headache ,  bloating ,  ...           1

# %%
print(f'shape of concat_df: {concat_df.shape}')
# Out:
# shape of concat_df: (362806, 12)

# %%
concat_df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362806 entries, 0 to 362805
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Age            362806 non-null  object
#  1   Condition      362806 non-null  object
#  2   Date           362806 non-null  object
#  3   Drug           362806 non-null  object
#  4   DrugId         362806 non-null  object
#  5   EaseofUse      362806 non-null  object
#  6   Effectiveness  362806 non-null  object
#  7   Reviews        362806 non-null  object
#  8   Satisfaction   362806 non-null  object
#  9   Sex            362806 non-null  object
#  10  Sides          362806 non-null  object
#  11  UsefulCount    362806 non-null  object
# dtypes: object(12)
# memory usage: 399.7 MB

# %%
concat_df.nunique()
# Out:
# Age                  12
# Condition          1806
# Date               4525
# Drug               7096
# DrugId             6573
# EaseofUse            13
# Effectiveness         7
# Reviews          250162
# Satisfaction         70
# Sex                  66
# Sides              1726
# UsefulCount         148
# dtype: int64

# %%
concat_df['Sex'].value_counts()
# Out:
# Sex
# Female                                238119
# Male                                   98000
#                                        26520
#   dizziness                               24
#   headache                                14
#                                        ...
# ,3, '                                      1
#  irritability                              1
#  bleeding                                  1
#  peeling/flaking/scabbing/crusting         1
#  unusual  dreams                           1
# Name: count, Length: 66, dtype: int64

# %%
concat_df['Satisfaction'].value_counts()
# Out:
# Satisfaction
# 5                                                                                                                                                                                                     111498
# 1                                                                                                                                                                                                     100859
# 4                                                                                                                                                                                                      63129
# 3                                                                                                                                                                                                      51837
# 2                                                                                                                                                                                                      35329
#                                                                                                                                                                                                        ...
#   weight loss                                                                                                                                                                                              1
#  thickening/hardening of the  skin                                                                                                                                                                         1
# I take this for my arthritis.  I have been taking it for 5 years.  I have no side effects.  One tablet decreases my arthritis for 24 - 36 hours.  I wonder why it isn\t prescribed more                    1
#  Dr\'s shouldn\'t be allowed to give it to patients                                                                                                                                                        1
# I have been using soma as needed for 3 years and it doe.s a great job in relieving kneck and lower back spasm and pain that I have caused by multiple disc  and nerve problems\',5,Male,Dizziness          1
# Name: count, Length: 70, dtype: int64

# %%
concat_df['Effectiveness'].value_counts()
# Out:
# Effectiveness
# 5     130389
# 4      81821
# 3      60409
# 1      59384
# 2      30800
# 6          2
# 10         1
# Name: count, dtype: int64

# %%
concat_df['EaseofUse'].value_counts()
# Out:
# EaseofUse
# 5         192632
# 4          74728
# 3          41299
# 1          35925
# 2          18189
# 62261         18
# 154215         6
# 11147          3
# 6              2
# 10             1
# 10149          1
# 169930         1
# 57948          1
# Name: count, dtype: int64

# %%
concat_df['Age'].value_counts()
# Out:
# Age
# 45-54         80043
# 55-64         75136
# 35-44         55011
# 25-34         49718
# 65-74         41216
# 19-24         24230
# 75 or over    15226
#               12202
# 13-18          7045
# 7-12           1644
# 3-6             838
# 0-2             497
# Name: count, dtype: int64

# %% [markdown]
# kanidat kolom yang bermasalah:
#
# | name kolom    | total number of unique      |
# | ------------- | ------------- |
# | EaseofUse     | 13            |
# | Satisfaction  | 70            |
# | Sex           | 66            |

# %%
invalid_easeofuse_df = concat_df[concat_df['EaseofUse'].isin(['62261', '154215', '11147', '10149', '169930', '57948'])]

# %%
invalid_easeofuse_df.shape
# Out:
# (30, 12)

# %%
invalid_easeofuse_df[:10]
# Out:
#                Age                                          Condition  \
# 320440       55-64  Treatment of Depletion of Body\s Supply of Sodium
# 320441       45-54  Treatment of Depletion of Body\s Supply of Sodium
# 320442       25-34  Treatment of Depletion of Body\s Supply of Sodium
# 330057  75 or over  Treatment of Depletion of Body\s Supply of Sodium
# 353216       55-64                                      Plantar Warts
# 353217       25-34                                      Plantar Warts
# 353218       19-24                                               Corn
# 353219       19-24                                        Common Wart
# 353220       55-64                                      Plantar Warts
# 353223       25-34                                        Common Wart
#
#                             Date                                   Drug  \
# 320440   Potassium and Chloride'                              4/25/2016
# 320441   Potassium and Chloride'                              4/26/2014
# 320442   Potassium and Chloride'                               4/5/2014
# 330057   Potassium and Chloride'                               8/6/2009
# 353216                12/16/2016  dr scholl\s clear away adhesive patch
# 353217                  3/6/2014  dr scholl\s clear away adhesive patch
# 353218                  2/8/2013  dr scholl\s clear away adhesive patch
# 353219                 1/29/2012  dr scholl\s clear away adhesive patch
# 353220                 7/26/2011  dr scholl\s clear away adhesive patch
# 353223                 4/22/2011  dr scholl\s clear away adhesive patch
#
#                          DrugId EaseofUse Effectiveness  \
# 320440  pedialyte oral solution     11147             3
# 320441  pedialyte oral solution     11147             5
# 320442  pedialyte oral solution     11147             3
# 330057                      yte     10149             4
# 353216               medicated'    154215             1
# 353217               medicated'    154215             2
# 353218               medicated'    154215             5
# 353219               medicated'    154215             4
# 353220               medicated'    154215             2
# 353223               medicated'    154215             3
#
#                                                   Reviews Satisfaction  \
# 320440  3After small bowel resection, I had diarrhea a...            1
# 320441  4Felt once I drank this liquid I felt more ene...            5
# 320442  2my 2 yr old son has been sick with diarhea an...            1
# 330057  5I have low sodium and this has helped, altho ...            4
# 353216  1small discs did not stay in place - pads were...            1
# 353217  2I have used Dr. Scholl\s salicylic acid and t...            1
# 353218  4I\ve had a small hard corn on both of my pink...            3
# 353219  5I had two common warts on my hands and used D...            5
# 353220  1Medicated pads do not adhere well to skin and...            1
# 353223  2it will take the wart way for about 6 weeks t...            1
#
#            Sex                                              Sides UsefulCount
# 320440                      Mild  nausea and vomiting  may occur.           0
# 320441  Female              Mild  nausea and vomiting  may occur.           1
# 320442  Female              Mild  nausea and vomiting  may occur.           1
# 330057  Female              Mild  nausea and vomiting  may occur.           1
# 353216    Male  Slight burning,  skin  redness, and peeling ma...           2
# 353217  Female  Slight burning,  skin  redness, and peeling ma...           3
# 353218  Female  Slight burning,  skin  redness, and peeling ma...           1
# 353219  Female  Slight burning,  skin  redness, and peeling ma...           0
# 353220    Male  Slight burning,  skin  redness, and peeling ma...           2
# 353223  Female  Slight burning,  skin  redness, and peeling ma...           1

# %%
invalid_easeofuse_df_copy = invalid_easeofuse_df.copy(deep=True)
invalid_easeofuse_df_copy.iloc[:4].loc[:, 'Condition'] = invalid_easeofuse_df_copy[:4]['Condition'] + invalid_easeofuse_df_copy[:4]['Date']
invalid_easeofuse_df_copy.iloc[:4].loc[:, 'Date'] = invalid_easeofuse_df_copy[:4]['Drug']
invalid_easeofuse_df_copy.iloc[:4].loc[:, 'Drug'] = invalid_easeofuse_df_copy[:4]['DrugId']
invalid_easeofuse_df_copy.iloc[:4].loc[:, 'DrugId'] = invalid_easeofuse_df_copy[:4]['EaseofUse']

invalid_easeofuse_df_copy.iloc[4:].loc[:, 'Drug'] = invalid_easeofuse_df_copy.iloc[4:].loc[:, 'Drug'] + '' + invalid_easeofuse_df_copy.iloc[4:].loc[:, 'DrugId'] 
invalid_easeofuse_df_copy.iloc[4:].loc[:, 'DrugId'] = invalid_easeofuse_df_copy.iloc[4:].loc[:, 'EaseofUse']
invalid_easeofuse_df_copy['EaseofUse'] = invalid_easeofuse_df_copy['Effectiveness']
invalid_easeofuse_df_copy[['Effectiveness', 'Reviews']] = invalid_easeofuse_df_copy['Reviews'].str.extract(r'(\d+)(.*)', expand=True)

# %%
invalid_easeofuse_df_copy[:10]
# Out:
#                Age                                          Condition  \
# 320440       55-64  Treatment of Depletion of Body\s Supply of Sod...
# 320441       45-54  Treatment of Depletion of Body\s Supply of Sod...
# 320442       25-34  Treatment of Depletion of Body\s Supply of Sod...
# 330057  75 or over  Treatment of Depletion of Body\s Supply of Sod...
# 353216       55-64                                      Plantar Warts
# 353217       25-34                                      Plantar Warts
# 353218       19-24                                               Corn
# 353219       19-24                                        Common Wart
# 353220       55-64                                      Plantar Warts
# 353223       25-34                                        Common Wart
#
#               Date                                              Drug  DrugId  \
# 320440   4/25/2016                           pedialyte oral solution   11147
# 320441   4/26/2014                           pedialyte oral solution   11147
# 320442    4/5/2014                           pedialyte oral solution   11147
# 330057    8/6/2009                                               yte   10149
# 353216  12/16/2016  dr scholl\s clear away adhesive patch medicated'  154215
# 353217    3/6/2014  dr scholl\s clear away adhesive patch medicated'  154215
# 353218    2/8/2013  dr scholl\s clear away adhesive patch medicated'  154215
# 353219   1/29/2012  dr scholl\s clear away adhesive patch medicated'  154215
# 353220   7/26/2011  dr scholl\s clear away adhesive patch medicated'  154215
# 353223   4/22/2011  dr scholl\s clear away adhesive patch medicated'  154215
#
#        EaseofUse Effectiveness  \
# 320440         3             3
# 320441         5             4
# 320442         3             2
# 330057         4             5
# 353216         1             1
# 353217         2             2
# 353218         5             4
# 353219         4             5
# 353220         2             1
# 353223         3             2
#
#                                                   Reviews Satisfaction  \
# 320440  After small bowel resection, I had diarrhea an...            1
# 320441  Felt once I drank this liquid I felt more ener...            5
# 320442  my 2 yr old son has been sick with diarhea and...            1
# 330057  I have low sodium and this has helped, altho m...            4
# 353216  small discs did not stay in place - pads were ...            1
# 353217  I have used Dr. Scholl\s salicylic acid and th...            1
# 353218  I\ve had a small hard corn on both of my pinky...            3
# 353219  I had two common warts on my hands and used Dr...            5
# 353220  Medicated pads do not adhere well to skin and ...            1
# 353223  it will take the wart way for about 6 weeks th...            1
#
#            Sex                                              Sides UsefulCount
# 320440                      Mild  nausea and vomiting  may occur.           0
# 320441  Female              Mild  nausea and vomiting  may occur.           1
# 320442  Female              Mild  nausea and vomiting  may occur.           1
# 330057  Female              Mild  nausea and vomiting  may occur.           1
# 353216    Male  Slight burning,  skin  redness, and peeling ma...           2
# 353217  Female  Slight burning,  skin  redness, and peeling ma...           3
# 353218  Female  Slight burning,  skin  redness, and peeling ma...           1
# 353219  Female  Slight burning,  skin  redness, and peeling ma...           0
# 353220    Male  Slight burning,  skin  redness, and peeling ma...           2
# 353223  Female  Slight burning,  skin  redness, and peeling ma...           1

# %%
concat_df.loc[invalid_easeofuse_df_copy.index] = invalid_easeofuse_df_copy

# %%
concat_df['EaseofUse'].value_counts()
# Out:
# EaseofUse
# 5     192650
# 4      74732
# 3      41303
# 1      35927
# 2      18191
# 6          2
# 10         1
# Name: count, dtype: int64

# %%
concat_df['Sex'].value_counts()
# Out:
# Sex
# Female                                238119
# Male                                   98000
#                                        26520
#   dizziness                               24
#   headache                                14
#                                        ...
# ,3, '                                      1
#  irritability                              1
#  bleeding                                  1
#  peeling/flaking/scabbing/crusting         1
#  unusual  dreams                           1
# Name: count, Length: 66, dtype: int64

# %%
invalid_sex = concat_df[~concat_df['Sex'].str.contains(r'^male$|^female$|^\s*$', case=False)]

# %%
invalid_sex.shape
# Out:
# (167, 12)

# %%
invalid_sex[:5]
# Out:
#           Age                                          Condition        Date  \
# 31058   65-74                      Inability to have an Erection   7/29/2009
# 51324   45-54                       Allergic Rhinitis Prevention    5/1/2014
# 163162  45-54  Multiple Sclerosis Symptoms Return then Become...  10/31/2013
# 215722  65-74                           Type 2 Diabetes Mellitus   4/12/2014
# 219503  35-44                                   Neuropathic Pain   9/29/2009
#
#                                              Drug  DrugId EaseofUse  \
# 31058                                     levitra   76765         5
# 51324            nasonex aerosol, spray with pump    4820         5
# 163162                                  tecfidera  163868         5
# 215722                                glimepiride   12271         5
# 219503  gabapentin tablet, extended release 24 hr   14208         5
#
#        Effectiveness                                            Reviews  \
# 31058              4  I find that on ehalf hour is when it starts to...
# 51324              5  This drug literally changed my life.  Before I...
# 163162             5  I have been taking the pill for about 3 months...
# 215722             2                           I can\t take it at night
# 219503             3  just started. I think I have felt a calming of...
#
#                                        Satisfaction  \
# 31058                                      flushing
# 51324   ,5,Female,Nose/throat dryness or irritation
# 163162                                      redness
# 215722       it causes my blood sugar to bottom out
# 219503                         ,5,Female,Drowsiness
#
#                                    Sex  \
# 31058              stuffy/ runny nose
# 51324     blood -tinged  mucus /phlegm
# 163162                        itching
# 215722                           ,2, '
# 219503            loss of coordination
#
#                                                  Sides UsefulCount
# 31058                       or  dizziness  may occur.'          11
# 51324                     and  nosebleeds  may occur.'          14
# 163162   and burning feeling of the  skin  may occur.'          14
# 215722          Nausea  and  upset stomach  may occur.          17
# 219503                     and  dizziness  may occur.'          20

# %%
columns_invalid_sex = ['Reviews', 'Satisfaction', 'Sex', 'Sides']
joined_strings = invalid_sex[columns_invalid_sex].apply(lambda row: ''.join(row.astype(str)), axis=1)

# %%
joined_strings.shape
# Out:
# (167,)

# %%
joined_strings[:5]
# Out:
# 31058     I find that on ehalf hour is when it starts to...
# 51324     This drug literally changed my life.  Before I...
# 163162    I have been taking the pill for about 3 months...
# 215722    I can\t take it at night it causes my blood su...
# 219503    just started. I think I have felt a calming of...
# dtype: object

# %%
for sample, value in enumerate(joined_strings):
    if sample >= 10:
        break
    print(value)
# Out:
# I find that on ehalf hour is when it starts to work for me and my erection is fairly solid and it stay that waay untill orgasm.  Also with in reasonable space of time I can have another erection though softer but works well.  I f not the night before the morning after when my erections are like my old pee erections but dont go away after peeing in I engage in sexualy activity\',4,Male,Headache  flushing stuffy/ runny nose  or  dizziness  may occur.'
# This drug literally changed my life.  Before I started taking it, I had 2-3 sinus infections/yr - I was always tired - always had sinus pressure.  A couple of times it progressed to pneumonia.  Now - I haven\t been sick in 2 yrs.  I have an occasional nose bleed but then I just make sure I\'m getting enough moisture in the air and it stops.  I use it year round,5,Female,Nose/throat dryness or irritation  blood -tinged  mucus /phlegm and  nosebleeds  may occur.'
# I have been taking the pill for about 3 months and is very happy with it\',5,Female,Flushing/warmth redness  itching  and burning feeling of the  skin  may occur.'
# I can\t take it at night it causes my blood sugar to bottom out,2, 'Nausea  and  upset stomach  may occur.
# just started. I think I have felt a calming of aching nerve related body pain and mood.It\s only been 1 day,5,Female,Drowsiness loss of coordination and  dizziness  may occur.'
# The one strange side effect is - it has colored my stool \"rust\".  Don\t know if anyone else has experienced this,5,Female,Diarrhea   headache  or  nausea  may occur.'
# so far i believe the drug is working but my mouth is so dry it is driving me nuts, it is also making me a little light headed at times, i do feel better however, thank goodness for someone else\s review of the same symptom,3,Female,Diarrhea   headache  or  nausea  may occur.'
# I hope I never stop taking this med. It takes a way the crippling stiff muscles, with out it I can\t roll over in bed without being in sever pain my skin doesn\'t feel raw.I can get a hug without cringing from pain. I stoped taking it because I thought it wasn\'t helping. I was quick to take it again to me it has been a god send. I have NO side effects from it. I just can\'t tell you how much it has helped me with Fibral mialgie.The cramps that your body goes through is crushateing. Mucles get hard as rocks  gets huge bumps. I hope this has helped some one. It takes a little time to work. But it does work ,5,Female,Drowsiness  dizziness   dry mouth   constipation  difficulty concentrating or  weight  gain may occur.'
# I have compressed nerve in my lower back due to a fall and I was having a hard time functioning and one morning I got up and the pain was so bad I could not move. I was really scared. I went to my family dr. and she presribed this and only 1 pill and I felt such relief. I have been on this for about 1 and half years and probsbly will be on it for the rest of my life.I don\t want surgery unless it is the last resort,5,Female,Drowsiness  dizziness   dry mouth   constipation  difficulty concentrating or  weight  gain may occur.'
# 2 years ago I took lovaza and my colestrol went down to  160  from 260 I took it for three months  It went back up to 260 within a year after I quit taking it.  Now its back up to 267, I have been taking it for six months this year and it has not went down at all I dont eat meat , butter or fried foods, Mostly egg whites and  very little fruits and veggies I dont eat the latter because when I do My leggs get realy restless at night after I lay down and relax never bother\s me in the day time only at night,2,Female,Upset stomach  burping and strange taste in  mouth  may occur.'

# %%
invalid_sex_fixed = joined_strings.str.extract(r'^(.+?),(\d+),(\w+),(.+)$')

# %%
invalid_sex_fixed[:15]
# Out:
#                                                         0    1       2  \
# 31058   I find that on ehalf hour is when it starts to...    4    Male
# 51324   This drug literally changed my life.  Before I...    5  Female
# 163162  I have been taking the pill for about 3 months...    5  Female
# 215722                                                NaN  NaN     NaN
# 219503  just started. I think I have felt a calming of...    5  Female
# 294488  The one strange side effect is - it has colore...    5  Female
# 294734  so far i believe the drug is working but my mo...    3  Female
# 298207  I hope I never stop taking this med. It takes ...    5  Female
# 298438  I have compressed nerve in my lower back due t...    5  Female
# 299110  2 years ago I took lovaza and my colestrol wen...    2  Female
# 299860  The first couple of months Lisinopril worked f...    1  Female
# 300116  Really don\t know if the issues I have is a si...    4    Male
# 300562  The first couple of months Lisinopril worked f...    1  Female
# 300637  Really don\t know if the issues I have is a si...    4    Male
# 301444  I have suffered from insomnia for most of my l...    1  Female
#
#                                                         3
# 31058   Headache  flushing stuffy/ runny nose  or  diz...
# 51324   Nose/throat dryness or irritation  blood -ting...
# 163162  Flushing/warmth redness  itching  and burning ...
# 215722                                                NaN
# 219503  Drowsiness loss of coordination and  dizziness...
# 294488       Diarrhea   headache  or  nausea  may occur.'
# 294734       Diarrhea   headache  or  nausea  may occur.'
# 298207  Drowsiness  dizziness   dry mouth   constipati...
# 298438  Drowsiness  dizziness   dry mouth   constipati...
# 299110  Upset stomach  burping and strange taste in  m...
# 299860  Dizziness   lightheadedness  tiredness or  hea...
# 300116  Dizziness   lightheadedness  tiredness or  hea...
# 300562  Dizziness   lightheadedness  tiredness or  hea...
# 300637  Dizziness   lightheadedness  tiredness or  hea...
# 301444  Dizziness   dry mouth  unpleasant taste or dif...

# %%
invalid_sex_fixed.rename(columns={index:value for index, value in enumerate(columns_invalid_sex)}, inplace=True)

# %%
invalid_sex_fixed[:15]
# Out:
#                                                   Reviews Satisfaction  \
# 31058   I find that on ehalf hour is when it starts to...            4
# 51324   This drug literally changed my life.  Before I...            5
# 163162  I have been taking the pill for about 3 months...            5
# 215722                                                NaN          NaN
# 219503  just started. I think I have felt a calming of...            5
# 294488  The one strange side effect is - it has colore...            5
# 294734  so far i believe the drug is working but my mo...            3
# 298207  I hope I never stop taking this med. It takes ...            5
# 298438  I have compressed nerve in my lower back due t...            5
# 299110  2 years ago I took lovaza and my colestrol wen...            2
# 299860  The first couple of months Lisinopril worked f...            1
# 300116  Really don\t know if the issues I have is a si...            4
# 300562  The first couple of months Lisinopril worked f...            1
# 300637  Really don\t know if the issues I have is a si...            4
# 301444  I have suffered from insomnia for most of my l...            1
#
#            Sex                                              Sides
# 31058     Male  Headache  flushing stuffy/ runny nose  or  diz...
# 51324   Female  Nose/throat dryness or irritation  blood -ting...
# 163162  Female  Flushing/warmth redness  itching  and burning ...
# 215722     NaN                                                NaN
# 219503  Female  Drowsiness loss of coordination and  dizziness...
# 294488  Female       Diarrhea   headache  or  nausea  may occur.'
# 294734  Female       Diarrhea   headache  or  nausea  may occur.'
# 298207  Female  Drowsiness  dizziness   dry mouth   constipati...
# 298438  Female  Drowsiness  dizziness   dry mouth   constipati...
# 299110  Female  Upset stomach  burping and strange taste in  m...
# 299860  Female  Dizziness   lightheadedness  tiredness or  hea...
# 300116    Male  Dizziness   lightheadedness  tiredness or  hea...
# 300562  Female  Dizziness   lightheadedness  tiredness or  hea...
# 300637    Male  Dizziness   lightheadedness  tiredness or  hea...
# 301444  Female  Dizziness   dry mouth  unpleasant taste or dif...

# %%
get_nan_index_in_invalid_sex_fixed = invalid_sex_fixed[invalid_sex_fixed['Sex'].isna()].index
get_nan_index_in_invalid_sex_fixed
# Out:
# Index([215722, 306577, 306579, 307538, 307540, 308658, 324376, 324446, 326417,
#        337005, 347550, 350319, 351953, 353926, 355615, 355720, 355729],
#       dtype='int64')

# %%
for value in joined_strings.loc[get_nan_index_in_invalid_sex_fixed]:
    print(value)
# Out:
# I can\t take it at night it causes my blood sugar to bottom out,2, 'Nausea  and  upset stomach  may occur.
# I have severe Scoliosis,I\m 61yrs I was diagnosed whenot I was 11yrs old.I never had surgery iwore a backbrace 4yrs after all I went threw finally ended up in a pain clinic.Been on 3 different medsnow I take a 15mg it gives me good relief.I can now do things I couldnt.I am thankful for the relief,4, 'Nausea ,  vomiting ,  constipation ,  lightheadedness ,  dizziness , or drowsiness may occur.
# I have severe Scoliosis,I\m 61yrs I was diagnosed whenot I was 11yrs old.I never had surgery iwore a backbrace 4yrs after all I went threw finally ended up in a pain clinic.Been on 3 different medsnow I take a 15mg it gives me good relief.I can now do things I couldnt.I am thankful for the relief,4, 'Nausea ,  vomiting ,  constipation ,  lightheadedness ,  dizziness , or drowsiness may occur.
# I have severe Scoliosis,I\m 61yrs I was diagnosed whenot I was 11yrs old.I never had surgery iwore a backbrace 4yrs after all I went threw finally ended up in a pain clinic.Been on 3 different medsnow I take a 15mg it gives me good relief.I can now do things I couldnt.I am thankful for the relief,4, 'Nausea ,  vomiting ,  constipation ,  lightheadedness ,  dizziness , or drowsiness may occur.
# I have severe Scoliosis,I\m 61yrs I was diagnosed whenot I was 11yrs old.I never had surgery iwore a backbrace 4yrs after all I went threw finally ended up in a pain clinic.Been on 3 different medsnow I take a 15mg it gives me good relief.I can now do things I couldnt.I am thankful for the relief,4, 'Nausea ,  vomiting ,  constipation ,  dry mouth ,  weakness ,  sweating ,  lightheadedness ,  dizziness , or drowsiness may occur.
# when I first had the nexplanon put in my arm I was excited because I didn\t have to worry about bc for the next 3 years. Now bleed extremely heavy to the point when the clots come out it looks like I\'m having a miscarriage I have mood swings like I\'m bipolar and I gained almost 60 pounds. I don\'t recommend this birth control to anyone,1, 'Nausea ,  stomach  cramping/ bloating ,  dizziness ,  headache ,  breast  tenderness,  acne ,  hair loss ,  weight  gain, and  vaginal irritation /discharge may occur.
# 5This medication is a God send, it totally controls my mania (I do not do depression at all but I do extreme mania with aggressive tendencies)  In addition this medication aids in sleeping through the night and I still dream...however on some days there is a bit of a groggy feeling for a couple hours I would not operate heavy equipment during this time...Namaste\',4, 'Constipation , drowsiness,  upset stomach , tiredness,  weight  gain,  blurred vision , or  dry mouth  may occur.
# 5This medication is a God send, it totally controls my mania (I do not do depression at all but I do extreme mania with aggressive tendencies)  In addition this medication aids in sleeping through the night and I still dream...however on some days there is a bit of a groggy feeling for a couple hours I would not operate heavy equipment during this time...Namaste\',4, 'Constipation , drowsiness,  upset stomach , tiredness,  weight  gain,  blurred vision , or  dry mouth  may occur.
# It has burnt my 2 leg\s to the bone on April 2013 3years down the line wounds still open unbearable pain district nurses in every day caused vasculitis and then after a long period of hospitalisation every couple of months I am back in hospital with cellulites it\'s been hell on earth chances are 1 million to 1 don\'t take the gamble don\'take sitagliptin ,1, '
# Hi everyone, \nI just started using this cream. I can\t really give a full review as of yet. I am hoping I can give a great review in a few weeks/months. \nI do however have a question for the other women who have used this. \nDid you shave the area prior to using the cream? \nIf so did you start getting little white \"bumps\" on the area? \nI am getting married in October and need this hairy chin and neck GONE!! Any hope? \nThank you,3, 'Burning, stinging, tingling, and redness of the  skin  may occur.
# This has been a wonder drug for me in combination with Lamictal.  I was able to lose over 100 pounds while taking this medication.  I\ve not had any mood swings but still suffer at times with depression.  My dr. put me on some vitamins that help with anxiety depression and mania.  I highly recommend Geodon,5, 'Drowsiness,  dizziness ,  lightheadedness ,  weakness ,  nausea ,  vomiting ,  runny nose , and  cough  may occur.
# this drug is amazing for lowering your bp,but you cant take it every day just as needed,,i get cramps in my fingers and feet,it makes you so tired and lazy,cause it gets your bl so low after a few days,pee a lot up all night,i only take it when I fall off the wagon and it gets me back in a few days then I don\t take it any more ,2, 'Upset stomach ,  dizziness , or  headache  may occur as your body adjusts to the  medication . If any of these effects last or get worse, tell your doctor or  pharmacist  promptly.
# This medication has the worst side effects,withdrawing from friends and family, trouble speaking, over emotional, anger, I can\t sleep an when I can sleep my foot taps anxiety attacks hot sweats get the need to get up and move around or pace mostly in the ankle area and flexors  migraine headache\'s,2, 'Drowsiness,  dizziness , unusual tiredness, or  weakness  may occur.
# Long term usage, too many side effects to mention,  all were life altering side effects.  Kept my B/P down, but the trade off wasn\t worth it.  Trying to find a new med,1, 'Dizziness  or  lightheadedness  may occur as your body adjusts to the  medication . If any of these effects persist or worsen, tell your doctor or  pharmacist  promptly.
# been on it for a few weeks don\t really notice a diference with pain am also on oxicodone kind of have anxity feelings with this drug when first take but got better later,2, 'Drowsiness,  dizziness ,  weakness , tiredness,  headache ,  trouble sleeping ,  nausea , increased urination, or  constipation  may occur.
# I think I have a unique problem in that antibiotics cause soreness, aches and pains in my ankles and knees. This is my 2nd day and I can barely get around. I\m thinking of stopping taking it before the 5 days,1, 'Stomach  upset,  diarrhea ,  nausea , or  vomiting  may occur.
# I think I have a unique problem in that antibiotics cause soreness, aches and pains in my ankles and knees. This is my 2nd day and I can barely get around. I\m thinking of stopping taking it before the 5 days,1, 'Stomach  upset,  diarrhea ,  nausea , or  vomiting  may occur.

# %%
extracted_nan_index_in_invalid_sex_fixed = joined_strings.loc[get_nan_index_in_invalid_sex_fixed].str.extract(r'^(.+?),(\d+),(.+)$')

# %%
extracted_nan_index_in_invalid_sex_fixed
# Out:
#                                                         0  1  \
# 215722  I can\t take it at night it causes my blood su...  2
# 306577  I have severe Scoliosis,I\m 61yrs I was diagno...  4
# 306579  I have severe Scoliosis,I\m 61yrs I was diagno...  4
# 307538  I have severe Scoliosis,I\m 61yrs I was diagno...  4
# 307540  I have severe Scoliosis,I\m 61yrs I was diagno...  4
# 308658  when I first had the nexplanon put in my arm I...  1
# 324376  5This medication is a God send, it totally con...  4
# 324446  5This medication is a God send, it totally con...  4
# 326417  It has burnt my 2 leg\s to the bone on April 2...  1
# 337005  Hi everyone, \nI just started using this cream...  3
# 347550  This has been a wonder drug for me in combinat...  5
# 350319  this drug is amazing for lowering your bp,but ...  2
# 351953  This medication has the worst side effects,wit...  2
# 353926  Long term usage, too many side effects to ment...  1
# 355615  been on it for a few weeks don\t really notice...  2
# 355720  I think I have a unique problem in that antibi...  1
# 355729  I think I have a unique problem in that antibi...  1
#
#                                                         2
# 215722            'Nausea  and  upset stomach  may occur.
# 306577   'Nausea ,  vomiting ,  constipation ,  lighth...
# 306579   'Nausea ,  vomiting ,  constipation ,  lighth...
# 307538   'Nausea ,  vomiting ,  constipation ,  lighth...
# 307540   'Nausea ,  vomiting ,  constipation ,  dry mo...
# 308658   'Nausea ,  stomach  cramping/ bloating ,  diz...
# 324376   'Constipation , drowsiness,  upset stomach , ...
# 324446   'Constipation , drowsiness,  upset stomach , ...
# 326417                                                 '
# 337005   'Burning, stinging, tingling, and redness of ...
# 347550   'Drowsiness,  dizziness ,  lightheadedness , ...
# 350319   'Upset stomach ,  dizziness , or  headache  m...
# 351953   'Drowsiness,  dizziness , unusual tiredness, ...
# 353926   'Dizziness  or  lightheadedness  may occur as...
# 355615   'Drowsiness,  dizziness ,  weakness , tiredne...
# 355720   'Stomach  upset,  diarrhea ,  nausea , or  vo...
# 355729   'Stomach  upset,  diarrhea ,  nausea , or  vo...

# %%
invalid_sex_fixed.loc[extracted_nan_index_in_invalid_sex_fixed.index, ['Reviews', 'Satisfaction', 'Sides']] = extracted_nan_index_in_invalid_sex_fixed.values

# %%
invalid_sex_fixed.loc[extracted_nan_index_in_invalid_sex_fixed.index]
# Out:
#                                                   Reviews Satisfaction  Sex  \
# 215722  I can\t take it at night it causes my blood su...            2  NaN
# 306577  I have severe Scoliosis,I\m 61yrs I was diagno...            4  NaN
# 306579  I have severe Scoliosis,I\m 61yrs I was diagno...            4  NaN
# 307538  I have severe Scoliosis,I\m 61yrs I was diagno...            4  NaN
# 307540  I have severe Scoliosis,I\m 61yrs I was diagno...            4  NaN
# 308658  when I first had the nexplanon put in my arm I...            1  NaN
# 324376  5This medication is a God send, it totally con...            4  NaN
# 324446  5This medication is a God send, it totally con...            4  NaN
# 326417  It has burnt my 2 leg\s to the bone on April 2...            1  NaN
# 337005  Hi everyone, \nI just started using this cream...            3  NaN
# 347550  This has been a wonder drug for me in combinat...            5  NaN
# 350319  this drug is amazing for lowering your bp,but ...            2  NaN
# 351953  This medication has the worst side effects,wit...            2  NaN
# 353926  Long term usage, too many side effects to ment...            1  NaN
# 355615  been on it for a few weeks don\t really notice...            2  NaN
# 355720  I think I have a unique problem in that antibi...            1  NaN
# 355729  I think I have a unique problem in that antibi...            1  NaN
#
#                                                     Sides
# 215722            'Nausea  and  upset stomach  may occur.
# 306577   'Nausea ,  vomiting ,  constipation ,  lighth...
# 306579   'Nausea ,  vomiting ,  constipation ,  lighth...
# 307538   'Nausea ,  vomiting ,  constipation ,  lighth...
# 307540   'Nausea ,  vomiting ,  constipation ,  dry mo...
# 308658   'Nausea ,  stomach  cramping/ bloating ,  diz...
# 324376   'Constipation , drowsiness,  upset stomach , ...
# 324446   'Constipation , drowsiness,  upset stomach , ...
# 326417                                                 '
# 337005   'Burning, stinging, tingling, and redness of ...
# 347550   'Drowsiness,  dizziness ,  lightheadedness , ...
# 350319   'Upset stomach ,  dizziness , or  headache  m...
# 351953   'Drowsiness,  dizziness , unusual tiredness, ...
# 353926   'Dizziness  or  lightheadedness  may occur as...
# 355615   'Drowsiness,  dizziness ,  weakness , tiredne...
# 355720   'Stomach  upset,  diarrhea ,  nausea , or  vo...
# 355729   'Stomach  upset,  diarrhea ,  nausea , or  vo...

# %%
invalid_sex_fixed.shape
# Out:
# (167, 4)

# %%
invalid_sex_fixed
# Out:
#                                                   Reviews Satisfaction  \
# 31058   I find that on ehalf hour is when it starts to...            4
# 51324   This drug literally changed my life.  Before I...            5
# 163162  I have been taking the pill for about 3 months...            5
# 215722  I can\t take it at night it causes my blood su...            2
# 219503  just started. I think I have felt a calming of...            5
# ...                                                   ...          ...
# 361380  I to like the others applied it to my shoulder...            1
# 361851      Can\t sleep at night and difficult to urinate            1
# 361952  so far i believe the drug is working but my mo...            3
# 361967  The one strange side effect is - it has colore...            5
# 362696  I have tried to quit chewing and then smoking ...            5
#
#            Sex                                              Sides
# 31058     Male  Headache  flushing stuffy/ runny nose  or  diz...
# 51324   Female  Nose/throat dryness or irritation  blood -ting...
# 163162  Female  Flushing/warmth redness  itching  and burning ...
# 215722     NaN            'Nausea  and  upset stomach  may occur.
# 219503  Female  Drowsiness loss of coordination and  dizziness...
# ...        ...                                                ...
# 361380  Female  Warmth stinging or burning on the application ...
# 361851  Female  Nausea   dry mouth  loss of appetite tiredness...
# 361952  Female  Diarrhea   nausea   vomiting   headache  or  d...
# 361967  Female  Diarrhea   nausea   vomiting   headache  or  d...
# 362696    Male  Nausea   headache   vomiting  drowsiness gas  ...
#
# [167 rows x 4 columns]

# %%
concat_df.loc[invalid_sex_fixed.index, invalid_sex_fixed.columns]
# Out:
#                                                   Reviews  \
# 31058   I find that on ehalf hour is when it starts to...
# 51324   This drug literally changed my life.  Before I...
# 163162  I have been taking the pill for about 3 months...
# 215722                           I can\t take it at night
# 219503  just started. I think I have felt a calming of...
# ...                                                   ...
# 361380  I to like the others applied it to my shoulder...
# 361851  Can\t sleep at night and difficult to urinate,...
# 361952  so far i believe the drug is working but my mo...
# 361967  The one strange side effect is - it has colore...
# 362696  I have tried to quit chewing and then smoking ...
#
#                                        Satisfaction  \
# 31058                                      flushing
# 51324   ,5,Female,Nose/throat dryness or irritation
# 163162                                      redness
# 215722       it causes my blood sugar to bottom out
# 219503                         ,5,Female,Drowsiness
# ...                                             ...
# 361380                             ,1,Female,Warmth
# 361851                                    sweating
# 361952                                    vomiting
# 361967                                    vomiting
# 362696                            trouble sleeping
#
#                                    Sex  \
# 31058              stuffy/ runny nose
# 51324     blood -tinged  mucus /phlegm
# 163162                        itching
# 215722                           ,2, '
# 219503            loss of coordination
# ...                                ...
# 361380                        stinging
# 361851                 blurred vision
# 361952                       headache
# 361967                       headache
# 362696                unusual  dreams
#
#                                                   Sides
# 31058                        or  dizziness  may occur.'
# 51324                      and  nosebleeds  may occur.'
# 163162    and burning feeling of the  skin  may occur.'
# 215722           Nausea  and  upset stomach  may occur.
# 219503                      and  dizziness  may occur.'
# ...                                                 ...
# 361380   or burning on the application site may occur.'
# 361851                          and yawning may occur.'
# 361952   or  diaper rash  in young children may occur.'
# 361967   or  diaper rash  in young children may occur.'
# 362696                  or changes in taste may occur.'
#
# [167 rows x 4 columns]

# %%
concat_df.loc[invalid_sex_fixed.index, invalid_sex_fixed.columns] = invalid_sex_fixed.values

# %%
concat_df.loc[invalid_sex_fixed.index]
# Out:
#                Age                                          Condition  \
# 31058        65-74                      Inability to have an Erection
# 51324        45-54                       Allergic Rhinitis Prevention
# 163162       45-54  Multiple Sclerosis Symptoms Return then Become...
# 215722       65-74                           Type 2 Diabetes Mellitus
# 219503       35-44                                   Neuropathic Pain
# ...            ...                                                ...
# 361380       45-54                                           Backache
# 361851       55-64                                         Depression
# 361952       55-64  Acute Maxillary Sinus S. Pneumoniae Bacteria I...
# 361967  75 or over  Acute Maxillary Sinus S. Pneumoniae Bacteria I...
# 362696       35-44                                       Stop Smoking
#
#               Date                                       Drug  DrugId  \
# 31058    7/29/2009                                    levitra   76765
# 51324     5/1/2014           nasonex aerosol, spray with pump    4820
# 163162  10/31/2013                                  tecfidera  163868
# 215722   4/12/2014                                glimepiride   12271
# 219503   9/29/2009  gabapentin tablet, extended release 24 hr   14208
# ...            ...                                        ...     ...
# 361380    3/1/2011                          capzasin-hp cream   61857
# 361851    1/7/2012                                     celexa    8603
# 361952   12/8/2007                                   cefdinir    5543
# 361967   1/27/2012                                   cefdinir    5543
# 362696  11/19/2007                                    chantix  144470
#
#        EaseofUse Effectiveness  \
# 31058          5             4
# 51324          5             5
# 163162         5             5
# 215722         5             2
# 219503         5             3
# ...          ...           ...
# 361380         1             1
# 361851         1             1
# 361952         5             3
# 361967         5             4
# 362696         5             5
#
#                                                   Reviews Satisfaction  \
# 31058   I find that on ehalf hour is when it starts to...            4
# 51324   This drug literally changed my life.  Before I...            5
# 163162  I have been taking the pill for about 3 months...            5
# 215722  I can\t take it at night it causes my blood su...            2
# 219503  just started. I think I have felt a calming of...            5
# ...                                                   ...          ...
# 361380  I to like the others applied it to my shoulder...            1
# 361851      Can\t sleep at night and difficult to urinate            1
# 361952  so far i believe the drug is working but my mo...            3
# 361967  The one strange side effect is - it has colore...            5
# 362696  I have tried to quit chewing and then smoking ...            5
#
#            Sex                                              Sides UsefulCount
# 31058     Male  Headache  flushing stuffy/ runny nose  or  diz...          11
# 51324   Female  Nose/throat dryness or irritation  blood -ting...          14
# 163162  Female  Flushing/warmth redness  itching  and burning ...          14
# 215722     NaN            'Nausea  and  upset stomach  may occur.          17
# 219503  Female  Drowsiness loss of coordination and  dizziness...          20
# ...        ...                                                ...         ...
# 361380  Female  Warmth stinging or burning on the application ...           1
# 361851  Female  Nausea   dry mouth  loss of appetite tiredness...           5
# 361952  Female  Diarrhea   nausea   vomiting   headache  or  d...           9
# 361967  Female  Diarrhea   nausea   vomiting   headache  or  d...           1
# 362696    Male  Nausea   headache   vomiting  drowsiness gas  ...           7
#
# [167 rows x 12 columns]

# %%
concat_df['Sex'].value_counts()
# Out:
# Sex
# Female    238226
# Male       98043
#            26520
# Name: count, dtype: int64

# %%
concat_df['Satisfaction'].value_counts()
# Out:
# Satisfaction
# 5     111550
# 1     100901
# 4      63158
# 3      51852
# 2      35342
# 6          2
# 10         1
# Name: count, dtype: int64

# %%
# empty_string_columns = concat_df.columns[concat_df.apply(lambda col: col.str.match(r'^\s*$').any())]

# print(empty_string_columns)

# concat_df.replace(r'^\s*$', np.nan, regex=True, inplace=True)
