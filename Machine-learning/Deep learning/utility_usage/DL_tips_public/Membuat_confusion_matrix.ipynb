# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from nnfs.datasets import spiral_data
# Out:
# 2022-09-21 17:47:43.014877: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-21 17:47:43.529161: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-09-21 17:47:43.529197: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-09-21 17:47:43.579885: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-09-21 17:47:44.590207: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-09-21 17:47:44.590282: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-09-21 17:47:44.590290: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
X, y = spiral_data(1000, classes=2)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=.2,
    random_state=43
)


print(f'X_train{X_train.shape}')
print(f'X_test{X_test.shape}')
print(f'y_train{y_train.shape}')
print(f'y_test{y_test.shape}')
print(f'X{X.shape}')
print(f'y{y.shape}')
# Out:
# X_train(1600, 2)
# X_test(400, 2)
# y_train(1600,)
# y_test(400,)
# X(2000, 2)
# y(2000,)

# %%
model = keras.Sequential([
    keras.layers.Dense(10, activation='relu'),
    keras.layers.Dense(5, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid'),
])

model.compile(
    loss=keras.losses.BinaryCrossentropy(),
    optimizer=keras.optimizers.Adam(),
    metrics=['accuracy']
)

# membuat callbacks
lr_rate_schedular = keras.callbacks.LearningRateScheduler(lambda epoch: 1e-4 * 10**(epoch/20))

history = model.fit(
    X_train, 
    y_train, 
    epochs=100,
    callbacks=[lr_rate_schedular]
)
# Out:
# Epoch 1/100
# 2022-09-21 17:47:47.358930: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-09-21 17:47:47.359331: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-09-21 17:47:47.359350: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (anggads01): /proc/driver/nvidia/version does not exist
# 2022-09-21 17:47:47.360018: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 50/50 [==============================] - 0s 888us/step - loss: 0.6958 - accuracy: 0.5194 - lr: 1.0000e-04
# Epoch 2/100
# 50/50 [==============================] - 0s 876us/step - loss: 0.6954 - accuracy: 0.5206 - lr: 1.1220e-04
# Epoch 3/100
# 50/50 [==============================] - 0s 913us/step - loss: 0.6949 - accuracy: 0.5344 - lr: 1.2589e-04
# Epoch 4/100
# 50/50 [==============================] - 0s 942us/step - loss: 0.6945 - accuracy: 0.5475 - lr: 1.4125e-04
# Epoch 5/100
# 50/50 [==============================] - 0s 934us/step - loss: 0.6940 - accuracy: 0.5556 - lr: 1.5849e-04
# Epoch 6/100
# 50/50 [==============================] - 0s 897us/step - loss: 0.6934 - accuracy: 0.5569 - lr: 1.7783e-04
# Epoch 7/100
# 50/50 [==============================] - 0s 855us/step - loss: 0.6928 - accuracy: 0.5650 - lr: 1.9953e-04
# Epoch 8/100
# 50/50 [==============================] - 0s 924us/step - loss: 0.6922 - accuracy: 0.5688 - lr: 2.2387e-04
# Epoch 9/100
# 50/50 [==============================] - 0s 996us/step - loss: 0.6916 - accuracy: 0.5719 - lr: 2.5119e-04
# Epoch 10/100
# 50/50 [==============================] - 0s 989us/step - loss: 0.6909 - accuracy: 0.5819 - lr: 2.8184e-04
# Epoch 11/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6900 - accuracy: 0.5906 - lr: 3.1623e-04
# Epoch 12/100
# 50/50 [==============================] - 0s 880us/step - loss: 0.6890 - accuracy: 0.5950 - lr: 3.5481e-04
# Epoch 13/100
# 50/50 [==============================] - 0s 938us/step - loss: 0.6882 - accuracy: 0.5806 - lr: 3.9811e-04
# Epoch 14/100
# 50/50 [==============================] - 0s 933us/step - loss: 0.6873 - accuracy: 0.5888 - lr: 4.4668e-04
# Epoch 15/100
# 50/50 [==============================] - 0s 904us/step - loss: 0.6861 - accuracy: 0.5906 - lr: 5.0119e-04
# Epoch 16/100
# 50/50 [==============================] - 0s 940us/step - loss: 0.6845 - accuracy: 0.5956 - lr: 5.6234e-04
# Epoch 17/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.
# 50/50 [==============================] - 0s 1ms/step - loss: 1.0473 - accuracy: 0.4875 - lr: 7.9433
# Epoch 100/100
# 50/50 [==============================] - 0s 923us/step - loss: 0.9530 - accuracy: 0.5150 - lr: 8.9125

# %%
# Tuning lr ideally

lrs =  1e-4 * (10**(tf.range(100) / 20))
loss = np.array(history.history['loss'])

history_lr = pd.DataFrame(np.c_[lrs, np.array(history.history['loss'])])
x_lr, y_loss = history_lr.iloc[np.argmin(loss), :] 

plt.semilogx(lrs, loss)
plt.xlabel('Learning rate')
plt.ylabel('Loss')
plt.title('Learning rate vs. Loss')

plt.annotate(
    f"loss: {round(y_loss, 2)}\n lr: {round(x_lr, 3)}", 
    xy=(x_lr, y_loss), 
    xytext=(y_loss, y_loss), 
    arrowprops=dict(arrowstyle="->", 
    color="green", 
    lw=2,
   )
)

plt.show()

# %%
model = keras.Sequential([
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid'),
])

model.compile(
    loss=keras.losses.BinaryCrossentropy(),
    optimizer=keras.optimizers.Adam(learning_rate=0.022),
    metrics=['accuracy']
)


history = model.fit(
    X_train, 
    y_train, 
    epochs=100,
)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 0s 972us/step - loss: 0.6670 - accuracy: 0.5644
# Epoch 2/100
# 50/50 [==============================] - 0s 861us/step - loss: 0.6185 - accuracy: 0.5906
# Epoch 3/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5503 - accuracy: 0.7262
# Epoch 4/100
# 50/50 [==============================] - 0s 931us/step - loss: 0.4106 - accuracy: 0.8450
# Epoch 5/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3513 - accuracy: 0.8744
# Epoch 6/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3162 - accuracy: 0.8850
# Epoch 7/100
# 50/50 [==============================] - 0s 997us/step - loss: 0.3044 - accuracy: 0.9013
# Epoch 8/100
# 50/50 [==============================] - 0s 969us/step - loss: 0.1904 - accuracy: 0.9381
# Epoch 9/100
# 50/50 [==============================] - 0s 962us/step - loss: 0.1866 - accuracy: 0.9431
# Epoch 10/100
# 50/50 [==============================] - 0s 963us/step - loss: 0.1291 - accuracy: 0.9569
# Epoch 11/100
# 50/50 [==============================] - 0s 952us/step - loss: 0.1101 - accuracy: 0.9663
# Epoch 12/100
# 50/50 [==============================] - 0s 974us/step - loss: 0.1197 - accuracy: 0.9656
# Epoch 13/100
# 50/50 [==============================] - 0s 962us/step - loss: 0.1315 - accuracy: 0.9588
# Epoch 14/100
# 50/50 [==============================] - 0s 950us/step - loss: 0.1318 - accuracy: 0.9625
# Epoch 15/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1328 - accuracy: 0.9631
# Epoch 16/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1239 - accuracy: 0.9669
# Epoch 17/100
# 50/50 [==============================] - 0s 997us/step - loss: 0.0935 - accuracy: 0.9731
# Epoch 18/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0697 - accuracy: 0.9775
# Epoch 19/100
# 50/50 [==============================] - 0s 977us/step - loss: 0.0678 - accuracy: 0.9769
# Epoch 20/100
# 50/50 [==============================] - 0s 987us/step - loss: 0.1154 - accuracy: 0.9694
# Epoch 21/100
# 50/50 [==============================] - 0s 949us/step - loss: 0.1223 - accuracy: 0.9600
# Epoch 22/100
# 50/50 [==============================] - 0s 944us/step - loss: 0.0723 - accuracy: 0.9781
# Epoch 23/100
# 50/50 [==============================] - 0s 913us/step - loss: 0.0720 - accuracy: 0.9812
# Epoch 24/100
# 50/50 [==============================] - 0s 934us/step - loss: 0.0848 - accuracy: 0.9700
# Epoch 25/100
# 50/50 [==============================] - 0s 973us/step - loss: 0.0932 - accuracy: 0.9731
# Epoch 26/100
# 50/50 [==============================] - 0s 964us/step - loss: 0.0755 - accuracy: 0.9775
# Epoch 27/100
# 50/50 [==============================] - 0s 954us/step - loss: 0.0636 - accuracy: 0.9806
# Epoch 28/100
# 50/50 [==============================] - 0s 898us/step - loss: 0.0733 - accuracy: 0.9806
# Epoch 29/100
# 50/50 [==============================] - 0s 979us/step - loss: 0.1005 - accuracy: 0.9712
# Epoch 30/100
# 50/50 [==============================] - 0s 944us/step - loss: 0.0677 - accuracy: 0.9831
# Epoch 31/100
# 50/50 [==============================] - 0s 993us/step - loss: 0.0812 - accuracy: 0.9706
# Epoch 32/100
# 50/50 [==============================] - 0s 976us/step - loss: 0.0709 - accuracy: 0.9819
# Epoch 33/100
# 50/50 [==============================] - 0s 944us/step - loss: 0.0577 - accuracy: 0.9787
# Epoch 34/100
# 50/50 [==============================] - 0s 964us/step - loss: 0.0541 - accuracy: 0.9787
# Epoch 35/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0538 - accuracy: 0.9831
# Epoch 36/100
# 50/50 [==============================] - 0s 955us/step - loss: 0.1164 - accuracy: 0.9669
# Epoch 37/100
# 50/50 [==============================] - 0s 943us/step - loss: 0.0462 - accuracy: 0.9831
# Epoch 38/100
# 50/50 [==============================] - 0s 907us/step - loss: 0.0658 - accuracy: 0.9787
# Epoch 39/100
# 50/50 [==============================] - 0s 886us/step - loss: 0.0619 - accuracy: 0.9756
# Epoch 40/100
# 50/50 [==============================] - 0s 914us/step - loss: 0.1036 - accuracy: 0.9669
# Epoch 41/100
# 50/50 [==============================] - 0s 854us/step - loss: 0.1083 - accuracy: 0.9681
# Epoch 42/100
# 50/50 [==============================] - 0s 962us/step - loss: 0.1317 - accuracy: 0.9700
# Epoch 43/100
# 50/50 [==============================] - 0s 950us/step - loss: 0.1210 - accuracy: 0.9656
# Epoch 44/100
# 50/50 [==============================] - 0s 953us/step - loss: 0.0542 - accuracy: 0.9800
# Epoch 45/100
# 50/50 [==============================] - 0s 910us/step - loss: 0.0451 - accuracy: 0.9825
# Epoch 46/100
# 50/50 [==============================] - 0s 972us/step - loss: 0.0500 - accuracy: 0.9850
# Epoch 47/100
# 50/50 [==============================] - 0s 874us/step - loss: 0.0301 - accuracy: 0.9931
# Epoch 48/100
# 50/50 [==============================] - 0s 870us/step - loss: 0.0340 - accuracy: 0.9875
# Epoch 49/100
# 50/50 [==============================] - 0s 926us/step - loss: 0.0556 - accuracy: 0.9819
# Epoch 50/100
# 50/50 [==============================] - 0s 935us/step - loss: 0.0430 - accuracy: 0.9825
# Epoch 51/100
# 50/50 [==============================] - 0s 890us/step - loss: 0.0606 - accuracy: 0.9831
# Epoch 52/100
# 50/50 [==============================] - 0s 928us/step - loss: 0.0387 - accuracy: 0.9887
# Epoch 53/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0408 - accuracy: 0.9881
# Epoch 54/100
# 50/50 [==============================] - 0s 959us/step - loss: 0.0311 - accuracy: 0.9869
# Epoch 55/100
# 50/50 [==============================] - 0s 920us/step - loss: 0.0839 - accuracy: 0.9750
# Epoch 56/100
# 50/50 [==============================] - 0s 957us/step - loss: 0.0801 - accuracy: 0.9787
# Epoch 57/100
# 50/50 [==============================] - 0s 935us/step - loss: 0.0807 - accuracy: 0.9731
# Epoch 58/100
# 50/50 [==============================] - 0s 894us/step - loss: 0.0711 - accuracy: 0.9750
# Epoch 59/100
# 50/50 [==============================] - 0s 871us/step - loss: 0.0399 - accuracy: 0.9850
# Epoch 60/100
# 50/50 [==============================] - 0s 903us/step - loss: 0.0453 - accuracy: 0.9837
# Epoch 61/100
# 50/50 [==============================] - 0s 961us/step - loss: 0.0332 - accuracy: 0.9881
# Epoch 62/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0548 - accuracy: 0.9831
# Epoch 63/100
# 50/50 [==============================] - 0s 954us/step - loss: 0.0971 - accuracy: 0.9744
# Epoch 64/100
# 50/50 [==============================] - 0s 963us/step - loss: 0.0761 - accuracy: 0.9775
# Epoch 65/100
# 50/50 [==============================] - 0s 835us/step - loss: 0.0429 - accuracy: 0.9844
# Epoch 66/100
# 50/50 [==============================] - 0s 804us/step - loss: 0.0562 - accuracy: 0.9837
# Epoch 67/100
# 50/50 [==============================] - 0s 795us/step - loss: 0.0591 - accuracy: 0.9831
# Epoch 68/100
# 50/50 [==============================] - 0s 805us/step - loss: 0.0436 - accuracy: 0.9844
# Epoch 69/100
# 50/50 [==============================] - 0s 822us/step - loss: 0.0350 - accuracy: 0.9869
# Epoch 70/100
# 50/50 [==============================] - 0s 894us/step - loss: 0.0410 - accuracy: 0.9906
# Epoch 71/100
# 50/50 [==============================] - 0s 924us/step - loss: 0.0404 - accuracy: 0.9862
# Epoch 72/100
# 50/50 [==============================] - 0s 941us/step - loss: 0.0409 - accuracy: 0.9806
# Epoch 73/100
# 50/50 [==============================] - 0s 887us/step - loss: 0.0310 - accuracy: 0.9900
# Epoch 74/100
# 50/50 [==============================] - 0s 866us/step - loss: 0.0368 - accuracy: 0.9869
# Epoch 75/100
# 50/50 [==============================] - 0s 963us/step - loss: 0.0272 - accuracy: 0.9900
# Epoch 76/100
# 50/50 [==============================] - 0s 892us/step - loss: 0.0468 - accuracy: 0.9850
# Epoch 77/100
# 50/50 [==============================] - 0s 961us/step - loss: 0.0503 - accuracy: 0.9806
# Epoch 78/100
# 50/50 [==============================] - 0s 793us/step - loss: 0.0388 - accuracy: 0.9881
# Epoch 79/100
# 50/50 [==============================] - 0s 804us/step - loss: 0.3554 - accuracy: 0.9525
# Epoch 80/100
# 50/50 [==============================] - 0s 865us/step - loss: 0.1827 - accuracy: 0.9456
# Epoch 81/100
# 50/50 [==============================] - 0s 894us/step - loss: 0.0381 - accuracy: 0.9850
# Epoch 82/100
# 50/50 [==============================] - 0s 875us/step - loss: 0.0483 - accuracy: 0.9812
# Epoch 83/100
# 50/50 [==============================] - 0s 850us/step - loss: 0.0565 - accuracy: 0.9762
# Epoch 84/100
# 50/50 [==============================] - 0s 926us/step - loss: 0.0399 - accuracy: 0.9875
# Epoch 85/100
# 50/50 [==============================] - 0s 955us/step - loss: 0.0444 - accuracy: 0.9844
# Epoch 86/100
# 50/50 [==============================] - 0s 931us/step - loss: 0.0425 - accuracy: 0.9875
# Epoch 87/100
# 50/50 [==============================] - 0s 946us/step - loss: 0.0340 - accuracy: 0.9887
# Epoch 88/100
# 50/50 [==============================] - 0s 918us/step - loss: 0.0345 - accuracy: 0.9862
# Epoch 89/100
# 50/50 [==============================] - 0s 855us/step - loss: 0.0441 - accuracy: 0.9831
# Epoch 90/100
# 50/50 [==============================] - 0s 821us/step - loss: 0.0883 - accuracy: 0.9781
# Epoch 91/100
# 50/50 [==============================] - 0s 897us/step - loss: 0.0703 - accuracy: 0.9756
# Epoch 92/100
# 50/50 [==============================] - 0s 978us/step - loss: 0.0347 - accuracy: 0.9875
# Epoch 93/100
# 50/50 [==============================] - 0s 993us/step - loss: 0.0311 - accuracy: 0.9900
# Epoch 94/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0384 - accuracy: 0.9881
# Epoch 95/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0407 - accuracy: 0.9844
# Epoch 96/100
# 50/50 [==============================] - 0s 943us/step - loss: 0.0453 - accuracy: 0.9887
# Epoch 97/100
# 50/50 [==============================] - 0s 954us/step - loss: 0.0517 - accuracy: 0.9887
# Epoch 98/100
# 50/50 [==============================] - 0s 949us/step - loss: 0.0484 - accuracy: 0.9837
# Epoch 99/100
# 50/50 [==============================] - 0s 879us/step - loss: 0.0537 - accuracy: 0.9837
# Epoch 100/100
# 50/50 [==============================] - 0s 843us/step - loss: 0.0403 - accuracy: 0.9869

# %%
model.evaluate(X_test, y_test)
# Out:
# 13/13 [==============================] - 0s 896us/step - loss: 0.0240 - accuracy: 0.9875
# [0.02399544045329094, 0.987500011920929]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

y_pred = np.round(model.predict(X_test).ravel())
matrix = confusion_matrix(y_test, y_pred)
matrix
# Out:
# 13/13 [==============================] - 0s 892us/step
# array([[185,   1],
#        [  4, 210]])

# %%
def plot_confusion_matrix(
    matrix,
    class_labels=False,
    figsize=(16, 8), 
    y_ticks_rot=0, 
    x_ticks_rot=0, 
    fs_title=20, 
    fs_label=14, 
    pallete=plt.cm.magma
):
    norm = matrix.sum(axis=1, keepdims=True)
    percentages = ((matrix / norm) * 100).ravel()
    matrices = matrix.ravel()

    cm = np.array([f'{val}\n{percentage:.5f}%' for percentage, val in zip(percentages, matrices)]).reshape(matrix.shape)

    plt.figure(figsize=figsize)

    if class_labels:
        values_labels = [val for val in class_labels.values()]
    else:
        values_labels = "auto"

    sns.heatmap(
        matrix, 
        annot=cm, 
        cmap=pallete, 
        fmt='s', 
        xticklabels=values_labels, 
        yticklabels=values_labels
    )
    plt.xticks(rotation=x_ticks_rot)
    plt.yticks(rotation=y_ticks_rot)
    plt.ylabel('True Label', fontsize=fs_label)
    plt.xlabel('Predicted Label', fontsize=fs_label)
    plt.title('confusion matrix', fontsize=fs_title)
    plt.show()

# %%
plot_confusion_matrix(matrix, pallete=plt.cm.magma)

# %%
df = pd.DataFrame(np.append(X, y.reshape(-1,1), axis=1), columns=['X1', 'X2', 'y'])

plt.figure(figsize=(12, 8))
sns.scatterplot(data=df, x='X1', y='X2', hue='y', alpha=.75)
plt.grid(alpha=.6)
plt.show()

# %%
# Jika menggunakan label
labels = {
    0: 'biru',
    1: 'jingga'
}

plot_confusion_matrix(matrix, pallete=plt.cm.magma, class_labels=labels)

# %%
df_compare = pd.DataFrame(np.append(y_test.reshape(-1,1), y_pred.reshape(-1,1), axis=1), columns=['y test', 'y pred'])

grouping = df_compare.melt().value_counts().sort_index()
display(grouping)
grouping.unstack('variable').plot.bar()
# Out:
# variable  value
# y pred    0.0      189
#           1.0      211
# y test    0.0      186
#           1.0      214
# dtype: int64
# <AxesSubplot:xlabel='value'>
