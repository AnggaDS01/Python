# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def get_data(path):
    return pd.read_csv('./dataset/'+path+'.csv')

df = get_data('penguins_size')

# %%
def diagnose_data(df):
    print(f'shape:\n{df.shape}\n')
    print(f'columns:\n{sorted(df.columns)}\n')
    print(f'n dtypes:\n{df.dtypes.value_counts()}\n')
    print(f'n uniques:')
    for col in df.columns:
        print(f'{col}: {df[col].nunique()}')
    print(f'\nunique values:')
    for col in df.columns:
        print(f'{col}: {df[col].unique()}')
    print(f'\nnull values:')
    for col in df.columns:
        print(f'{col}: {df[col].isnull().sum()}')
    print('\ninfo:')
    df.info()
    return df.head()

def get_data_types(df, types='numeric'):
    numeric_cols = [col for col in df.columns if df[col].dtype != object]
    object_cols = [col for col in df.columns if df[col].dtype == object]
    
    if types == 'numeric':
        return df[numeric_cols]
    elif types == 'object':
        return df[numeric_cols]
    else:
        print('check your argument once again!!')

diagnose_data(df)
# Out:
# shape:
# (344, 7)
#
# columns:
# ['body_mass_g', 'culmen_depth_mm', 'culmen_length_mm', 'flipper_length_mm', 'island', 'sex', 'species']
#
# n dtypes:
# float64    4
# object     3
# dtype: int64
#
# n uniques:
# species: 3
# island: 3
# culmen_length_mm: 164
# culmen_depth_mm: 80
# flipper_length_mm: 55
# body_mass_g: 94
# sex: 3
#
# unique values:
# species: ['Adelie' 'Chinstrap' 'Gentoo']
# island: ['Torgersen' 'Biscoe' 'Dream']
# culmen_length_mm: [39.1 39.5 40.3  nan 36.7 39.3 38.9 39.2 34.1 42.  37.8 41.1 38.6 34.6
#  36.6 38.7 42.5 34.4 46.  37.7 35.9 38.2 38.8 35.3 40.6 40.5 37.9 37.2
#  40.9 36.4 42.2 37.6 39.8 36.5 40.8 36.  44.1 37.  39.6 37.5 42.3 40.1
#  35.  34.5 41.4 39.  35.7 41.3 41.6 35.5 41.8 33.5 39.7 45.8 42.8 36.2
#  42.1 42.9 35.1 37.3 36.3 36.9 38.3 34.  38.1 33.1 43.2 41.  45.6 42.7
#  40.2 35.2 41.5 38.5 43.1 36.8 35.6 32.1 40.7 46.5 50.  51.3 45.4 52.7
#  45.2 46.1 46.6 51.7 47.  52.  45.9 50.5 50.3 58.  46.4 49.2 42.4 48.5
#  50.6 46.7 49.5 52.8 54.2 51.  49.7 47.5 47.6 46.9 53.5 49.  46.2 50.9
#  45.5 50.8 50.1 51.5 49.8 48.1 51.4 45.7 50.7 52.2 49.3 50.2 51.9 46.8
#  55.8 43.5 49.6 48.7 43.3 48.4 45.1 46.3 44.5 47.8 48.2 47.3 59.6 49.1
#  42.6 44.4 44.  45.3 43.6 44.9 45.  43.8 50.4 54.3 47.7 48.6 51.1 52.5
#  47.4 43.4 52.1 49.4 55.9 47.2 41.7 53.4 55.1 48.8 49.9]
# culmen_depth_mm: [18.7 17.4 18.   nan 19.3 20.6 17.8 19.6 18.1 20.2 17.1 17.3 17.6 21.2
#  21.1 19.  20.7 18.4 21.5 18.3 19.2 17.2 18.9 18.6 17.9 16.7 17.  20.
#  18.5 19.1 19.7 16.9 18.8 17.7 19.5 17.5 16.6 18.2 16.2 19.4 16.8 16.1
#  20.3 16.  16.5 20.5 19.8 15.9 20.1 15.5 19.9 20.8 16.4 13.2 16.3 14.1
#  15.2 14.5 13.5 14.6 15.3 13.4 15.4 13.7 15.7 15.1 14.3 15.8 13.1 15.
#  14.2 14.8 13.6 13.9 13.3 14.4 13.8 14.9 15.6 14.  14.7]
# flipper_length_mm: [181. 186. 195.  nan 193. 190. 180. 182. 191. 198. 185. 197. 184. 194.
#  174. 189. 187. 183. 172. 178. 188. 196. 179. 200. 192. 202. 205. 208.
#  203. 199. 176. 210. 201. 212. 206. 207. 211. 230. 218. 215. 219. 209.
#  214. 216. 213. 217. 221. 222. 220. 225. 224. 231. 229. 223. 228. 226.]
# body_mass_g: [3750. 3800. 3250.   nan 3450. 3650. 3625. 4675. 3475. 4250. 3300. 3700.
#  3200. 4400. 4500. 3325. 4200. 3400. 3600. 3950. 3550. 3150. 3900. 4150.
#  4650. 3100. 3000. 4600. 3425. 2975. 3500. 4300. 4050. 2900. 2850. 3350.
#  4100. 3050. 4450. 4000. 4700. 4350. 3725. 4725. 3075. 2925. 3175. 4775.
#  3825. 4275. 4075. 3775. 3875. 3275. 4475. 3975. 3525. 3575. 4550. 3850.
#  4800. 2700. 3675. 5700. 5400. 5200. 5150. 5550. 5850. 6300. 5350. 5000.
#  5050. 5100. 5650. 5250. 6050. 4950. 4750. 4900. 5300. 4850. 5800. 6000.
#  5950. 4625. 5450. 5600. 4875. 4925. 4975. 5500. 4575. 4375. 5750.]
# sex: ['MALE' 'FEMALE' nan '.']
#
# null values:
# species: 0
# island: 0
# culmen_length_mm: 2
# culmen_depth_mm: 2
# flipper_length_mm: 2
# body_mass_g: 2
# sex: 10
#
# info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

imp = IterativeImputer()

numeric_df = get_data_types(df, 'numeric').isnull().sum()
target_cols = numeric_df[numeric_df > 0].index

df[target_cols] = imp.fit_transform(df[target_cols])

# %%
diagnose_data(df)
# Out:
# shape:
# (344, 7)
#
# columns:
# ['body_mass_g', 'culmen_depth_mm', 'culmen_length_mm', 'flipper_length_mm', 'island', 'sex', 'species']
#
# n dtypes:
# float64    4
# object     3
# dtype: int64
#
# n uniques:
# species: 3
# island: 3
# culmen_length_mm: 165
# culmen_depth_mm: 81
# flipper_length_mm: 56
# body_mass_g: 95
# sex: 3
#
# unique values:
# species: ['Adelie' 'Chinstrap' 'Gentoo']
# island: ['Torgersen' 'Biscoe' 'Dream']
# culmen_length_mm: [39.1        39.5        40.3        43.92192982 36.7        39.3
#  38.9        39.2        34.1        42.         37.8        41.1
#  38.6        34.6        36.6        38.7        42.5        34.4
#  46.         37.7        35.9        38.2        38.8        35.3
#  40.6        40.5        37.9        37.2        40.9        36.4
#  42.2        37.6        39.8        36.5        40.8        36.
#  44.1        37.         39.6        37.5        42.3        40.1
#  35.         34.5        41.4        39.         35.7        41.3
#  41.6        35.5        41.8        33.5        39.7        45.8
#  42.8        36.2        42.1        42.9        35.1        37.3
#  36.3        36.9        38.3        34.         38.1        33.1
#  43.2        41.         45.6        42.7        40.2        35.2
#  41.5        38.5        43.1        36.8        35.6        32.1
#  40.7        46.5        50.         51.3        45.4        52.7
#  45.2        46.1        46.6        51.7        47.         52.
#  45.9        50.5        50.3        58.         46.4        49.2
#  42.4        48.5        50.6        46.7        49.5        52.8
#  54.2        51.         49.7        47.5        47.6        46.9
#  53.5        49.         46.2        50.9        45.5        50.8
#  50.1        51.5        49.8        48.1        51.4        45.7
#  50.7        52.2        49.3        50.2        51.9        46.8
#  55.8        43.5        49.6        48.7        43.3        48.4
#  45.1        46.3        44.5        47.8        48.2        47.3
#  59.6        49.1        42.6        44.4        44.         45.3
#  43.6        44.9        45.         43.8        50.4        54.3
#  47.7        48.6        51.1        52.5        47.4        43.4
#  52.1        49.4        55.9        47.2        41.7        53.4
#  55.1        48.8        49.9       ]
# culmen_depth_mm: [18.7        17.4        18.         17.15116959 19.3        20.6
#  17.8        19.6        18.1        20.2        17.1        17.3
#  17.6        21.2        21.1        19.         20.7        18.4
#  21.5        18.3        19.2        17.2        18.9        18.6
#  17.9        16.7        17.         20.         18.5        19.1
#  19.7        16.9        18.8        17.7        19.5        17.5
#  16.6        18.2        16.2        19.4        16.8        16.1
#  20.3        16.         16.5        20.5        19.8        15.9
#  20.1        15.5        19.9        20.8        16.4        13.2
#  16.3        14.1        15.2        14.5        13.5        14.6
#  15.3        13.4        15.4        13.7        15.7        15.1
#  14.3        15.8        13.1        15.         14.2        14.8
#  13.6        13.9        13.3        14.4        13.8        14.9
#  15.6        14.         14.7       ]
# flipper_length_mm: [181.         186.         195.         200.91520468 193.
#  190.         180.         182.         191.         198.
#  185.         197.         184.         194.         174.
#  189.         187.         183.         172.         178.
#  188.         196.         179.         200.         192.
#  202.         205.         208.         203.         199.
#  176.         210.         201.         212.         206.
#  207.         211.         230.         218.         215.
#  219.         209.         214.         216.         213.
#  217.         221.         222.         220.         225.
#  224.         231.         229.         223.         228.
#  226.        ]
# body_mass_g: [3750.         3800.         3250.         4201.75438596 3450.
#  3650.         3625.         4675.         3475.         4250.
#  3300.         3700.         3200.         4400.         4500.
#  3325.         4200.         3400.         3600.         3950.
#  3550.         3150.         3900.         4150.         4650.
#  3100.         3000.         4600.         3425.         2975.
#  3500.         4300.         4050.         2900.         2850.
#  3350.         4100.         3050.         4450.         4000.
#  4700.         4350.         3725.         4725.         3075.
#  2925.         3175.         4775.         3825.         4275.
#  4075.         3775.         3875.         3275.         4475.
#  3975.         3525.         3575.         4550.         3850.
#  4800.         2700.         3675.         5700.         5400.
#  5200.         5150.         5550.         5850.         6300.
#  5350.         5000.         5050.         5100.         5650.
#  5250.         6050.         4950.         4750.         4900.
#  5300.         4850.         5800.         6000.         5950.
#  4625.         5450.         5600.         4875.         4925.
#  4975.         5500.         4575.         4375.         5750.        ]
# sex: ['MALE' 'FEMALE' nan '.']
#
# null values:
# species: 0
# island: 0
# culmen_length_mm: 0
# culmen_depth_mm: 0
# flipper_length_mm: 0
# body_mass_g: 0
# sex: 10
#
# info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   344 non-null    float64
#  3   culmen_depth_mm    344 non-null    float64
#  4   flipper_length_mm  344 non-null    float64
#  5   body_mass_g        344 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen          39.10000         18.70000         181.000000
# 1  Adelie  Torgersen          39.50000         17.40000         186.000000
# 2  Adelie  Torgersen          40.30000         18.00000         195.000000
# 3  Adelie  Torgersen          43.92193         17.15117         200.915205
# 4  Adelie  Torgersen          36.70000         19.30000         193.000000
#
#    body_mass_g     sex
# 0  3750.000000    MALE
# 1  3800.000000  FEMALE
# 2  3250.000000  FEMALE
# 3  4201.754386     NaN
# 4  3450.000000  FEMALE

# %%
sns.pairplot(df, hue='species')
plt.show()

# %%
df.loc[~df['sex'].isin(['FEMALE', 'MALE']), ['species', 'sex']]
# Out:
#     species  sex
# 3    Adelie  NaN
# 8    Adelie  NaN
# 9    Adelie  NaN
# 10   Adelie  NaN
# 11   Adelie  NaN
# 47   Adelie  NaN
# 246  Gentoo  NaN
# 286  Gentoo  NaN
# 324  Gentoo  NaN
# 336  Gentoo    .
# 339  Gentoo  NaN

# %%
df['sex'] = df['sex'].replace({np.nan:df['sex'].mode()[0], '.':df['sex'].mode()[0]})

# %%
diagnose_data(df)
# Out:
# shape:
# (344, 7)
#
# columns:
# ['body_mass_g', 'culmen_depth_mm', 'culmen_length_mm', 'flipper_length_mm', 'island', 'sex', 'species']
#
# n dtypes:
# float64    4
# object     3
# dtype: int64
#
# n uniques:
# species: 3
# island: 3
# culmen_length_mm: 165
# culmen_depth_mm: 81
# flipper_length_mm: 56
# body_mass_g: 95
# sex: 2
#
# unique values:
# species: ['Adelie' 'Chinstrap' 'Gentoo']
# island: ['Torgersen' 'Biscoe' 'Dream']
# culmen_length_mm: [39.1        39.5        40.3        43.92192982 36.7        39.3
#  38.9        39.2        34.1        42.         37.8        41.1
#  38.6        34.6        36.6        38.7        42.5        34.4
#  46.         37.7        35.9        38.2        38.8        35.3
#  40.6        40.5        37.9        37.2        40.9        36.4
#  42.2        37.6        39.8        36.5        40.8        36.
#  44.1        37.         39.6        37.5        42.3        40.1
#  35.         34.5        41.4        39.         35.7        41.3
#  41.6        35.5        41.8        33.5        39.7        45.8
#  42.8        36.2        42.1        42.9        35.1        37.3
#  36.3        36.9        38.3        34.         38.1        33.1
#  43.2        41.         45.6        42.7        40.2        35.2
#  41.5        38.5        43.1        36.8        35.6        32.1
#  40.7        46.5        50.         51.3        45.4        52.7
#  45.2        46.1        46.6        51.7        47.         52.
#  45.9        50.5        50.3        58.         46.4        49.2
#  42.4        48.5        50.6        46.7        49.5        52.8
#  54.2        51.         49.7        47.5        47.6        46.9
#  53.5        49.         46.2        50.9        45.5        50.8
#  50.1        51.5        49.8        48.1        51.4        45.7
#  50.7        52.2        49.3        50.2        51.9        46.8
#  55.8        43.5        49.6        48.7        43.3        48.4
#  45.1        46.3        44.5        47.8        48.2        47.3
#  59.6        49.1        42.6        44.4        44.         45.3
#  43.6        44.9        45.         43.8        50.4        54.3
#  47.7        48.6        51.1        52.5        47.4        43.4
#  52.1        49.4        55.9        47.2        41.7        53.4
#  55.1        48.8        49.9       ]
# culmen_depth_mm: [18.7        17.4        18.         17.15116959 19.3        20.6
#  17.8        19.6        18.1        20.2        17.1        17.3
#  17.6        21.2        21.1        19.         20.7        18.4
#  21.5        18.3        19.2        17.2        18.9        18.6
#  17.9        16.7        17.         20.         18.5        19.1
#  19.7        16.9        18.8        17.7        19.5        17.5
#  16.6        18.2        16.2        19.4        16.8        16.1
#  20.3        16.         16.5        20.5        19.8        15.9
#  20.1        15.5        19.9        20.8        16.4        13.2
#  16.3        14.1        15.2        14.5        13.5        14.6
#  15.3        13.4        15.4        13.7        15.7        15.1
#  14.3        15.8        13.1        15.         14.2        14.8
#  13.6        13.9        13.3        14.4        13.8        14.9
#  15.6        14.         14.7       ]
# flipper_length_mm: [181.         186.         195.         200.91520468 193.
#  190.         180.         182.         191.         198.
#  185.         197.         184.         194.         174.
#  189.         187.         183.         172.         178.
#  188.         196.         179.         200.         192.
#  202.         205.         208.         203.         199.
#  176.         210.         201.         212.         206.
#  207.         211.         230.         218.         215.
#  219.         209.         214.         216.         213.
#  217.         221.         222.         220.         225.
#  224.         231.         229.         223.         228.
#  226.        ]
# body_mass_g: [3750.         3800.         3250.         4201.75438596 3450.
#  3650.         3625.         4675.         3475.         4250.
#  3300.         3700.         3200.         4400.         4500.
#  3325.         4200.         3400.         3600.         3950.
#  3550.         3150.         3900.         4150.         4650.
#  3100.         3000.         4600.         3425.         2975.
#  3500.         4300.         4050.         2900.         2850.
#  3350.         4100.         3050.         4450.         4000.
#  4700.         4350.         3725.         4725.         3075.
#  2925.         3175.         4775.         3825.         4275.
#  4075.         3775.         3875.         3275.         4475.
#  3975.         3525.         3575.         4550.         3850.
#  4800.         2700.         3675.         5700.         5400.
#  5200.         5150.         5550.         5850.         6300.
#  5350.         5000.         5050.         5100.         5650.
#  5250.         6050.         4950.         4750.         4900.
#  5300.         4850.         5800.         6000.         5950.
#  4625.         5450.         5600.         4875.         4925.
#  4975.         5500.         4575.         4375.         5750.        ]
# sex: ['MALE' 'FEMALE']
#
# null values:
# species: 0
# island: 0
# culmen_length_mm: 0
# culmen_depth_mm: 0
# flipper_length_mm: 0
# body_mass_g: 0
# sex: 0
#
# info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   344 non-null    float64
#  3   culmen_depth_mm    344 non-null    float64
#  4   flipper_length_mm  344 non-null    float64
#  5   body_mass_g        344 non-null    float64
#  6   sex                344 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen          39.10000         18.70000         181.000000
# 1  Adelie  Torgersen          39.50000         17.40000         186.000000
# 2  Adelie  Torgersen          40.30000         18.00000         195.000000
# 3  Adelie  Torgersen          43.92193         17.15117         200.915205
# 4  Adelie  Torgersen          36.70000         19.30000         193.000000
#
#    body_mass_g     sex
# 0  3750.000000    MALE
# 1  3800.000000  FEMALE
# 2  3250.000000  FEMALE
# 3  4201.754386    MALE
# 4  3450.000000  FEMALE

# %%
from sklearn.preprocessing import LabelBinarizer

lb = LabelBinarizer()
df['sex'] = lb.fit_transform(df[['sex']])

df = pd.get_dummies(data=df, columns=['island'])

# %%
diagnose_data(df)
# Out:
# shape:
# (344, 9)
#
# columns:
# ['body_mass_g', 'culmen_depth_mm', 'culmen_length_mm', 'flipper_length_mm', 'island_Biscoe', 'island_Dream', 'island_Torgersen', 'sex', 'species']
#
# n dtypes:
# float64    4
# uint8      3
# object     1
# int32      1
# dtype: int64
#
# n uniques:
# species: 3
# culmen_length_mm: 165
# culmen_depth_mm: 81
# flipper_length_mm: 56
# body_mass_g: 95
# sex: 2
# island_Biscoe: 2
# island_Dream: 2
# island_Torgersen: 2
#
# unique values:
# species: ['Adelie' 'Chinstrap' 'Gentoo']
# culmen_length_mm: [39.1        39.5        40.3        43.92192982 36.7        39.3
#  38.9        39.2        34.1        42.         37.8        41.1
#  38.6        34.6        36.6        38.7        42.5        34.4
#  46.         37.7        35.9        38.2        38.8        35.3
#  40.6        40.5        37.9        37.2        40.9        36.4
#  42.2        37.6        39.8        36.5        40.8        36.
#  44.1        37.         39.6        37.5        42.3        40.1
#  35.         34.5        41.4        39.         35.7        41.3
#  41.6        35.5        41.8        33.5        39.7        45.8
#  42.8        36.2        42.1        42.9        35.1        37.3
#  36.3        36.9        38.3        34.         38.1        33.1
#  43.2        41.         45.6        42.7        40.2        35.2
#  41.5        38.5        43.1        36.8        35.6        32.1
#  40.7        46.5        50.         51.3        45.4        52.7
#  45.2        46.1        46.6        51.7        47.         52.
#  45.9        50.5        50.3        58.         46.4        49.2
#  42.4        48.5        50.6        46.7        49.5        52.8
#  54.2        51.         49.7        47.5        47.6        46.9
#  53.5        49.         46.2        50.9        45.5        50.8
#  50.1        51.5        49.8        48.1        51.4        45.7
#  50.7        52.2        49.3        50.2        51.9        46.8
#  55.8        43.5        49.6        48.7        43.3        48.4
#  45.1        46.3        44.5        47.8        48.2        47.3
#  59.6        49.1        42.6        44.4        44.         45.3
#  43.6        44.9        45.         43.8        50.4        54.3
#  47.7        48.6        51.1        52.5        47.4        43.4
#  52.1        49.4        55.9        47.2        41.7        53.4
#  55.1        48.8        49.9       ]
# culmen_depth_mm: [18.7        17.4        18.         17.15116959 19.3        20.6
#  17.8        19.6        18.1        20.2        17.1        17.3
#  17.6        21.2        21.1        19.         20.7        18.4
#  21.5        18.3        19.2        17.2        18.9        18.6
#  17.9        16.7        17.         20.         18.5        19.1
#  19.7        16.9        18.8        17.7        19.5        17.5
#  16.6        18.2        16.2        19.4        16.8        16.1
#  20.3        16.         16.5        20.5        19.8        15.9
#  20.1        15.5        19.9        20.8        16.4        13.2
#  16.3        14.1        15.2        14.5        13.5        14.6
#  15.3        13.4        15.4        13.7        15.7        15.1
#  14.3        15.8        13.1        15.         14.2        14.8
#  13.6        13.9        13.3        14.4        13.8        14.9
#  15.6        14.         14.7       ]
# flipper_length_mm: [181.         186.         195.         200.91520468 193.
#  190.         180.         182.         191.         198.
#  185.         197.         184.         194.         174.
#  189.         187.         183.         172.         178.
#  188.         196.         179.         200.         192.
#  202.         205.         208.         203.         199.
#  176.         210.         201.         212.         206.
#  207.         211.         230.         218.         215.
#  219.         209.         214.         216.         213.
#  217.         221.         222.         220.         225.
#  224.         231.         229.         223.         228.
#  226.        ]
# body_mass_g: [3750.         3800.         3250.         4201.75438596 3450.
#  3650.         3625.         4675.         3475.         4250.
#  3300.         3700.         3200.         4400.         4500.
#  3325.         4200.         3400.         3600.         3950.
#  3550.         3150.         3900.         4150.         4650.
#  3100.         3000.         4600.         3425.         2975.
#  3500.         4300.         4050.         2900.         2850.
#  3350.         4100.         3050.         4450.         4000.
#  4700.         4350.         3725.         4725.         3075.
#  2925.         3175.         4775.         3825.         4275.
#  4075.         3775.         3875.         3275.         4475.
#  3975.         3525.         3575.         4550.         3850.
#  4800.         2700.         3675.         5700.         5400.
#  5200.         5150.         5550.         5850.         6300.
#  5350.         5000.         5050.         5100.         5650.
#  5250.         6050.         4950.         4750.         4900.
#  5300.         4850.         5800.         6000.         5950.
#  4625.         5450.         5600.         4875.         4925.
#  4975.         5500.         4575.         4375.         5750.        ]
# sex: [1 0]
# island_Biscoe: [0 1]
# island_Dream: [0 1]
# island_Torgersen: [1 0]
#
# null values:
# species: 0
# culmen_length_mm: 0
# culmen_depth_mm: 0
# flipper_length_mm: 0
# body_mass_g: 0
# sex: 0
# island_Biscoe: 0
# island_Dream: 0
# island_Torgersen: 0
#
# info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   culmen_length_mm   344 non-null    float64
#  2   culmen_depth_mm    344 non-null    float64
#  3   flipper_length_mm  344 non-null    float64
#  4   body_mass_g        344 non-null    float64
#  5   sex                344 non-null    int32
#  6   island_Biscoe      344 non-null    uint8
#  7   island_Dream       344 non-null    uint8
#  8   island_Torgersen   344 non-null    uint8
# dtypes: float64(4), int32(1), object(1), uint8(3)
# memory usage: 15.9+ KB
#   species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0  Adelie          39.10000         18.70000         181.000000  3750.000000
# 1  Adelie          39.50000         17.40000         186.000000  3800.000000
# 2  Adelie          40.30000         18.00000         195.000000  3250.000000
# 3  Adelie          43.92193         17.15117         200.915205  4201.754386
# 4  Adelie          36.70000         19.30000         193.000000  3450.000000
#
#    sex  island_Biscoe  island_Dream  island_Torgersen
# 0    1              0             0                 1
# 1    0              0             0                 1
# 2    0              0             0                 1
# 3    1              0             0                 1
# 4    0              0             0                 1

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['species'] = le.fit_transform(df['species'])

diagnose_data(df)
# Out:
# shape:
# (344, 9)
#
# columns:
# ['body_mass_g', 'culmen_depth_mm', 'culmen_length_mm', 'flipper_length_mm', 'island_Biscoe', 'island_Dream', 'island_Torgersen', 'sex', 'species']
#
# n dtypes:
# float64    4
# uint8      3
# int32      2
# dtype: int64
#
# n uniques:
# species: 3
# culmen_length_mm: 165
# culmen_depth_mm: 81
# flipper_length_mm: 56
# body_mass_g: 95
# sex: 2
# island_Biscoe: 2
# island_Dream: 2
# island_Torgersen: 2
#
# unique values:
# species: [0 1 2]
# culmen_length_mm: [39.1        39.5        40.3        43.92192982 36.7        39.3
#  38.9        39.2        34.1        42.         37.8        41.1
#  38.6        34.6        36.6        38.7        42.5        34.4
#  46.         37.7        35.9        38.2        38.8        35.3
#  40.6        40.5        37.9        37.2        40.9        36.4
#  42.2        37.6        39.8        36.5        40.8        36.
#  44.1        37.         39.6        37.5        42.3        40.1
#  35.         34.5        41.4        39.         35.7        41.3
#  41.6        35.5        41.8        33.5        39.7        45.8
#  42.8        36.2        42.1        42.9        35.1        37.3
#  36.3        36.9        38.3        34.         38.1        33.1
#  43.2        41.         45.6        42.7        40.2        35.2
#  41.5        38.5        43.1        36.8        35.6        32.1
#  40.7        46.5        50.         51.3        45.4        52.7
#  45.2        46.1        46.6        51.7        47.         52.
#  45.9        50.5        50.3        58.         46.4        49.2
#  42.4        48.5        50.6        46.7        49.5        52.8
#  54.2        51.         49.7        47.5        47.6        46.9
#  53.5        49.         46.2        50.9        45.5        50.8
#  50.1        51.5        49.8        48.1        51.4        45.7
#  50.7        52.2        49.3        50.2        51.9        46.8
#  55.8        43.5        49.6        48.7        43.3        48.4
#  45.1        46.3        44.5        47.8        48.2        47.3
#  59.6        49.1        42.6        44.4        44.         45.3
#  43.6        44.9        45.         43.8        50.4        54.3
#  47.7        48.6        51.1        52.5        47.4        43.4
#  52.1        49.4        55.9        47.2        41.7        53.4
#  55.1        48.8        49.9       ]
# culmen_depth_mm: [18.7        17.4        18.         17.15116959 19.3        20.6
#  17.8        19.6        18.1        20.2        17.1        17.3
#  17.6        21.2        21.1        19.         20.7        18.4
#  21.5        18.3        19.2        17.2        18.9        18.6
#  17.9        16.7        17.         20.         18.5        19.1
#  19.7        16.9        18.8        17.7        19.5        17.5
#  16.6        18.2        16.2        19.4        16.8        16.1
#  20.3        16.         16.5        20.5        19.8        15.9
#  20.1        15.5        19.9        20.8        16.4        13.2
#  16.3        14.1        15.2        14.5        13.5        14.6
#  15.3        13.4        15.4        13.7        15.7        15.1
#  14.3        15.8        13.1        15.         14.2        14.8
#  13.6        13.9        13.3        14.4        13.8        14.9
#  15.6        14.         14.7       ]
# flipper_length_mm: [181.         186.         195.         200.91520468 193.
#  190.         180.         182.         191.         198.
#  185.         197.         184.         194.         174.
#  189.         187.         183.         172.         178.
#  188.         196.         179.         200.         192.
#  202.         205.         208.         203.         199.
#  176.         210.         201.         212.         206.
#  207.         211.         230.         218.         215.
#  219.         209.         214.         216.         213.
#  217.         221.         222.         220.         225.
#  224.         231.         229.         223.         228.
#  226.        ]
# body_mass_g: [3750.         3800.         3250.         4201.75438596 3450.
#  3650.         3625.         4675.         3475.         4250.
#  3300.         3700.         3200.         4400.         4500.
#  3325.         4200.         3400.         3600.         3950.
#  3550.         3150.         3900.         4150.         4650.
#  3100.         3000.         4600.         3425.         2975.
#  3500.         4300.         4050.         2900.         2850.
#  3350.         4100.         3050.         4450.         4000.
#  4700.         4350.         3725.         4725.         3075.
#  2925.         3175.         4775.         3825.         4275.
#  4075.         3775.         3875.         3275.         4475.
#  3975.         3525.         3575.         4550.         3850.
#  4800.         2700.         3675.         5700.         5400.
#  5200.         5150.         5550.         5850.         6300.
#  5350.         5000.         5050.         5100.         5650.
#  5250.         6050.         4950.         4750.         4900.
#  5300.         4850.         5800.         6000.         5950.
#  4625.         5450.         5600.         4875.         4925.
#  4975.         5500.         4575.         4375.         5750.        ]
# sex: [1 0]
# island_Biscoe: [0 1]
# island_Dream: [0 1]
# island_Torgersen: [1 0]
#
# null values:
# species: 0
# culmen_length_mm: 0
# culmen_depth_mm: 0
# flipper_length_mm: 0
# body_mass_g: 0
# sex: 0
# island_Biscoe: 0
# island_Dream: 0
# island_Torgersen: 0
#
# info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    int32
#  1   culmen_length_mm   344 non-null    float64
#  2   culmen_depth_mm    344 non-null    float64
#  3   flipper_length_mm  344 non-null    float64
#  4   body_mass_g        344 non-null    float64
#  5   sex                344 non-null    int32
#  6   island_Biscoe      344 non-null    uint8
#  7   island_Dream       344 non-null    uint8
#  8   island_Torgersen   344 non-null    uint8
# dtypes: float64(4), int32(2), uint8(3)
# memory usage: 14.6 KB
#    species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0        0          39.10000         18.70000         181.000000  3750.000000
# 1        0          39.50000         17.40000         186.000000  3800.000000
# 2        0          40.30000         18.00000         195.000000  3250.000000
# 3        0          43.92193         17.15117         200.915205  4201.754386
# 4        0          36.70000         19.30000         193.000000  3450.000000
#
#    sex  island_Biscoe  island_Dream  island_Torgersen
# 0    1              0             0                 1
# 1    0              0             0                 1
# 2    0              0             0                 1
# 3    1              0             0                 1
# 4    0              0             0                 1

# %%
X = df.drop(columns='species', axis='columns')
y = df['species']

# %%
X.head()
# Out:
#    culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  sex  \
# 0          39.10000         18.70000         181.000000  3750.000000    1
# 1          39.50000         17.40000         186.000000  3800.000000    0
# 2          40.30000         18.00000         195.000000  3250.000000    0
# 3          43.92193         17.15117         200.915205  4201.754386    1
# 4          36.70000         19.30000         193.000000  3450.000000    0
#
#    island_Biscoe  island_Dream  island_Torgersen
# 0              0             0                 1
# 1              0             0                 1
# 2              0             0                 1
# 3              0             0                 1
# 4              0             0                 1

# %%
y.unique()
# Out:
# array([0, 1, 2])

# %%
from sklearn.preprocessing import MinMaxScaler

cols_scale = [col for col in X.columns if len(X[col].unique()) > 2]

scaler = MinMaxScaler()
X[cols_scale] = scaler.fit_transform(X[cols_scale])

# %%
X.head()
# Out:
#    culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  sex  \
# 0          0.254545         0.666667           0.152542     0.291667    1
# 1          0.269091         0.511905           0.237288     0.305556    0
# 2          0.298182         0.583333           0.389831     0.152778    0
# 3          0.429888         0.482282           0.490088     0.417154    1
# 4          0.167273         0.738095           0.355932     0.208333    0
#
#    island_Biscoe  island_Dream  island_Torgersen
# 0              0             0                 1
# 1              0             0                 1
# 2              0             0                 1
# 3              0             0                 1
# 4              0             0                 1

# %%
from sklearn.feature_selection import f_classif
f, p = f_classif(X[cols_scale], y)

f, p
# Out:
# (array([405.48163828, 354.41046638, 579.15971127, 338.57291008]),
#  array([7.23326619e-091, 5.42594307e-084, 2.21139411e-110, 1.00697705e-081]))

# %%
from sklearn.feature_selection import mutual_info_classif
mi = mutual_info_classif(X[cols_scale], y)

mi
# Out:
# array([0.54782045, 0.58368258, 0.61143884, 0.50253527])

# %%
feature_score = pd.DataFrame(
    {
        'Feature': X[cols_scale].columns,
        'F': f,
        'MI': mi,
    }
).sort_values(
    'MI', ascending=False
)

feature_score.style.bar(
    subset=['F', 'MI'], color='grey'
)
# Out:
# <style  type="text/css" >
# #T_17a15_row0_col1,#T_17a15_row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,grey 100.0%, transparent 100.0%);
#         }#T_17a15_row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,grey 6.6%, transparent 6.6%);
#         }#T_17a15_row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,grey 74.5%, transparent 74.5%);
#         }#T_17a15_row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,grey 27.8%, transparent 27.8%);
#         }#T_17a15_row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,grey 41.6%, transparent 41.6%);
#         }#T_17a15_row3_col1,#T_17a15_row3_col2{
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_17a15_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >F</th>        <th class="col_heading level0 col2" >MI</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_17a15_level0_row0" class="row_heading level0 row0" >2</th>
#                         <td id="T_17a15_row0_col0" class="data row0 col0" >flipper_length_mm</td>
#                         <td id="T_17a15_row0_col1" class="data row0 col1" >579.159711</td>
#                         <td id="T_17a15_row0_col2" class="data row0 col2" >0.611439</td>
#             </tr>
#             <tr>
#                         <th id="T_17a15_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_17a15_row1_col0" class="data row1 col0" >culmen_depth_mm</td>
#                         <td id="T_17a15_row1_col1" class="data row1 col1" >354.410466</td>
#                         <td id="T_17a15_row1_col2" class="data row1 col2" >0.583683</td>
#             </tr>
#             <tr>
#                         <th id="T_17a15_level0_row2" class="row_heading level0 row2" >0</th>
#                         <td id="T_17a15_row2_col0" class="data row2 col0" >culmen_length_mm</td>
#                         <td id="T_17a15_row2_col1" class="data row2 col1" >405.481638</td>
#                         <td id="T_17a15_row2_col2" class="data row2 col2" >0.547820</td>
#             </tr>
#             <tr>
#                         <th id="T_17a15_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_17a15_row3_col0" class="data row3 col0" >body_mass_g</td>
#                         <td id="T_17a15_row3_col1" class="data row3 col1" >338.572910</td>
#                         <td id="T_17a15_row3_col2" class="data row3 col2" >0.502535</td>
#             </tr>
#     </tbody></table>

# %%
sns.pairplot(data=df[['species', 'culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm', 'body_mass_g']], hue='species')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_validate

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=.25,
    random_state=1
)

# %%
model_params=[
    {
        'model_name': 'DecisionTreeClassifier',
        'model': DecisionTreeClassifier()
    },
    {
        'model_name': 'RandomForestClassifier',
        'model': RandomForestClassifier()
    },
    {
        'model_name': 'LogisticRegression',
        'model': LogisticRegression()
    },
    {
        'model_name': 'SVM',
        'model': SVC()
    },
    {
        'model_name': 'KNeighborsClassifier',
        'model': KNeighborsClassifier()
    }
]

def tuning_models(X, y, model_params, model_name='model_name', model='model', max_splits=20, get_mean=False):
    rs = ShuffleSplit(n_splits=max_splits, test_size=.2, random_state=0)
    estimated_model = {}
    for idx in range(len(model_params)):
        cv_results = cross_validate(
            model_params[idx]['model'], X, y, cv=rs, scoring='accuracy'
        )
        estimated_model[model_params[idx]['model_name']]= cv_results['test_score']
    df_scoring = pd.DataFrame(estimated_model, index=[f'score {i}' for i in range(max_splits)])
    
    if get_mean:
        for col in df_scoring.columns:
            print(f'{col}: {df_scoring[col].mean()}')
    else:
        return df_scoring

# %%
tuning_models(X_train, y_train, model_params, 'model_name', 'model', 20)
# Out:
#           DecisionTreeClassifier  RandomForestClassifier  LogisticRegression  \
# score 0                 0.980769                0.961538            0.980769
# score 1                 0.923077                0.980769            1.000000
# score 2                 0.942308                0.961538            0.961538
# score 3                 0.961538                0.980769            0.980769
# score 4                 0.961538                1.000000            1.000000
# score 5                 0.903846                0.961538            0.980769
# score 6                 0.980769                1.000000            1.000000
# score 7                 0.942308                1.000000            1.000000
# score 8                 1.000000                1.000000            1.000000
# score 9                 0.961538                0.980769            0.980769
# score 10                0.942308                0.980769            0.980769
# score 11                0.961538                0.980769            0.980769
# score 12                0.980769                1.000000            1.000000
# score 13                1.000000                1.000000            1.000000
# score 14                0.961538                1.000000            1.000000
# score 15                0.903846                0.961538            0.961538
# score 16                0.980769                1.000000            1.000000
# score 17                0.980769                0.980769            0.980769
# score 18                1.000000                1.000000            1.000000
# score 19                1.000000                1.000000            1.000000
#
#                SVM  KNeighborsClassifier
# score 0   0.980769              0.961538
# score 1   1.000000              1.000000
# score 2   0.980769              0.980769
# score 3   1.000000              1.000000
# score 4   0.980769              0.980769
# score 5   1.000000              1.000000
# score 6   1.000000              1.000000
# score 7   1.000000              1.000000
# score 8   1.000000              1.000000
# score 9   0.961538              0.961538
# score 10  0.980769              0.980769
# score 11  0.980769              0.980769
# score 12  1.000000              1.000000
# score 13  1.000000              0.980769
# score 14  1.000000              0.980769
# score 15  0.980769              0.980769
# score 16  1.000000              1.000000
# score 17  0.980769              0.980769
# score 18  1.000000              1.000000
# score 19  1.000000              0.980769

# %%
tuning_models(X, y, model_params, 'model_name', 'model', 20, get_mean=True)
# Out:
# DecisionTreeClassifier: 0.972463768115942
# RandomForestClassifier: 0.9884057971014494
# LogisticRegression: 0.9898550724637684
# SVM: 0.9905797101449277
# KNeighborsClassifier: 0.9898550724637684

# %%
scores = []

clf = GridSearchCV(
    estimator=SVC(random_state=0),
    param_grid={   
        'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
        'C': [0.5, 1, 10, 100],
        'gamma': ['scale', 'auto', 1, 0.1, 0.01, 0.001]
    },
    cv=20,
    n_jobs=4,
    return_train_score=False
)
clf.fit(X_train, y_train)
scores.append({
    'model': 'SVM',
    'best_score': clf.best_score_,
    'best_params': clf.best_params_
})

# %%
cv_df = pd.DataFrame(scores, columns=['model', 'best_score', 'best_params'])
cv_df
# Out:
#   model  best_score                                    best_params
# 0   SVM    0.996154  {'C': 100, 'gamma': 0.1, 'kernel': 'sigmoid'}

# %%
from sklearn.metrics import classification_report

model = SVC(C = 100, gamma= 0.1, kernel= 'sigmoid', random_state=0)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        42
#            1       1.00      1.00      1.00        14
#            2       1.00      1.00      1.00        30
#
#     accuracy                           1.00        86
#    macro avg       1.00      1.00      1.00        86
# weighted avg       1.00      1.00      1.00        86

# %%
series_pred = pd.Series(le.inverse_transform(y_pred))

# %%
series_test = pd.Series(le.inverse_transform(y_test))

# %%
pd.concat([series_test, series_pred], axis='columns', keys=['test', 'predicted'])
# Out:
#       test predicted
# 0   Gentoo    Gentoo
# 1   Gentoo    Gentoo
# 2   Gentoo    Gentoo
# 3   Adelie    Adelie
# 4   Gentoo    Gentoo
# ..     ...       ...
# 81  Gentoo    Gentoo
# 82  Adelie    Adelie
# 83  Adelie    Adelie
# 84  Gentoo    Gentoo
# 85  Adelie    Adelie
#
# [86 rows x 2 columns]
